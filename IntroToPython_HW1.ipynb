# %% [markdown]
# # Welcome to Intro to Python's Homework 1 Part 1 & 2
#
# Function 1 - 4. Now some of these will also be covered in 90 questions as well.
# Hello Students!! I hope this finds you well. I am trying to make these so it is easier for the students to upload and open the questions. It is also slightly easier than the powerpoints. You will be finding many more questions along the way and I hope I don't give you too many. But I believe in you. Good luck.

# %%
# HW Problem 1 Part 1 Function 1
# Make a function called silly_case 
# that takes a string  and returns a new string that is the same as the input string
# but the first letter of each word is in lowercase 
# and all the other letters are uppercase.
# Please do not use looping!!

poem = "It matters now how straight the gate, \nhow charged with punishments the scroll. \nI am the master of my fate: \nI am the captain of my soul."
x = "This is a string"


assert silly_case(poem) == "iT mATTERS nOW hOW sTRAIGHT tHE gATE, \nhOW cHARGED wITH pUNISHMENTS tHE sCROLL. \ni aM tHE mASTER oF mY fATE: \ni aM tHE cAPTAIN oF mY sOUL."
assert silly_case(x) == "tHIS iS a sTRING"
print("HW Problem 1 Function 1 is correct")

# %%
# HW Problem 1 Part 1 Function 2

# Make a function called dash_stringify 
# so that is takes a list of words (strings) and returns a string
# that contains all the words from the list with ‘-’ in between the words.
# No looping!!!




assert dash_stringify(fruits) == "Orange-Lemon-Lime-Cherry-Peach-Apricot"
try:
  assert dash_stringify(nums) == "1-2-3"
except:
  print("Dash Stringify can only be used on Strings")
print("HW Problem 1 Function 2 is correct")

# %%
# HW Problem 1 Part 1 Function 3

# This function is also probably a part of you 90 problems. 


# Make a function called is_perfect_square so that it takes a number as an input and returns True if the 
# given number is a perfect square, or False if it is not. 
# Please do not use looping!!

# A perfect square is an integer number which is the square of an integer. For example 25 (5*5),  49 
# (7*7), and 81 (9*9) are all perfect squares



assert is_perfect_square1(81) == True
assert is_perfect_square1(82) == False
assert is_perfect_square2(81) == True
assert is_perfect_square2(83) == False
assert is_perfect_square3(81) == True
assert is_perfect_square3(83) == False

print("HW1 Function 3 is correct")

# %%
# HW Problem 1 Part 1 Function 4

# Make a function called is_leap_year so that it takes a year 
# as a number input and returns True if the given number is a leap year
# or False if it is not. 


# Leap years are years that are divisible by 4
# Exception: Centennial years (years divided by 100) are not leap years
# Exception to exception: years divisible by 400 are indeed leap years


assert is_leap_year(1900) == False
assert is_leap_year(2000) == True
assert is_leap_year(2012) == True
assert is_leap_year(2018) == False

print("HW1 Function 4 is correct")

# %% [markdown]
# # HW1 Part 3 Create Your Own Chatbot Project
#
# Hello Students in this project you will be creating your own chatbot. The bot will take in
# input from you and seem to respond with questions. Only you will be doing all the
# programming. If you follow the steps and fill in some of the blanks you will have a great
# project to complete.
# *Caution this image is large and opening this markdown editor will be confusing. Don't worry we'll cover this
#
# ![chatbot3.png](data:image/png;base64,...)

# %% [markdown]
# # Step 1: Create a file for you code
#
# You may do this in MyBinder or REPLIT as well. But you may also use this file.
#
# # Step 2: Add Code for the Introductions
# To start, the chatbot introduces itself using print statements and asks the user for their name
# using an input statement. The name entered by the user is stored in a variable called ​name​ and
# used again later to print a custom message.

# %%
# Try Coding this yourself in this box before looking at the next cell for the answer

# Psuedocode 
# Print introduction to the chatbot  
# Get name from user 
# Print hello name (name gotten from user)

# %% [markdown]
# # Chatbot Introduction Answer

# %%
print("Hello. I am Zyxo 64. I am a chatbot") 
print("I like animals and I lover to talk about food") 
name = input("What is your name?: ") 
print("Hello", name + ", nice to meet you.")

# %% [markdown]
# # Step 3: Add Code for the Introductions
# To show that your chat bot can do math (and you can try out the Python math functions), ask
# the user for the current year and a guess of the chatbot’s age. Then, respond with the year in
# which the hatbot will be 100. (You can easily change this to asking the user for their age and
# telling them the year they will be 100.) ​You will be adding this to the code you were given above
#
#
# *Guidance: When there are ???? question marks in the code. You are supposed to fill in that section.*
#
# *In addition "Psuedocode" is the plain langauge mental process that your program is going to follow. It is a good idea to know what you want to code before you code it*
#
# *Another piece of guidance is that if you need to comment (put # in front) out a bunch of code at at time to make corrections to an error. You can select it all and hit the Ctrl + /*

# %%
# Please try to code this psuedocode. I will provide a little assistance

# Pseudocode 
# Get current year from user 
# Print guess is correct 
# Get chatbot age from user 
# Print guess is correct 
# Convert chatbot age to integer 
# Set years to 100 - chatbot age 
# Print I will be 100 in years 
# Convert current year to integer 
# Print That will be current year + years 


#  get year information 
# Delete the ???? and replace it with a python command that would ask the user what year it is
# Then delete the second ????, replace it with something that will have the chatbot say what is shown

year = input("I am not very good at dates. What is the year?: ")
print("Yes, I think that is correct. Thanks!")

# ask user to guess the age of the chatbot
# sometimes you may have to retype the whole line. I have seen just placing the ???? with the correct code doesn't work 
# even if the code will work. Just delete the original line if so.

myage = input("Can you guess my age? - enter a number. ")
print("Yes, you are right. I am", myage + ".")


# do math to calculate when chatbot will be 100 

myage = ????(myage)  # Look up a python function to convert a string into an integer
nyears = 100 - myage 
????("I will be 100 in", nyears, "years.")
????("That will be the year", int(year) + nyears)

# %% [markdown]
# # Step 4: Use Data Stored for Simple Fill-in Template Responses
# We can now ask and respond to the user on a few topics, using the data entered by the user
# where possible in the conversation. Here is an example of a conversation on food and another
# one on animals. Notice how the responses entered by the user are stored in variables and
# reused in the print statements.
#
#
#
# You are now being asked to code this section on your own. Based on
# the code shown in steps 2 and 3 you should have all the pieces to do
# this correctly! Good luck!
# The same will apply for steps 5 and 6. Try matching the pseudocode
# to the actual code to see what each part of pseudocode requires. You
# may also reference the original conversation if you are not sure what
# to put in each part. In addition you do not have to exactly copy what is
# in the chat

# %%
# Pseudocode 
# Print I love chocolate and trying new kinds of food 
# Get favorite food from user 
# Print I like favorite food too 
# Get how often user eats favorite food 
# Print Interesting. I wonder if that is good for your health 
# Get favorite animal from user 
# Print favorite animal! I don’t like them 
# Print I wonder if favorite animal likes to eat favorite food

# %% [markdown]
# # Step 5: Add in a Conversation About Feelings
# Add in some more general comments on how the user is feeling, responding with a generic
# comment so the chatbot does not have to make an actual intelligent response based on the
# user’s input.

# %%
# Pseudocode 
# Get how user is feeling 
# Print why are you feeling the way the user is feeling now 
# Get user’s reason 
# Print I understand. Thanks for sharing

# %% [markdown]
# # Step 6: Close with a Custom Goodbye
# Close the chatbot conversation with a custom goodbye using the user’s name.

# %%
# Pseudocode 
# Print it’s been a long day 
# Print I am too tired to talk. We can chat again later 
# Print goodbye, user name, I like chatting with you
