# %%
# !pip install numpy
# !pip install scipy
# !pip install seaborn
# !pip install pandas
# !pip install matplotlib
# !pip install sklearn
# !pip install pymatgen
# Out:
# Requirement already satisfied: numpy in /srv/conda/envs/notebook/lib/python3.7/site-packages (1.21.4)
# Requirement already satisfied: scipy in /srv/conda/envs/notebook/lib/python3.7/site-packages (1.7.3)
# Requirement already satisfied: numpy<1.23.0,>=1.16.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from scipy) (1.21.4)
# Requirement already satisfied: seaborn in /srv/conda/envs/notebook/lib/python3.7/site-packages (0.11.2)
# Requirement already satisfied: scipy>=1.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from seaborn) (1.7.3)
# Requirement already satisfied: matplotlib>=2.2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from seaborn) (3.5.0)
# Requirement already satisfied: pandas>=0.23 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from seaborn) (1.3.4)
# Requirement already satisfied: numpy>=1.15 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from seaborn) (1.21.4)
# Requirement already satisfied: pillow>=6.2.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (8.4.0)
# Requirement already satisfied: setuptools-scm>=4 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (6.3.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (4.28.2)
# Requirement already satisfied: python-dateutil>=2.7 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (3.0.6)
# Requirement already satisfied: pytz>=2017.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas>=0.23->seaborn) (2021.3)
# Requirement already satisfied: six>=1.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)
# Requirement already satisfied: tomli>=1.0.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from setuptools-scm>=4->matplotlib>=2.2->seaborn) (1.2.2)
# Requirement already satisfied: setuptools in /srv/conda/envs/notebook/lib/python3.7/site-packages (from setuptools-scm>=4->matplotlib>=2.2->seaborn) (59.1.1)
# Requirement already satisfied: pandas in /srv/conda/envs/notebook/lib/python3.7/site-packages (1.3.4)
# Requirement already satisfied: pytz>=2017.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas) (2021.3)
# Requirement already satisfied: numpy>=1.17.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas) (1.21.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Requirement already satisfied: matplotlib in /srv/conda/envs/notebook/lib/python3.7/site-packages (3.5.0)
# Requirement already satisfied: packaging>=20.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib) (3.0.6)
# Requirement already satisfied: python-dateutil>=2.7 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib) (4.28.2)
# Requirement already satisfied: cycler>=0.10 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: numpy>=1.17 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib) (1.21.4)
# Requirement already satisfied: pillow>=6.2.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: setuptools-scm>=4 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib) (6.3.2)
# Requirement already satisfied: six>=1.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: tomli>=1.0.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from setuptools-scm>=4->matplotlib) (1.2.2)
# Requirement already satisfied: setuptools in /srv/conda/envs/notebook/lib/python3.7/site-packages (from setuptools-scm>=4->matplotlib) (59.1.1)
# Requirement already satisfied: sklearn in /srv/conda/envs/notebook/lib/python3.7/site-packages (0.0)
# Requirement already satisfied: scikit-learn in /srv/conda/envs/notebook/lib/python3.7/site-packages (from sklearn) (1.0.1)
# Requirement already satisfied: numpy>=1.14.6 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from scikit-learn->sklearn) (1.21.4)
# Requirement already satisfied: joblib>=0.11 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from scikit-learn->sklearn) (1.1.0)
# Requirement already satisfied: scipy>=1.1.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from scikit-learn->sklearn) (1.7.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from scikit-learn->sklearn) (3.0.0)
# Requirement already satisfied: pymatgen in /srv/conda/envs/notebook/lib/python3.7/site-packages (2022.0.16)
# Requirement already satisfied: matplotlib>=1.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pymatgen) (3.5.0)
# Requirement already satisfied: uncertainties>=3.1.4 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pymatgen) (3.1.6)
# Requirement already satisfied: ruamel.yaml>=0.15.6 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pymatgen) (0.17.17)
# Requirement already satisfied: requests in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pymatgen) (2.26.0)
# Requirement already satisfied: palettable>=3.1.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pymatgen) (3.3.0)
# Requirement already satisfied: plotly>=4.5.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pymatgen) (5.4.0)
# Requirement already satisfied: tabulate in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pymatgen) (0.8.9)
# Requirement already satisfied: spglib>=1.9.9.44 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pymatgen) (1.16.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pymatgen) (4.0.0)
# Requirement already satisfied: sympy in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pymatgen) (1.9)
# Requirement already satisfied: monty>=3.0.2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pymatgen) (2021.12.1)
# Requirement already satisfied: pandas in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pymatgen) (1.3.4)
# Requirement already satisfied: scipy>=1.5.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pymatgen) (1.7.3)
# Requirement already satisfied: networkx>=2.2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pymatgen) (2.6.3)
# Requirement already satisfied: numpy>=1.20.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pymatgen) (1.21.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib>=1.5->pymatgen) (1.3.2)
# Requirement already satisfied: packaging>=20.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib>=1.5->pymatgen) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib>=1.5->pymatgen) (8.4.0)
# Requirement already satisfied: cycler>=0.10 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib>=1.5->pymatgen) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib>=1.5->pymatgen) (4.28.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib>=1.5->pymatgen) (3.0.6)
# Requirement already satisfied: python-dateutil>=2.7 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib>=1.5->pymatgen) (2.8.2)
# Requirement already satisfied: setuptools-scm>=4 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib>=1.5->pymatgen) (6.3.2)
# Requirement already satisfied: tenacity>=6.2.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from plotly>=4.5.0->pymatgen) (8.0.1)
# Requirement already satisfied: six in /srv/conda/envs/notebook/lib/python3.7/site-packages (from plotly>=4.5.0->pymatgen) (1.16.0)
# Requirement already satisfied: ruamel.yaml.clib>=0.1.2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from ruamel.yaml>=0.15.6->pymatgen) (0.2.6)
# Requirement already satisfied: future in /srv/conda/envs/notebook/lib/python3.7/site-packages (from uncertainties>=3.1.4->pymatgen) (0.18.2)
# Requirement already satisfied: pytz>=2017.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas->pymatgen) (2021.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests->pymatgen) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests->pymatgen) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests->pymatgen) (3.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests->pymatgen) (2.0.0)
# Requirement already satisfied: mpmath>=0.19 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from sympy->pymatgen) (1.2.1)
# Requirement already satisfied: setuptools in /srv/conda/envs/notebook/lib/python3.7/site-packages (from setuptools-scm>=4->matplotlib>=1.5->pymatgen) (59.1.1)
# Requirement already satisfied: tomli>=1.0.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from setuptools-scm>=4->matplotlib>=1.5->pymatgen) (1.2.2)

# %%
# Importing Librariesb
import numpy as np
import scipy as sp
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, GridSearchCV, KFold
from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
from sklearn.ensemble import AdaBoostRegressor, AdaBoostClassifier, \
    GradientBoostingClassifier, GradientBoostingRegressor, \
    RandomForestClassifier, RandomForestRegressor
from sklearn.metrics import r2_score
from pymatgen.core import Element, Composition, periodic_table
from functools import partial

# %%
#  --NotebookApp.iopub_data_rate_limit=1.0e10

# %%
# Loading training and testing data
train= pd.read_csv("train.csv",index_col=False)
test= pd.read_csv("test.csv",index_col=False)

# Querying materials and their properties based on training data
from pymatgen.ext.matproj import MPRester
mpr = MPRester("241iWwhTEOaNmC6V")

# Using material IDs provided in training data to get corresponding information from MPD
data = mpr.query(criteria={"task_id": {"$in":train["material_id"].to_list()}}, properties=["material_id","energy",
        "energy_per_atom",
        "volume",
        "formation_energy_per_atom",
        "nsites",
        "pretty_formula",                                                                                  
        "nelements",
        "density",  "band_gap"])
df = pd.DataFrame(data)
display(df)
# Out:
# 0 of 5619 done 0.0%
# 500 of 5619 done 8.9%
# 1000 of 5619 done 17.8%
# 1500 of 5619 done 26.7%
# 2000 of 5619 done 35.6%
# 2500 of 5619 done 44.5%
# 3000 of 5619 done 53.4%
# 3500 of 5619 done 62.3%
# 4000 of 5619 done 71.2%
# 4500 of 5619 done 80.1%
# 5000 of 5619 done 89.0%
# 5500 of 5619 done 97.9%
# 5619 of 5619 done 100.0%
#      material_id      energy  energy_per_atom      volume  \
# 0     mp-1001034  -52.019078        -3.715648  376.145863
# 1     mp-1001780  -22.364406        -5.591101   78.515319
# 2     mp-1001786  -23.600913        -5.900228   71.701237
# 3     mp-1002124  -19.780759        -9.890380   32.055765
# 4     mp-1004528  -95.454964        -5.614998  324.979430
# ...          ...         ...              ...         ...
# 5614    mvc-6916  -99.385289        -7.098949  156.686110
# 5615    mvc-6928  -91.603914        -6.543137  173.941832
# 5616    mvc-6946  -36.735653        -6.122609   97.529160
# 5617    mvc-7040 -145.212422        -8.067357  418.920727
# 5618    mvc-7383 -124.502927        -6.225146  317.655229
#
#       formation_energy_per_atom  nsites pretty_formula  nelements   density  \
# 0                     -0.703661      14     Mg(InSe2)2          3  5.030727
# 1                     -1.699567       4         LuCuS2          3  6.400668
# 2                     -2.103385       4         LiScS2          3  2.687084
# 3                     -0.298402       2            HfC          2  9.868236
# 4                     -3.162482      17      CsB3PbF12          4  3.068458
# ...                         ...     ...            ...        ...       ...
# 5614                  -2.307339      14        MgMn2O4          3  4.200544
# 5615                  -2.192463      14      Ca(FeO2)2          3  4.119621
# 5616                  -1.961400       6           SnO2          2  5.131960
# 5617                  -1.999722      18          Re2O7          2  3.840256
# 5618                  -1.597210      20        ZnCr2O7          3  2.941999
#
#       band_gap
# 0       0.7432
# 1       1.5031
# 2       1.5296
# 3       0.5774
# 4       6.3125
# ...        ...
# 5614    0.0516
# 5615    1.7463
# 5616    2.1009
# 5617    3.4689
# 5618    2.4238
#
# [5619 rows x 10 columns]

# %%
# Making list of possible noble gases 
nobles = ["He","Ne", "Ar", "Kr", "Xe", "Rn", "Og"]
filt_data = df

#Iterating through data and using pandas drop function to filter out materials containing noble gas elements 
for i in nobles:
    filt_data = filt_data.drop(filt_data[filt_data['pretty_formula'].str.contains(i)].index)
    
n = len(filt_data)
print(f'There are {n} materials left')    
display(filt_data)


print(f'There are {n} materials left')    
display(filt_data)
# Out:
# There are 5614 materials left
#      material_id      energy  energy_per_atom      volume  \
# 0     mp-1001034  -52.019078        -3.715648  376.145863
# 1     mp-1001780  -22.364406        -5.591101   78.515319
# 2     mp-1001786  -23.600913        -5.900228   71.701237
# 3     mp-1002124  -19.780759        -9.890380   32.055765
# 4     mp-1004528  -95.454964        -5.614998  324.979430
# ...          ...         ...              ...         ...
# 5614    mvc-6916  -99.385289        -7.098949  156.686110
# 5615    mvc-6928  -91.603914        -6.543137  173.941832
# 5616    mvc-6946  -36.735653        -6.122609   97.529160
# 5617    mvc-7040 -145.212422        -8.067357  418.920727
# 5618    mvc-7383 -124.502927        -6.225146  317.655229
#
#       formation_energy_per_atom  nsites pretty_formula  nelements   density  \
# 0                     -0.703661      14     Mg(InSe2)2          3  5.030727
# 1                     -1.699567       4         LuCuS2          3  6.400668
# 2                     -2.103385       4         LiScS2          3  2.687084
# 3                     -0.298402       2            HfC          2  9.868236
# 4                     -3.162482      17      CsB3PbF12          4  3.068458
# ...                         ...     ...            ...        ...       ...
# 5614                  -2.307339      14        MgMn2O4          3  4.200544
# 5615                  -2.192463      14      Ca(FeO2)2          3  4.119621
# 5616                  -1.961400       6           SnO2          2  5.131960
# 5617                  -1.999722      18          Re2O7          2  3.840256
# 5618                  -1.597210      20        ZnCr2O7          3  2.941999
#
#       band_gap
# 0       0.7432
# 1       1.5031
# 2       1.5296
# 3       0.5774
# 4       6.3125
# ...        ...
# 5614    0.0516
# 5615    1.7463
# 5616    2.1009
# 5617    3.4689
# 5618    2.4238
#
# [5614 rows x 10 columns]
# There are 5614 materials left
#      material_id      energy  energy_per_atom      volume  \
# 0     mp-1001034  -52.019078        -3.715648  376.145863
# 1     mp-1001780  -22.364406        -5.591101   78.515319
# 2     mp-1001786  -23.600913        -5.900228   71.701237
# 3     mp-1002124  -19.780759        -9.890380   32.055765
# 4     mp-1004528  -95.454964        -5.614998  324.979430
# ...          ...         ...              ...         ...
# 5614    mvc-6916  -99.385289        -7.098949  156.686110
# 5615    mvc-6928  -91.603914        -6.543137  173.941832
# 5616    mvc-6946  -36.735653        -6.122609   97.529160
# 5617    mvc-7040 -145.212422        -8.067357  418.920727
# 5618    mvc-7383 -124.502927        -6.225146  317.655229
#
#       formation_energy_per_atom  nsites pretty_formula  nelements   density  \
# 0                     -0.703661      14     Mg(InSe2)2          3  5.030727
# 1                     -1.699567       4         LuCuS2          3  6.400668
# 2                     -2.103385       4         LiScS2          3  2.687084
# 3                     -0.298402       2            HfC          2  9.868236
# 4                     -3.162482      17      CsB3PbF12          4  3.068458
# ...                         ...     ...            ...        ...       ...
# 5614                  -2.307339      14        MgMn2O4          3  4.200544
# 5615                  -2.192463      14      Ca(FeO2)2          3  4.119621
# 5616                  -1.961400       6           SnO2          2  5.131960
# 5617                  -1.999722      18          Re2O7          2  3.840256
# 5618                  -1.597210      20        ZnCr2O7          3  2.941999
#
#       band_gap
# 0       0.7432
# 1       1.5031
# 2       1.5296
# 3       0.5774
# 4       6.3125
# ...        ...
# 5614    0.0516
# 5615    1.7463
# 5616    2.1009
# 5617    3.4689
# 5618    2.4238
#
# [5614 rows x 10 columns]

# %%
filt_data
# Out:
#      material_id      energy  energy_per_atom      volume  \
# 0     mp-1001034  -52.019078        -3.715648  376.145863
# 1     mp-1001780  -22.364406        -5.591101   78.515319
# 2     mp-1001786  -23.600913        -5.900228   71.701237
# 3     mp-1002124  -19.780759        -9.890380   32.055765
# 4     mp-1004528  -95.454964        -5.614998  324.979430
# ...          ...         ...              ...         ...
# 5614    mvc-6916  -99.385289        -7.098949  156.686110
# 5615    mvc-6928  -91.603914        -6.543137  173.941832
# 5616    mvc-6946  -36.735653        -6.122609   97.529160
# 5617    mvc-7040 -145.212422        -8.067357  418.920727
# 5618    mvc-7383 -124.502927        -6.225146  317.655229
#
#       formation_energy_per_atom  nsites pretty_formula  nelements   density  \
# 0                     -0.703661      14     Mg(InSe2)2          3  5.030727
# 1                     -1.699567       4         LuCuS2          3  6.400668
# 2                     -2.103385       4         LiScS2          3  2.687084
# 3                     -0.298402       2            HfC          2  9.868236
# 4                     -3.162482      17      CsB3PbF12          4  3.068458
# ...                         ...     ...            ...        ...       ...
# 5614                  -2.307339      14        MgMn2O4          3  4.200544
# 5615                  -2.192463      14      Ca(FeO2)2          3  4.119621
# 5616                  -1.961400       6           SnO2          2  5.131960
# 5617                  -1.999722      18          Re2O7          2  3.840256
# 5618                  -1.597210      20        ZnCr2O7          3  2.941999
#
#       band_gap
# 0       0.7432
# 1       1.5031
# 2       1.5296
# 3       0.5774
# 4       6.3125
# ...        ...
# 5614    0.0516
# 5615    1.7463
# 5616    2.1009
# 5617    3.4689
# 5618    2.4238
#
# [5614 rows x 10 columns]

# %%
listA = [a for a in filt_data["pretty_formula"]]
listB = [Composition(a) for a in listA]
listC = [a.elements for a in listB]

editC = [item for sublist in listC for item in sublist]
unique_editC = set(editC)
unique_editC

UL_editC = [a for a in unique_editC]
cprops = [a.data for a in UL_editC]

# %%
peel=set(UL_editC)
sy_editC = [a.symbol for a in UL_editC]
sy_editC


pd.set_option('display.max_columns', None)

cprops_df = pd.DataFrame(cprops, index=sy_editC)

cprops_df.head()
# Out:
#     Atomic mass  Atomic no                                    Atomic orbitals  \
# H      1.007940          1                                  {'1s': -0.233471}
# Li     6.941000          3                  {'1s': -1.878564, '2s': -0.10554}
# Be     9.012182          4                 {'1s': -3.856411, '2s': -0.205744}
# B     10.811000          5  {'1s': -6.564347, '2p': -0.136603, '2s': -0.34...
# C     12.010700          6  {'1s': -9.947718, '2p': -0.199186, '2s': -0.50...
#
#     Atomic radius Atomic radius calculated Boiling point  \
# H            0.25                     0.53       20.28 K
# Li           1.45                     1.67        1615 K
# Be           1.05                     1.12        2742 K
# B            0.85                     0.87        4200 K
# C            0.70                     0.67        4300 K
#
#              Brinell hardness Bulk modulus  \
# H   no data MN m<sup>-2</sup>  no data GPa
# Li  no data MN m<sup>-2</sup>       11 GPa
# Be      600 MN m<sup>-2</sup>      130 GPa
# B   no data MN m<sup>-2</sup>      320 GPa
# C   no data MN m<sup>-2</sup>       33 GPa
#
#    Coefficient of linear thermal expansion Common oxidation states  \
# H   no data x10<sup>-6</sup>K<sup>-1</sup>                 [-1, 1]
# Li       46 x10<sup>-6</sup>K<sup>-1</sup>                     [1]
# Be     11.3 x10<sup>-6</sup>K<sup>-1</sup>                     [2]
# B         6 x10<sup>-6</sup>K<sup>-1</sup>                     [3]
# C       7.1 x10<sup>-6</sup>K<sup>-1</sup>                 [-4, 4]
#
#    Critical temperature           Density of solid  \
# H                  33 K  no data kg m<sup>-3</sup>
# Li               3223 K      535 kg m<sup>-3</sup>
# Be            no data K     1848 kg m<sup>-3</sup>
# B             no data K     2460 kg m<sup>-3</sup>
# C             no data K     2267 kg m<sup>-3</sup>
#
#                                Electrical resistivity  \
# H                   no data 10<sup>-8</sup> &Omega; m
# Li                      9.5 10<sup>-8</sup> &Omega; m
# Be                      3.8 10<sup>-8</sup> &Omega; m
# B       &gt; 10<sup>12</sup>10<sup>-8</sup> &Omega; m
# C   about 1000 - direction dependent10<sup>-8</sup...
#
#                   Electronic structure  ICSD oxidation states Liquid range  \
# H                       1s<sup>1</sup>                [1, -1]       6.27 K
# Li                 [He].2s<sup>1</sup>                    [1]    1161.31 K
# Be                 [He].2s<sup>2</sup>                    [2]       1182 K
# B   [He].2s<sup>2</sup>.2p<sup>1</sup>                [3, -3]       1851 K
# C   [He].2s<sup>2</sup>.2p<sup>2</sup>  [2, 3, 4, -4, -3, -2]        500 K
#
#    Melting point  Mendeleev no                           Mineral hardness  \
# H        14.01 K           103                                    no data
# Li      453.69 K            12                                        0.6
# Be        1560 K            77                                        5.5
# B         2349 K            86                                        9.3
# C         3800 K            95  0.5 (graphite; diamond is 10.0)(no units)
#
#             Molar volume       Name              Oxidation states  \
# H   11.42 cm<sup>3</sup>   Hydrogen                       [-1, 1]
# Li  13.02 cm<sup>3</sup>    Lithium                           [1]
# Be   4.85 cm<sup>3</sup>  Beryllium                           [2]
# B    4.39 cm<sup>3</sup>      Boron                     [1, 2, 3]
# C    5.29 cm<sup>3</sup>     Carbon  [-4, -3, -2, -1, 1, 2, 3, 4]
#
#    Poissons ratio Reflectivity                       Refractive index  \
# H         no data    no data %  1.000132 (gas; liquid 1.12)(no units)
# Li        no data    no data %                                no data
# Be          0.032    no data %                                no data
# B         no data    no data %                                no data
# C         no data         27 %              2.417 (diamond)(no units)
#
#    Rigidity modulus                                      Shannon radii  \
# H       no data GPa  {'1': {'I': {'': {'crystal_radius': -0.24, 'io...
# Li          4.2 GPa  {'1': {'IV': {'': {'crystal_radius': 0.73, 'io...
# Be          132 GPa  {'2': {'III': {'': {'crystal_radius': 0.3, 'io...
# B       no data GPa  {'3': {'III': {'': {'crystal_radius': 0.15, 'i...
# C       no data GPa  {'4': {'III': {'': {'crystal_radius': 0.06, 'i...
#
#    Superconduction temperature                    Thermal conductivity  \
# H                    no data K  0.1805 W m<sup>-1</sup> K<sup>-1</sup>
# Li                   no data K      85 W m<sup>-1</sup> K<sup>-1</sup>
# Be                     0.026 K     190 W m<sup>-1</sup> K<sup>-1</sup>
# B                    no data K      27 W m<sup>-1</sup> K<sup>-1</sup>
# C                    no data K     140 W m<sup>-1</sup> K<sup>-1</sup>
#
#     Van der waals radius       Velocity of sound           Vickers hardness  \
# H                   1.10   1270 m s<sup>-1</sup>  no data MN m<sup>-2</sup>
# Li                  1.82   6000 m s<sup>-1</sup>  no data MN m<sup>-2</sup>
# Be                  1.53  13000 m s<sup>-1</sup>     1670 MN m<sup>-2</sup>
# B                   1.92  16200 m s<sup>-1</sup>    49000 MN m<sup>-2</sup>
# C                   1.70  18350 m s<sup>-1</sup>  no data MN m<sup>-2</sup>
#
#        X Youngs modulus            NMR Quadrupole Moment Metallic radius  \
# H   2.20    no data GPa                    {'H-2': 2.86}         no data
# Li  0.98        4.9 GPa  {'Li-6': -0.808, 'Li-7': -40.1}            1.52
# Be  1.57        287 GPa                  {'Be-9': 52.88}            1.12
# B   2.04    no data GPa   {'B-10': 84.59, 'B-11': 40.59}         no data
# C   2.55    no data GPa                  {'C-11': 33.27}         no data
#
#     iupac_ordering  IUPAC ordering Ground level  \
# H               92              92        2S1/2
# Li              11              11        2S1/2
# Be              17              17          1S0
# B               81              81       2P°1/2
# C               86              86          3P0
#
#                                   Ionization energies  Electron affinity  \
# H                                   [13.598434599702]           0.754598
# Li             [5.391714996, 75.640097, 122.45435914]           0.618049
# Be      [9.322699, 18.21115, 153.896205, 217.7185861]          -0.520000
# B   [8.298019, 25.15483, 37.93059, 259.3715, 340.2...           0.279723
# C   [11.260288, 24.383154, 47.88778, 64.49352, 392...           1.262114
#
#     Ionic radii Ionic radii hs Ionic radii ls
# H           NaN            NaN            NaN
# Li   {'1': 0.9}            NaN            NaN
# Be  {'2': 0.59}            NaN            NaN
# B   {'3': 0.41}            NaN            NaN
# C    {'4': 0.3}            NaN            NaN

# %%
droplist = ['Ionic radii',
    'Ionic radii hs', 
     'Ionic radii ls',
     'iupac_ordering', 
     'IUPAC ordering', 
     'NMR Quadrupole Moment', 
     'Reflectivity',
     'Refractive index', 
     'Rigidity modulus', 
     'Shannon radii',
     'Superconduction temperature',
     'Mendeleev no',       
     'Mineral hardness',
     'Molar volume',
     'Name',
     'Oxidation states',
     'ICSD oxidation states',
     'Brinell hardness',
     'Atomic orbitals', 
     'Coefficient of linear thermal expansion',
     'Atomic orbitals',
     'Electronic structure',
     'Electrical resistivity',
     'Ground level'
           ]


cprops_df = cprops_df.drop(columns=droplist)
cprops_df
# Out:
#     Atomic mass  Atomic no  Atomic radius Atomic radius calculated  \
# H      1.007940          1           0.25                     0.53
# Li     6.941000          3           1.45                     1.67
# Be     9.012182          4           1.05                     1.12
# B     10.811000          5           0.85                     0.87
# C     12.010700          6           0.70                     0.67
# ..          ...        ...            ...                      ...
# Pb   207.200000         82           1.80                     1.54
# Bi   208.980400         83           1.60                     1.43
# Ac   227.000000         89           1.95                  no data
# Th   232.038060         90           1.80                  no data
# U    238.028910         92           1.75                  no data
#
#    Boiling point Bulk modulus Common oxidation states Critical temperature  \
# H        20.28 K  no data GPa                 [-1, 1]                 33 K
# Li        1615 K       11 GPa                     [1]               3223 K
# Be        2742 K      130 GPa                     [2]            no data K
# B         4200 K      320 GPa                     [3]            no data K
# C         4300 K       33 GPa                 [-4, 4]            no data K
# ..           ...          ...                     ...                  ...
# Pb        2022 K       46 GPa                  [2, 4]            no data K
# Bi        1837 K       31 GPa                     [3]            no data K
# Ac        3573 K  no data GPa                     [3]            no data K
# Th        5093 K       54 GPa                     [4]            no data K
# U         4200 K      100 GPa                     [6]            no data K
#
#              Density of solid Liquid range Melting point Poissons ratio  \
# H   no data kg m<sup>-3</sup>       6.27 K       14.01 K        no data
# Li      535 kg m<sup>-3</sup>    1161.31 K      453.69 K        no data
# Be     1848 kg m<sup>-3</sup>       1182 K        1560 K          0.032
# B      2460 kg m<sup>-3</sup>       1851 K        2349 K        no data
# C      2267 kg m<sup>-3</sup>        500 K        3800 K        no data
# ..                        ...          ...           ...            ...
# Pb    11340 kg m<sup>-3</sup>    1421.39 K      600.61 K           0.44
# Bi     9780 kg m<sup>-3</sup>     1292.6 K       544.4 K           0.33
# Ac    10070 kg m<sup>-3</sup>       2250 K        1323 K        no data
# Th    11724 kg m<sup>-3</sup>       2978 K        2115 K           0.27
# U     19050 kg m<sup>-3</sup>     2794.7 K      1405.3 K           0.23
#
#                       Thermal conductivity  Van der waals radius  \
# H   0.1805 W m<sup>-1</sup> K<sup>-1</sup>                  1.10
# Li      85 W m<sup>-1</sup> K<sup>-1</sup>                  1.82
# Be     190 W m<sup>-1</sup> K<sup>-1</sup>                  1.53
# B       27 W m<sup>-1</sup> K<sup>-1</sup>                  1.92
# C      140 W m<sup>-1</sup> K<sup>-1</sup>                  1.70
# ..                                     ...                   ...
# Pb      35 W m<sup>-1</sup> K<sup>-1</sup>                  2.02
# Bi       8 W m<sup>-1</sup> K<sup>-1</sup>                  2.07
# Ac      12 W m<sup>-1</sup> K<sup>-1</sup>                  2.47
# Th      54 W m<sup>-1</sup> K<sup>-1</sup>                  2.45
# U       27 W m<sup>-1</sup> K<sup>-1</sup>                  2.41
#
#            Velocity of sound           Vickers hardness     X Youngs modulus  \
# H      1270 m s<sup>-1</sup>  no data MN m<sup>-2</sup>  2.20    no data GPa
# Li     6000 m s<sup>-1</sup>  no data MN m<sup>-2</sup>  0.98        4.9 GPa
# Be    13000 m s<sup>-1</sup>     1670 MN m<sup>-2</sup>  1.57        287 GPa
# B     16200 m s<sup>-1</sup>    49000 MN m<sup>-2</sup>  2.04    no data GPa
# C     18350 m s<sup>-1</sup>  no data MN m<sup>-2</sup>  2.55    no data GPa
# ..                       ...                        ...   ...            ...
# Pb     1260 m s<sup>-1</sup>  no data MN m<sup>-2</sup>  2.33         16 GPa
# Bi     1790 m s<sup>-1</sup>  no data MN m<sup>-2</sup>  2.02         32 GPa
# Ac  no data m s<sup>-1</sup>  no data MN m<sup>-2</sup>  1.10    no data GPa
# Th     2490 m s<sup>-1</sup>      350 MN m<sup>-2</sup>  1.30         79 GPa
# U      3155 m s<sup>-1</sup>     1960 MN m<sup>-2</sup>  1.38        208 GPa
#
#    Metallic radius                                Ionization energies  \
# H          no data                                  [13.598434599702]
# Li            1.52             [5.391714996, 75.640097, 122.45435914]
# Be            1.12      [9.322699, 18.21115, 153.896205, 217.7185861]
# B          no data  [8.298019, 25.15483, 37.93059, 259.3715, 340.2...
# C          no data  [11.260288, 24.383154, 47.88778, 64.49352, 392...
# ..             ...                                                ...
# Pb            1.75  [7.4166799, 15.032499, 31.9373, 42.33256, 68.8...
# Bi            1.82  [7.285516, 16.703, 25.57075, 45.37, 54.856, 88...
# Ac           1.878  [5.380226, 11.75, 17.431, 44.8, 55.0, 67.0, 79...
# Th           1.798  [6.3067, 12.1, 18.32, 28.648, 58.0, 69.1, 82.0...
# U            1.542  [6.19405, 11.6, 19.8, 36.7, 46.0, 62.0, 89.0, ...
#
#     Electron affinity
# H            0.754598
# Li           0.618049
# Be          -0.520000
# B            0.279723
# C            1.262114
# ..                ...
# Pb           0.356721
# Bi           0.942362
# Ac           0.350000
# Th           1.170000
# U            0.530000
#
# [80 rows x 21 columns]

# %%
#pd.set_option('display.max_rows', None)
cprops_df['Melting point']
# Out:
# H      14.01 K
# Li    453.69 K
# Be      1560 K
# B       2349 K
# C       3800 K
#         ...
# Pb    600.61 K
# Bi     544.4 K
# Ac      1323 K
# Th      2115 K
# U     1405.3 K
# Name: Melting point, Length: 80, dtype: object

# %%
cprops_df['Boiling point'] = [(a.replace('K', '', 1)) for a in cprops_df['Boiling point']]
cprops_df['Bulk modulus'] = cprops_df["Bulk modulus"].str.replace("GPa", "")
cprops_df['Critical temperature'] = cprops_df["Critical temperature"].str.replace("K", "")
cprops_df['Density of solid'] = cprops_df['Density of solid'].str.replace("no data", "NaN")
cprops_df['Density of solid'] = cprops_df["Density of solid"].str.replace("kg m<sup>-3</sup>", "")
cprops_df['Liquid range'] = [(a.replace('K', '', 1)) for a in cprops_df['Liquid range']]
cprops_df['Poissons ratio'] = [(a.replace('no data', 'NaN', 1)) for a in cprops_df['Poissons ratio']]
cprops_df['Poissons ratio'] = cprops_df['Poissons ratio'].str.replace("no data", "").astype(float)
cprops_df['Thermal conductivity'] = [float(a.replace('W m<sup>-1</sup> K<sup>-1</sup>', "", 1)) for a in cprops_df['Thermal conductivity']]
cprops_df['Velocity of sound'] = cprops_df['Velocity of sound'].str.replace("no data","NaN")
cprops_df['Velocity of sound'] = [(a.replace('m s<sup>-1</sup>', '', 1)) for a in cprops_df['Velocity of sound']]
cprops_df['Vickers hardness'] = cprops_df['Vickers hardness'].str.replace("no data", "NaN")
cprops_df['Vickers hardness'] = [(a.replace('MN m<sup>-2</sup>', '', 1)) for a in cprops_df['Vickers hardness']]
cprops_df['Youngs modulus'] = cprops_df['Youngs modulus'].str.replace("no data", "NaN")
cprops_df['Youngs modulus'] = [(a.replace('GPa', '', 1)) for a in cprops_df['Youngs modulus']]



#cprops_df['Boiling point'] = [float(a.replace('K', '', 1)) for a in cprops_df['Boiling point']]
cprops_df
# Out:
#     Atomic mass  Atomic no  Atomic radius Atomic radius calculated  \
# H      1.007940          1           0.25                     0.53
# Li     6.941000          3           1.45                     1.67
# Be     9.012182          4           1.05                     1.12
# B     10.811000          5           0.85                     0.87
# C     12.010700          6           0.70                     0.67
# ..          ...        ...            ...                      ...
# Pb   207.200000         82           1.80                     1.54
# Bi   208.980400         83           1.60                     1.43
# Ac   227.000000         89           1.95                  no data
# Th   232.038060         90           1.80                  no data
# U    238.028910         92           1.75                  no data
#
#    Boiling point Bulk modulus Common oxidation states Critical temperature  \
# H         20.28      no data                  [-1, 1]                  33
# Li         1615           11                      [1]                3223
# Be         2742          130                      [2]             no data
# B          4200          320                      [3]             no data
# C          4300           33                  [-4, 4]             no data
# ..           ...          ...                     ...                  ...
# Pb         2022           46                   [2, 4]             no data
# Bi         1837           31                      [3]             no data
# Ac         3573      no data                      [3]             no data
# Th         5093           54                      [4]             no data
# U          4200          100                      [6]             no data
#
#    Density of solid Liquid range Melting point  Poissons ratio  \
# H              NaN         6.27        14.01 K             NaN
# Li             535      1161.31       453.69 K             NaN
# Be            1848         1182         1560 K           0.032
# B             2460         1851         2349 K             NaN
# C             2267          500         3800 K             NaN
# ..              ...          ...           ...             ...
# Pb           11340      1421.39       600.61 K           0.440
# Bi            9780       1292.6        544.4 K           0.330
# Ac           10070         2250         1323 K             NaN
# Th           11724         2978         2115 K           0.270
# U            19050       2794.7       1405.3 K           0.230
#
#     Thermal conductivity  Van der waals radius Velocity of sound  \
# H                 0.1805                  1.10             1270
# Li               85.0000                  1.82             6000
# Be              190.0000                  1.53            13000
# B                27.0000                  1.92            16200
# C               140.0000                  1.70            18350
# ..                   ...                   ...               ...
# Pb               35.0000                  2.02             1260
# Bi                8.0000                  2.07             1790
# Ac               12.0000                  2.47              NaN
# Th               54.0000                  2.45             2490
# U                27.0000                  2.41             3155
#
#    Vickers hardness     X Youngs modulus Metallic radius  \
# H              NaN   2.20           NaN          no data
# Li             NaN   0.98           4.9             1.52
# Be            1670   1.57           287             1.12
# B            49000   2.04           NaN          no data
# C              NaN   2.55           NaN          no data
# ..              ...   ...            ...             ...
# Pb             NaN   2.33            16             1.75
# Bi             NaN   2.02            32             1.82
# Ac             NaN   1.10           NaN            1.878
# Th             350   1.30            79            1.798
# U             1960   1.38           208            1.542
#
#                                   Ionization energies  Electron affinity
# H                                   [13.598434599702]           0.754598
# Li             [5.391714996, 75.640097, 122.45435914]           0.618049
# Be      [9.322699, 18.21115, 153.896205, 217.7185861]          -0.520000
# B   [8.298019, 25.15483, 37.93059, 259.3715, 340.2...           0.279723
# C   [11.260288, 24.383154, 47.88778, 64.49352, 392...           1.262114
# ..                                                ...                ...
# Pb  [7.4166799, 15.032499, 31.9373, 42.33256, 68.8...           0.356721
# Bi  [7.285516, 16.703, 25.57075, 45.37, 54.856, 88...           0.942362
# Ac  [5.380226, 11.75, 17.431, 44.8, 55.0, 67.0, 79...           0.350000
# Th  [6.3067, 12.1, 18.32, 28.648, 58.0, 69.1, 82.0...           1.170000
# U   [6.19405, 11.6, 19.8, 36.7, 46.0, 62.0, 89.0, ...           0.530000
#
# [80 rows x 21 columns]

# %%
cprops_df['Bulk modulus'] = [(a.replace('no data', 'NaN', 1)) for a in cprops_df['Bulk modulus']]
cprops_df['Bulk modulus'] = [(a.replace('liquid', '', 1)) for a in cprops_df['Bulk modulus']]
cprops_df['Bulk modulus'] = cprops_df['Bulk modulus'].str.replace(r"\(.*\)","",  regex=True).astype(float)
cprops_df 
#cprops_df
# Out:
#     Atomic mass  Atomic no  Atomic radius Atomic radius calculated  \
# H      1.007940          1           0.25                     0.53
# Li     6.941000          3           1.45                     1.67
# Be     9.012182          4           1.05                     1.12
# B     10.811000          5           0.85                     0.87
# C     12.010700          6           0.70                     0.67
# ..          ...        ...            ...                      ...
# Pb   207.200000         82           1.80                     1.54
# Bi   208.980400         83           1.60                     1.43
# Ac   227.000000         89           1.95                  no data
# Th   232.038060         90           1.80                  no data
# U    238.028910         92           1.75                  no data
#
#    Boiling point  Bulk modulus Common oxidation states Critical temperature  \
# H         20.28            NaN                 [-1, 1]                  33
# Li         1615           11.0                     [1]                3223
# Be         2742          130.0                     [2]             no data
# B          4200          320.0                     [3]             no data
# C          4300           33.0                 [-4, 4]             no data
# ..           ...           ...                     ...                  ...
# Pb         2022           46.0                  [2, 4]             no data
# Bi         1837           31.0                     [3]             no data
# Ac         3573            NaN                     [3]             no data
# Th         5093           54.0                     [4]             no data
# U          4200          100.0                     [6]             no data
#
#    Density of solid Liquid range Melting point  Poissons ratio  \
# H              NaN         6.27        14.01 K             NaN
# Li             535      1161.31       453.69 K             NaN
# Be            1848         1182         1560 K           0.032
# B             2460         1851         2349 K             NaN
# C             2267          500         3800 K             NaN
# ..              ...          ...           ...             ...
# Pb           11340      1421.39       600.61 K           0.440
# Bi            9780       1292.6        544.4 K           0.330
# Ac           10070         2250         1323 K             NaN
# Th           11724         2978         2115 K           0.270
# U            19050       2794.7       1405.3 K           0.230
#
#     Thermal conductivity  Van der waals radius Velocity of sound  \
# H                 0.1805                  1.10             1270
# Li               85.0000                  1.82             6000
# Be              190.0000                  1.53            13000
# B                27.0000                  1.92            16200
# C               140.0000                  1.70            18350
# ..                   ...                   ...               ...
# Pb               35.0000                  2.02             1260
# Bi                8.0000                  2.07             1790
# Ac               12.0000                  2.47              NaN
# Th               54.0000                  2.45             2490
# U                27.0000                  2.41             3155
#
#    Vickers hardness     X Youngs modulus Metallic radius  \
# H              NaN   2.20           NaN          no data
# Li             NaN   0.98           4.9             1.52
# Be            1670   1.57           287             1.12
# B            49000   2.04           NaN          no data
# C              NaN   2.55           NaN          no data
# ..              ...   ...            ...             ...
# Pb             NaN   2.33            16             1.75
# Bi             NaN   2.02            32             1.82
# Ac             NaN   1.10           NaN            1.878
# Th             350   1.30            79            1.798
# U             1960   1.38           208            1.542
#
#                                   Ionization energies  Electron affinity
# H                                   [13.598434599702]           0.754598
# Li             [5.391714996, 75.640097, 122.45435914]           0.618049
# Be      [9.322699, 18.21115, 153.896205, 217.7185861]          -0.520000
# B   [8.298019, 25.15483, 37.93059, 259.3715, 340.2...           0.279723
# C   [11.260288, 24.383154, 47.88778, 64.49352, 392...           1.262114
# ..                                                ...                ...
# Pb  [7.4166799, 15.032499, 31.9373, 42.33256, 68.8...           0.356721
# Bi  [7.285516, 16.703, 25.57075, 45.37, 54.856, 88...           0.942362
# Ac  [5.380226, 11.75, 17.431, 44.8, 55.0, 67.0, 79...           0.350000
# Th  [6.3067, 12.1, 18.32, 28.648, 58.0, 69.1, 82.0...           1.170000
# U   [6.19405, 11.6, 19.8, 36.7, 46.0, 62.0, 89.0, ...           0.530000
#
# [80 rows x 21 columns]

# %%
cprops_df['Melting point'] = cprops_df['Melting point'].str.replace("K", "")
cprops_df['Melting point'] = cprops_df['Melting point'].str.replace("white P", "")
cprops_df['Melting point'] = cprops_df['Melting point'].str.replace(r"\(.*\)","",  regex=True).astype(float)
#cprops_df['Melting point'] = [float(a.replace('K', '', 1)) for a in cprops_df['Melting point']]

# %%
cprops_df
# Out:
#     Atomic mass  Atomic no  Atomic radius Atomic radius calculated  \
# H      1.007940          1           0.25                     0.53
# Li     6.941000          3           1.45                     1.67
# Be     9.012182          4           1.05                     1.12
# B     10.811000          5           0.85                     0.87
# C     12.010700          6           0.70                     0.67
# ..          ...        ...            ...                      ...
# Pb   207.200000         82           1.80                     1.54
# Bi   208.980400         83           1.60                     1.43
# Ac   227.000000         89           1.95                  no data
# Th   232.038060         90           1.80                  no data
# U    238.028910         92           1.75                  no data
#
#    Boiling point  Bulk modulus Common oxidation states Critical temperature  \
# H         20.28            NaN                 [-1, 1]                  33
# Li         1615           11.0                     [1]                3223
# Be         2742          130.0                     [2]             no data
# B          4200          320.0                     [3]             no data
# C          4300           33.0                 [-4, 4]             no data
# ..           ...           ...                     ...                  ...
# Pb         2022           46.0                  [2, 4]             no data
# Bi         1837           31.0                     [3]             no data
# Ac         3573            NaN                     [3]             no data
# Th         5093           54.0                     [4]             no data
# U          4200          100.0                     [6]             no data
#
#    Density of solid Liquid range  Melting point  Poissons ratio  \
# H              NaN         6.27           14.01             NaN
# Li             535      1161.31          453.69             NaN
# Be            1848         1182         1560.00           0.032
# B             2460         1851         2349.00             NaN
# C             2267          500         3800.00             NaN
# ..              ...          ...            ...             ...
# Pb           11340      1421.39          600.61           0.440
# Bi            9780       1292.6          544.40           0.330
# Ac           10070         2250         1323.00             NaN
# Th           11724         2978         2115.00           0.270
# U            19050       2794.7         1405.30           0.230
#
#     Thermal conductivity  Van der waals radius Velocity of sound  \
# H                 0.1805                  1.10             1270
# Li               85.0000                  1.82             6000
# Be              190.0000                  1.53            13000
# B                27.0000                  1.92            16200
# C               140.0000                  1.70            18350
# ..                   ...                   ...               ...
# Pb               35.0000                  2.02             1260
# Bi                8.0000                  2.07             1790
# Ac               12.0000                  2.47              NaN
# Th               54.0000                  2.45             2490
# U                27.0000                  2.41             3155
#
#    Vickers hardness     X Youngs modulus Metallic radius  \
# H              NaN   2.20           NaN          no data
# Li             NaN   0.98           4.9             1.52
# Be            1670   1.57           287             1.12
# B            49000   2.04           NaN          no data
# C              NaN   2.55           NaN          no data
# ..              ...   ...            ...             ...
# Pb             NaN   2.33            16             1.75
# Bi             NaN   2.02            32             1.82
# Ac             NaN   1.10           NaN            1.878
# Th             350   1.30            79            1.798
# U             1960   1.38           208            1.542
#
#                                   Ionization energies  Electron affinity
# H                                   [13.598434599702]           0.754598
# Li             [5.391714996, 75.640097, 122.45435914]           0.618049
# Be      [9.322699, 18.21115, 153.896205, 217.7185861]          -0.520000
# B   [8.298019, 25.15483, 37.93059, 259.3715, 340.2...           0.279723
# C   [11.260288, 24.383154, 47.88778, 64.49352, 392...           1.262114
# ..                                                ...                ...
# Pb  [7.4166799, 15.032499, 31.9373, 42.33256, 68.8...           0.356721
# Bi  [7.285516, 16.703, 25.57075, 45.37, 54.856, 88...           0.942362
# Ac  [5.380226, 11.75, 17.431, 44.8, 55.0, 67.0, 79...           0.350000
# Th  [6.3067, 12.1, 18.32, 28.648, 58.0, 69.1, 82.0...           1.170000
# U   [6.19405, 11.6, 19.8, 36.7, 46.0, 62.0, 89.0, ...           0.530000
#
# [80 rows x 21 columns]

# %%
cprops_df['Metallic radius'] = cprops_df['Metallic radius'].astype(str)
cprops_df['Metallic radius'] = [(a.replace('no data', 'NaN', 1)) for a in cprops_df['Metallic radius']]
cprops_df['Metallic radius'] = cprops_df['Metallic radius'].astype(float)
cprops_df
# Out:
#     Atomic mass  Atomic no  Atomic radius Atomic radius calculated  \
# H      1.007940          1           0.25                     0.53
# Li     6.941000          3           1.45                     1.67
# Be     9.012182          4           1.05                     1.12
# B     10.811000          5           0.85                     0.87
# C     12.010700          6           0.70                     0.67
# ..          ...        ...            ...                      ...
# Pb   207.200000         82           1.80                     1.54
# Bi   208.980400         83           1.60                     1.43
# Ac   227.000000         89           1.95                  no data
# Th   232.038060         90           1.80                  no data
# U    238.028910         92           1.75                  no data
#
#    Boiling point  Bulk modulus Common oxidation states Critical temperature  \
# H         20.28            NaN                 [-1, 1]                  33
# Li         1615           11.0                     [1]                3223
# Be         2742          130.0                     [2]             no data
# B          4200          320.0                     [3]             no data
# C          4300           33.0                 [-4, 4]             no data
# ..           ...           ...                     ...                  ...
# Pb         2022           46.0                  [2, 4]             no data
# Bi         1837           31.0                     [3]             no data
# Ac         3573            NaN                     [3]             no data
# Th         5093           54.0                     [4]             no data
# U          4200          100.0                     [6]             no data
#
#    Density of solid Liquid range  Melting point  Poissons ratio  \
# H              NaN         6.27           14.01             NaN
# Li             535      1161.31          453.69             NaN
# Be            1848         1182         1560.00           0.032
# B             2460         1851         2349.00             NaN
# C             2267          500         3800.00             NaN
# ..              ...          ...            ...             ...
# Pb           11340      1421.39          600.61           0.440
# Bi            9780       1292.6          544.40           0.330
# Ac           10070         2250         1323.00             NaN
# Th           11724         2978         2115.00           0.270
# U            19050       2794.7         1405.30           0.230
#
#     Thermal conductivity  Van der waals radius Velocity of sound  \
# H                 0.1805                  1.10             1270
# Li               85.0000                  1.82             6000
# Be              190.0000                  1.53            13000
# B                27.0000                  1.92            16200
# C               140.0000                  1.70            18350
# ..                   ...                   ...               ...
# Pb               35.0000                  2.02             1260
# Bi                8.0000                  2.07             1790
# Ac               12.0000                  2.47              NaN
# Th               54.0000                  2.45             2490
# U                27.0000                  2.41             3155
#
#    Vickers hardness     X Youngs modulus  Metallic radius  \
# H              NaN   2.20           NaN               NaN
# Li             NaN   0.98           4.9             1.520
# Be            1670   1.57           287             1.120
# B            49000   2.04           NaN               NaN
# C              NaN   2.55           NaN               NaN
# ..              ...   ...            ...              ...
# Pb             NaN   2.33            16             1.750
# Bi             NaN   2.02            32             1.820
# Ac             NaN   1.10           NaN             1.878
# Th             350   1.30            79             1.798
# U             1960   1.38           208             1.542
#
#                                   Ionization energies  Electron affinity
# H                                   [13.598434599702]           0.754598
# Li             [5.391714996, 75.640097, 122.45435914]           0.618049
# Be      [9.322699, 18.21115, 153.896205, 217.7185861]          -0.520000
# B   [8.298019, 25.15483, 37.93059, 259.3715, 340.2...           0.279723
# C   [11.260288, 24.383154, 47.88778, 64.49352, 392...           1.262114
# ..                                                ...                ...
# Pb  [7.4166799, 15.032499, 31.9373, 42.33256, 68.8...           0.356721
# Bi  [7.285516, 16.703, 25.57075, 45.37, 54.856, 88...           0.942362
# Ac  [5.380226, 11.75, 17.431, 44.8, 55.0, 67.0, 79...           0.350000
# Th  [6.3067, 12.1, 18.32, 28.648, 58.0, 69.1, 82.0...           1.170000
# U   [6.19405, 11.6, 19.8, 36.7, 46.0, 62.0, 89.0, ...           0.530000
#
# [80 rows x 21 columns]

# %%
type(cprops_df['Metallic radius'][1])
# Out:
# numpy.float64

# %%
cprops_df['Common oxidation states'] = [len(a) for a in cprops_df['Common oxidation states']]
cprops_df['Common oxidation states'] 

#executivejojodecision 841 11:30
# Out:
# H     2
# Li    1
# Be    1
# B     1
# C     2
#      ..
# Pb    2
# Bi    1
# Ac    1
# Th    1
# U     1
# Name: Common oxidation states, Length: 80, dtype: int64

# %%
cprops_df
# Out:
#     Atomic mass  Atomic no  Atomic radius Atomic radius calculated  \
# H      1.007940          1           0.25                     0.53
# Li     6.941000          3           1.45                     1.67
# Be     9.012182          4           1.05                     1.12
# B     10.811000          5           0.85                     0.87
# C     12.010700          6           0.70                     0.67
# ..          ...        ...            ...                      ...
# Pb   207.200000         82           1.80                     1.54
# Bi   208.980400         83           1.60                     1.43
# Ac   227.000000         89           1.95                  no data
# Th   232.038060         90           1.80                  no data
# U    238.028910         92           1.75                  no data
#
#    Boiling point  Bulk modulus  Common oxidation states Critical temperature  \
# H         20.28            NaN                        2                  33
# Li         1615           11.0                        1                3223
# Be         2742          130.0                        1             no data
# B          4200          320.0                        1             no data
# C          4300           33.0                        2             no data
# ..           ...           ...                      ...                  ...
# Pb         2022           46.0                        2             no data
# Bi         1837           31.0                        1             no data
# Ac         3573            NaN                        1             no data
# Th         5093           54.0                        1             no data
# U          4200          100.0                        1             no data
#
#    Density of solid Liquid range  Melting point  Poissons ratio  \
# H              NaN         6.27           14.01             NaN
# Li             535      1161.31          453.69             NaN
# Be            1848         1182         1560.00           0.032
# B             2460         1851         2349.00             NaN
# C             2267          500         3800.00             NaN
# ..              ...          ...            ...             ...
# Pb           11340      1421.39          600.61           0.440
# Bi            9780       1292.6          544.40           0.330
# Ac           10070         2250         1323.00             NaN
# Th           11724         2978         2115.00           0.270
# U            19050       2794.7         1405.30           0.230
#
#     Thermal conductivity  Van der waals radius Velocity of sound  \
# H                 0.1805                  1.10             1270
# Li               85.0000                  1.82             6000
# Be              190.0000                  1.53            13000
# B                27.0000                  1.92            16200
# C               140.0000                  1.70            18350
# ..                   ...                   ...               ...
# Pb               35.0000                  2.02             1260
# Bi                8.0000                  2.07             1790
# Ac               12.0000                  2.47              NaN
# Th               54.0000                  2.45             2490
# U                27.0000                  2.41             3155
#
#    Vickers hardness     X Youngs modulus  Metallic radius  \
# H              NaN   2.20           NaN               NaN
# Li             NaN   0.98           4.9             1.520
# Be            1670   1.57           287             1.120
# B            49000   2.04           NaN               NaN
# C              NaN   2.55           NaN               NaN
# ..              ...   ...            ...              ...
# Pb             NaN   2.33            16             1.750
# Bi             NaN   2.02            32             1.820
# Ac             NaN   1.10           NaN             1.878
# Th             350   1.30            79             1.798
# U             1960   1.38           208             1.542
#
#                                   Ionization energies  Electron affinity
# H                                   [13.598434599702]           0.754598
# Li             [5.391714996, 75.640097, 122.45435914]           0.618049
# Be      [9.322699, 18.21115, 153.896205, 217.7185861]          -0.520000
# B   [8.298019, 25.15483, 37.93059, 259.3715, 340.2...           0.279723
# C   [11.260288, 24.383154, 47.88778, 64.49352, 392...           1.262114
# ..                                                ...                ...
# Pb  [7.4166799, 15.032499, 31.9373, 42.33256, 68.8...           0.356721
# Bi  [7.285516, 16.703, 25.57075, 45.37, 54.856, 88...           0.942362
# Ac  [5.380226, 11.75, 17.431, 44.8, 55.0, 67.0, 79...           0.350000
# Th  [6.3067, 12.1, 18.32, 28.648, 58.0, 69.1, 82.0...           1.170000
# U   [6.19405, 11.6, 19.8, 36.7, 46.0, 62.0, 89.0, ...           0.530000
#
# [80 rows x 21 columns]

# %%
#cprops_df['First Ionization Energy'] = [a[0] for a in cprops_df['Ionization energies']]

# %%
cprops_df
# Out:
#     Atomic mass  Atomic no  Atomic radius Atomic radius calculated  \
# H      1.007940          1           0.25                     0.53
# Li     6.941000          3           1.45                     1.67
# Be     9.012182          4           1.05                     1.12
# B     10.811000          5           0.85                     0.87
# C     12.010700          6           0.70                     0.67
# ..          ...        ...            ...                      ...
# Pb   207.200000         82           1.80                     1.54
# Bi   208.980400         83           1.60                     1.43
# Ac   227.000000         89           1.95                  no data
# Th   232.038060         90           1.80                  no data
# U    238.028910         92           1.75                  no data
#
#    Boiling point  Bulk modulus  Common oxidation states Critical temperature  \
# H         20.28            NaN                        2                  33
# Li         1615           11.0                        1                3223
# Be         2742          130.0                        1             no data
# B          4200          320.0                        1             no data
# C          4300           33.0                        2             no data
# ..           ...           ...                      ...                  ...
# Pb         2022           46.0                        2             no data
# Bi         1837           31.0                        1             no data
# Ac         3573            NaN                        1             no data
# Th         5093           54.0                        1             no data
# U          4200          100.0                        1             no data
#
#    Density of solid Liquid range  Melting point  Poissons ratio  \
# H              NaN         6.27           14.01             NaN
# Li             535      1161.31          453.69             NaN
# Be            1848         1182         1560.00           0.032
# B             2460         1851         2349.00             NaN
# C             2267          500         3800.00             NaN
# ..              ...          ...            ...             ...
# Pb           11340      1421.39          600.61           0.440
# Bi            9780       1292.6          544.40           0.330
# Ac           10070         2250         1323.00             NaN
# Th           11724         2978         2115.00           0.270
# U            19050       2794.7         1405.30           0.230
#
#     Thermal conductivity  Van der waals radius Velocity of sound  \
# H                 0.1805                  1.10             1270
# Li               85.0000                  1.82             6000
# Be              190.0000                  1.53            13000
# B                27.0000                  1.92            16200
# C               140.0000                  1.70            18350
# ..                   ...                   ...               ...
# Pb               35.0000                  2.02             1260
# Bi                8.0000                  2.07             1790
# Ac               12.0000                  2.47              NaN
# Th               54.0000                  2.45             2490
# U                27.0000                  2.41             3155
#
#    Vickers hardness     X Youngs modulus  Metallic radius  \
# H              NaN   2.20           NaN               NaN
# Li             NaN   0.98           4.9             1.520
# Be            1670   1.57           287             1.120
# B            49000   2.04           NaN               NaN
# C              NaN   2.55           NaN               NaN
# ..              ...   ...            ...              ...
# Pb             NaN   2.33            16             1.750
# Bi             NaN   2.02            32             1.820
# Ac             NaN   1.10           NaN             1.878
# Th             350   1.30            79             1.798
# U             1960   1.38           208             1.542
#
#                                   Ionization energies  Electron affinity
# H                                   [13.598434599702]           0.754598
# Li             [5.391714996, 75.640097, 122.45435914]           0.618049
# Be      [9.322699, 18.21115, 153.896205, 217.7185861]          -0.520000
# B   [8.298019, 25.15483, 37.93059, 259.3715, 340.2...           0.279723
# C   [11.260288, 24.383154, 47.88778, 64.49352, 392...           1.262114
# ..                                                ...                ...
# Pb  [7.4166799, 15.032499, 31.9373, 42.33256, 68.8...           0.356721
# Bi  [7.285516, 16.703, 25.57075, 45.37, 54.856, 88...           0.942362
# Ac  [5.380226, 11.75, 17.431, 44.8, 55.0, 67.0, 79...           0.350000
# Th  [6.3067, 12.1, 18.32, 28.648, 58.0, 69.1, 82.0...           1.170000
# U   [6.19405, 11.6, 19.8, 36.7, 46.0, 62.0, 89.0, ...           0.530000
#
# [80 rows x 21 columns]

# %%
cprops_df = cprops_df.drop("Ionization energies", axis=1)

# %%
cprops_df
# Out:
#     Atomic mass  Atomic no  Atomic radius Atomic radius calculated  \
# H      1.007940          1           0.25                     0.53
# Li     6.941000          3           1.45                     1.67
# Be     9.012182          4           1.05                     1.12
# B     10.811000          5           0.85                     0.87
# C     12.010700          6           0.70                     0.67
# ..          ...        ...            ...                      ...
# Pb   207.200000         82           1.80                     1.54
# Bi   208.980400         83           1.60                     1.43
# Ac   227.000000         89           1.95                  no data
# Th   232.038060         90           1.80                  no data
# U    238.028910         92           1.75                  no data
#
#    Boiling point  Bulk modulus  Common oxidation states Critical temperature  \
# H         20.28            NaN                        2                  33
# Li         1615           11.0                        1                3223
# Be         2742          130.0                        1             no data
# B          4200          320.0                        1             no data
# C          4300           33.0                        2             no data
# ..           ...           ...                      ...                  ...
# Pb         2022           46.0                        2             no data
# Bi         1837           31.0                        1             no data
# Ac         3573            NaN                        1             no data
# Th         5093           54.0                        1             no data
# U          4200          100.0                        1             no data
#
#    Density of solid Liquid range  Melting point  Poissons ratio  \
# H              NaN         6.27           14.01             NaN
# Li             535      1161.31          453.69             NaN
# Be            1848         1182         1560.00           0.032
# B             2460         1851         2349.00             NaN
# C             2267          500         3800.00             NaN
# ..              ...          ...            ...             ...
# Pb           11340      1421.39          600.61           0.440
# Bi            9780       1292.6          544.40           0.330
# Ac           10070         2250         1323.00             NaN
# Th           11724         2978         2115.00           0.270
# U            19050       2794.7         1405.30           0.230
#
#     Thermal conductivity  Van der waals radius Velocity of sound  \
# H                 0.1805                  1.10             1270
# Li               85.0000                  1.82             6000
# Be              190.0000                  1.53            13000
# B                27.0000                  1.92            16200
# C               140.0000                  1.70            18350
# ..                   ...                   ...               ...
# Pb               35.0000                  2.02             1260
# Bi                8.0000                  2.07             1790
# Ac               12.0000                  2.47              NaN
# Th               54.0000                  2.45             2490
# U                27.0000                  2.41             3155
#
#    Vickers hardness     X Youngs modulus  Metallic radius  Electron affinity
# H              NaN   2.20           NaN               NaN           0.754598
# Li             NaN   0.98           4.9             1.520           0.618049
# Be            1670   1.57           287             1.120          -0.520000
# B            49000   2.04           NaN               NaN           0.279723
# C              NaN   2.55           NaN               NaN           1.262114
# ..              ...   ...            ...              ...                ...
# Pb             NaN   2.33            16             1.750           0.356721
# Bi             NaN   2.02            32             1.820           0.942362
# Ac             NaN   1.10           NaN             1.878           0.350000
# Th             350   1.30            79             1.798           1.170000
# U             1960   1.38           208             1.542           0.530000
#
# [80 rows x 20 columns]

# %%
#cprops_df['Critical temperature'] = [(a.replace('no data', 'NaN', 1)) for a in cprops_df['Critical temperature']]
cprops_df
# Out:
#     Atomic mass  Atomic no  Atomic radius Atomic radius calculated  \
# H      1.007940          1           0.25                     0.53
# Li     6.941000          3           1.45                     1.67
# Be     9.012182          4           1.05                     1.12
# B     10.811000          5           0.85                     0.87
# C     12.010700          6           0.70                     0.67
# ..          ...        ...            ...                      ...
# Pb   207.200000         82           1.80                     1.54
# Bi   208.980400         83           1.60                     1.43
# Ac   227.000000         89           1.95                  no data
# Th   232.038060         90           1.80                  no data
# U    238.028910         92           1.75                  no data
#
#    Boiling point  Bulk modulus  Common oxidation states Critical temperature  \
# H         20.28            NaN                        2                  33
# Li         1615           11.0                        1                3223
# Be         2742          130.0                        1             no data
# B          4200          320.0                        1             no data
# C          4300           33.0                        2             no data
# ..           ...           ...                      ...                  ...
# Pb         2022           46.0                        2             no data
# Bi         1837           31.0                        1             no data
# Ac         3573            NaN                        1             no data
# Th         5093           54.0                        1             no data
# U          4200          100.0                        1             no data
#
#    Density of solid Liquid range  Melting point  Poissons ratio  \
# H              NaN         6.27           14.01             NaN
# Li             535      1161.31          453.69             NaN
# Be            1848         1182         1560.00           0.032
# B             2460         1851         2349.00             NaN
# C             2267          500         3800.00             NaN
# ..              ...          ...            ...             ...
# Pb           11340      1421.39          600.61           0.440
# Bi            9780       1292.6          544.40           0.330
# Ac           10070         2250         1323.00             NaN
# Th           11724         2978         2115.00           0.270
# U            19050       2794.7         1405.30           0.230
#
#     Thermal conductivity  Van der waals radius Velocity of sound  \
# H                 0.1805                  1.10             1270
# Li               85.0000                  1.82             6000
# Be              190.0000                  1.53            13000
# B                27.0000                  1.92            16200
# C               140.0000                  1.70            18350
# ..                   ...                   ...               ...
# Pb               35.0000                  2.02             1260
# Bi                8.0000                  2.07             1790
# Ac               12.0000                  2.47              NaN
# Th               54.0000                  2.45             2490
# U                27.0000                  2.41             3155
#
#    Vickers hardness     X Youngs modulus  Metallic radius  Electron affinity
# H              NaN   2.20           NaN               NaN           0.754598
# Li             NaN   0.98           4.9             1.520           0.618049
# Be            1670   1.57           287             1.120          -0.520000
# B            49000   2.04           NaN               NaN           0.279723
# C              NaN   2.55           NaN               NaN           1.262114
# ..              ...   ...            ...              ...                ...
# Pb             NaN   2.33            16             1.750           0.356721
# Bi             NaN   2.02            32             1.820           0.942362
# Ac             NaN   1.10           NaN             1.878           0.350000
# Th             350   1.30            79             1.798           1.170000
# U             1960   1.38           208             1.542           0.530000
#
# [80 rows x 20 columns]

# %%
# OG_names = ['AtomicRadius', 'AtomicVolume', 'AtomicWeight', 'BulkModulus',
#        'BoilingT', 'Column', 'CovalentRadius', 'Density', 'ElectronAffinity',
#        'Electronegativity', 'FirstIonizationEnergy', 'HeatCapacityMass', 'Row',
#        'phi', 'SecondIonizationEnergy', 'ShearModulus', 'Superconduction temperature', 'Velocity of sound']

# %%
cprops_df.dtypes
# Out:
# Atomic mass                 float64
# Atomic no                     int64
# Atomic radius               float64
# Atomic radius calculated     object
# Boiling point                object
# Bulk modulus                float64
# Common oxidation states       int64
# Critical temperature         object
# Density of solid             object
# Liquid range                 object
# Melting point               float64
# Poissons ratio              float64
# Thermal conductivity        float64
# Van der waals radius        float64
# Velocity of sound            object
# Vickers hardness             object
# X                           float64
# Youngs modulus               object
# Metallic radius             float64
# Electron affinity           float64
# dtype: object

# %%
cprops_df = cprops_df.apply(pd.to_numeric, errors='coerce')

# %%
cprops_df.dtypes
# Out:
# Atomic mass                 float64
# Atomic no                     int64
# Atomic radius               float64
# Atomic radius calculated    float64
# Boiling point               float64
# Bulk modulus                float64
# Common oxidation states       int64
# Critical temperature        float64
# Density of solid            float64
# Liquid range                float64
# Melting point               float64
# Poissons ratio              float64
# Thermal conductivity        float64
# Van der waals radius        float64
# Velocity of sound           float64
# Vickers hardness            float64
# X                           float64
# Youngs modulus              float64
# Metallic radius             float64
# Electron affinity           float64
# dtype: object

# %%
# Computing mean values using mean function 
mvals = dict(cprops_df.mean())
mvals
# Out:
# {'Atomic mass': 107.06698397475,
#  'Atomic no': 44.7,
#  'Atomic radius': 1.48,
#  'Atomic radius calculated': 1.6537837837837837,
#  'Boiling point': 2696.401625,
#  'Bulk modulus': 91.64411764705883,
#  'Common oxidation states': 1.6625,
#  'Critical temperature': 1285.5176470588235,
#  'Density of solid': 8067.890410958904,
#  'Liquid range': 1317.882875,
#  'Melting point': 1383.99375,
#  'Poissons ratio': 0.2942692307692308,
#  'Thermal conductivity': 66.76124387499999,
#  'Van der waals radius': 2.1265,
#  'Velocity of sound': 3723.0015151515154,
#  'Vickers hardness': 2108.3076923076924,
#  'X': 1.7591250000000003,
#  'Youngs modulus': 111.78688524590164,
#  'Metallic radius': 1.6225909090909092,
#  'Electron affinity': 0.7264296744125001}

# %%
# Iterating through variable with averages to replace the NaN values in element_data
for key, value in mvals.items():
    cprops_df.loc[cprops_df[key].isnull(),key] = value

display(cprops_df)
# Out:
#     Atomic mass  Atomic no  Atomic radius  Atomic radius calculated  \
# H      1.007940        1.0           0.25                  0.530000
# Li     6.941000        3.0           1.45                  1.670000
# Be     9.012182        4.0           1.05                  1.120000
# B     10.811000        5.0           0.85                  0.870000
# C     12.010700        6.0           0.70                  0.670000
# ..          ...        ...            ...                       ...
# Pb   207.200000       82.0           1.80                  1.540000
# Bi   208.980400       83.0           1.60                  1.430000
# Ac   227.000000       89.0           1.95                  1.653784
# Th   232.038060       90.0           1.80                  1.653784
# U    238.028910       92.0           1.75                  1.653784
#
#     Boiling point  Bulk modulus  Common oxidation states  \
# H           20.28     91.644118                      2.0
# Li        1615.00     11.000000                      1.0
# Be        2742.00    130.000000                      1.0
# B         4200.00    320.000000                      1.0
# C         4300.00     33.000000                      2.0
# ..            ...           ...                      ...
# Pb        2022.00     46.000000                      2.0
# Bi        1837.00     31.000000                      1.0
# Ac        3573.00     91.644118                      1.0
# Th        5093.00     54.000000                      1.0
# U         4200.00    100.000000                      1.0
#
#     Critical temperature  Density of solid  Liquid range  Melting point  \
# H              33.000000       8067.890411          6.27          14.01
# Li           3223.000000        535.000000       1161.31         453.69
# Be           1285.517647       1848.000000       1182.00        1560.00
# B            1285.517647       2460.000000       1851.00        2349.00
# C            1285.517647       2267.000000        500.00        3800.00
# ..                   ...               ...           ...            ...
# Pb           1285.517647      11340.000000       1421.39         600.61
# Bi           1285.517647       9780.000000       1292.60         544.40
# Ac           1285.517647      10070.000000       2250.00        1323.00
# Th           1285.517647      11724.000000       2978.00        2115.00
# U            1285.517647      19050.000000       2794.70        1405.30
#
#     Poissons ratio  Thermal conductivity  Van der waals radius  \
# H         0.294269                0.1805                  1.10
# Li        0.294269               85.0000                  1.82
# Be        0.032000              190.0000                  1.53
# B         0.294269               27.0000                  1.92
# C         0.294269              140.0000                  1.70
# ..             ...                   ...                   ...
# Pb        0.440000               35.0000                  2.02
# Bi        0.330000                8.0000                  2.07
# Ac        0.294269               12.0000                  2.47
# Th        0.270000               54.0000                  2.45
# U         0.230000               27.0000                  2.41
#
#     Velocity of sound  Vickers hardness     X  Youngs modulus  \
# H         1270.000000       2108.307692  2.20      111.786885
# Li        6000.000000       2108.307692  0.98        4.900000
# Be       13000.000000       1670.000000  1.57      287.000000
# B        16200.000000      49000.000000  2.04      111.786885
# C        18350.000000       2108.307692  2.55      111.786885
# ..                ...               ...   ...             ...
# Pb        1260.000000       2108.307692  2.33       16.000000
# Bi        1790.000000       2108.307692  2.02       32.000000
# Ac        3723.001515       2108.307692  1.10      111.786885
# Th        2490.000000        350.000000  1.30       79.000000
# U         3155.000000       1960.000000  1.38      208.000000
#
#     Metallic radius  Electron affinity
# H          1.622591           0.754598
# Li         1.520000           0.618049
# Be         1.120000          -0.520000
# B          1.622591           0.279723
# C          1.622591           1.262114
# ..              ...                ...
# Pb         1.750000           0.356721
# Bi         1.820000           0.942362
# Ac         1.878000           0.350000
# Th         1.798000           1.170000
# U          1.542000           0.530000
#
# [80 rows x 20 columns]

# %%
# # Initializing variables
# Kp3_2 = list(filt_data["pretty_formula"])
# CFp3_2 = []
# task_id = filt_data["material_id"]

# properties = list(cprops_df.columns)
# compound_names  =  list(filt_data["pretty_formula"])
# average_dict = {}
# max_dict = {}
# min_dict = {}

# # Implementing same method as question 4 to compute max, min, and averages for all properties in data
# for elms in range(len(Kp3_2)): 
#     #Kp3_2 = filt_data["pretty_formula"]
#     #task = task_id[elms]
#     Kp3_2 = filt_data["pretty_formula"]
#     comp_eli_2 = Composition(CFp3_2)
#     CEl_2 = comp_eli_2.elements
#     q2dict = comp_eli_2.to_data_dict['unit_cell_composition']
#     row_avgs = {}
#     row_max = {}
#     row_min = {}
    
#     for col in properties:
#       overall = 0
#       allval = []
#       for key, value in q2dict.items():
#         property_ = cprops_df.loc[key, col]
#         overall += property_ * value
#         allval.append(property_)
#       num_total = sum(q2dict.values())
#       avg = overall/num_total
#       row_avgs[col + '_avg'] = avg
#       row_max[col + '_max'] = max(allval)
#       row_min[col + '_min'] = min(allval)
#     average_dict[task] = row_avgs
#     max_dict[task] = row_max
#     min_dict[task] = row_min

# %%
#jojoversion

# %%
filt_data_comp = filt_data
filt_data_comp['Composition'] = [Composition(c) for c in filt_data_comp["pretty_formula"]]
filt_data_comp['num_atoms'] = [c.num_atoms for c in filt_data_comp['Composition']]
filt_data_comp['volume_per_atom'] = filt_data_comp['volume']/filt_data_comp['num_atoms']
filt_data_comp
#filt_data
# Out:
#      material_id      energy  energy_per_atom      volume  \
# 0     mp-1001034  -52.019078        -3.715648  376.145863
# 1     mp-1001780  -22.364406        -5.591101   78.515319
# 2     mp-1001786  -23.600913        -5.900228   71.701237
# 3     mp-1002124  -19.780759        -9.890380   32.055765
# 4     mp-1004528  -95.454964        -5.614998  324.979430
# ...          ...         ...              ...         ...
# 5614    mvc-6916  -99.385289        -7.098949  156.686110
# 5615    mvc-6928  -91.603914        -6.543137  173.941832
# 5616    mvc-6946  -36.735653        -6.122609   97.529160
# 5617    mvc-7040 -145.212422        -8.067357  418.920727
# 5618    mvc-7383 -124.502927        -6.225146  317.655229
#
#       formation_energy_per_atom  nsites pretty_formula  nelements   density  \
# 0                     -0.703661      14     Mg(InSe2)2          3  5.030727
# 1                     -1.699567       4         LuCuS2          3  6.400668
# 2                     -2.103385       4         LiScS2          3  2.687084
# 3                     -0.298402       2            HfC          2  9.868236
# 4                     -3.162482      17      CsB3PbF12          4  3.068458
# ...                         ...     ...            ...        ...       ...
# 5614                  -2.307339      14        MgMn2O4          3  4.200544
# 5615                  -2.192463      14      Ca(FeO2)2          3  4.119621
# 5616                  -1.961400       6           SnO2          2  5.131960
# 5617                  -1.999722      18          Re2O7          2  3.840256
# 5618                  -1.597210      20        ZnCr2O7          3  2.941999
#
#       band_gap     Composition  num_atoms  volume_per_atom
# 0       0.7432    (Mg, In, Se)        7.0        53.735123
# 1       1.5031     (Lu, Cu, S)        4.0        19.628830
# 2       1.5296     (Li, Sc, S)        4.0        17.925309
# 3       0.5774         (Hf, C)        2.0        16.027883
# 4       6.3125  (Cs, B, Pb, F)       17.0        19.116437
# ...        ...             ...        ...              ...
# 5614    0.0516     (Mg, Mn, O)        7.0        22.383730
# 5615    1.7463     (Ca, Fe, O)        7.0        24.848833
# 5616    2.1009         (Sn, O)        3.0        32.509720
# 5617    3.4689         (Re, O)        9.0        46.546747
# 5618    2.4238     (Zn, Cr, O)       10.0        31.765523
#
# [5614 rows x 13 columns]

# %%
filt_data_comp['Composition'][0].num_atoms
# Out:
# 7.0

# %%
cprops_df_dict = cprops_df.to_dict()

rad_dict = cprops_df_dict['Atomic radius']

def radius_mean(composition):
    sumofradii = 0
    totnumatoms = 0
    for element, number in composition.items():
        sumofradii += (number*rad_dict[str(element)])
        totnumatoms += number
    return sumofradii/totnumatoms

atomic_radius = filt_data_comp['Composition'].apply(radius_mean)
atomic_radius
# Out:
# 0       1.314286
# 1       1.275000
# 2       1.262500
# 3       1.125000
# 4       0.761765
#           ...
# 5614    0.957143
# 5615    1.000000
# 5616    0.883333
# 5617    0.766667
# 5618    0.835000
# Name: Composition, Length: 5614, dtype: float64

# %%
#jojo version

def propertymean(property, composition):
    sumofproperty = 0
    totalnumatoms = 0
    for element, number in composition.items():
        sumofproperty += (number*cprops_df_dict[property][str(element)])
        totalnumatoms += number
    return sumofproperty/totalnumatoms

def maxofproperty(property, composition):
    propmax = None
    for element, number in composition.items():
        propertyvalue = cprops_df_dict[property][str(element)]
        if propmax:
            propmax = propertyvalue if propertyvalue > propmax else propmax
        else:
            propmax = propertyvalue
    return propmax

def minofproperty(property, composition):
    propmin = None
    for element, number in composition.items():
        propertyvalue = cprops_df_dict[property][str(element)]
        if propmin:
            propmin = propertyvalue if propertyvalue < propmin else propmin
        else:
            propmin = propertyvalue
    return propmin

# %%
cprops_df
# Out:
#     Atomic mass  Atomic no  Atomic radius  Atomic radius calculated  \
# H      1.007940        1.0           0.25                  0.530000
# Li     6.941000        3.0           1.45                  1.670000
# Be     9.012182        4.0           1.05                  1.120000
# B     10.811000        5.0           0.85                  0.870000
# C     12.010700        6.0           0.70                  0.670000
# N     14.006700        7.0           0.65                  0.560000
# O     15.999400        8.0           0.60                  0.480000
# F     18.998403        9.0           0.50                  0.420000
# Na    22.989769       11.0           1.80                  1.900000
# Mg    24.305000       12.0           1.50                  1.450000
# Al    26.981539       13.0           1.25                  1.180000
# Si    28.085500       14.0           1.10                  1.110000
# P     30.973762       15.0           1.00                  0.980000
# S     32.065000       16.0           1.00                  0.880000
# Cl    35.453000       17.0           1.00                  0.790000
# K     39.098300       19.0           2.20                  2.430000
# Ca    40.078000       20.0           1.80                  1.940000
# Sc    44.955912       21.0           1.60                  1.840000
# Ti    47.867000       22.0           1.40                  1.760000
# V     50.941500       23.0           1.35                  1.710000
# Cr    51.996100       24.0           1.40                  1.660000
# Mn    54.938045       25.0           1.40                  1.610000
# Fe    55.845000       26.0           1.40                  1.560000
# Co    58.933195       27.0           1.35                  1.520000
# Ni    58.693400       28.0           1.35                  1.490000
# Cu    63.546000       29.0           1.35                  1.450000
# Zn    65.409000       30.0           1.35                  1.420000
# Ga    69.723000       31.0           1.30                  1.360000
# Ge    72.640000       32.0           1.25                  1.250000
# As    74.921600       33.0           1.15                  1.140000
# Se    78.960000       34.0           1.15                  1.030000
# Ba        1620.000000       2108.307692  0.89       13.000000
# La        2475.000000        491.000000  1.10       37.000000
# Ce        2100.000000        270.000000  1.12       34.000000
# Pr        2280.000000        400.000000  1.13       37.000000
# Nd        2330.000000        343.000000  1.14       41.000000
# Sm        2130.000000        412.000000  1.17       50.000000
# Eu        3723.001515        167.000000  1.20       18.000000
# Gd        2680.000000        570.000000  1.20       55.000000
# Tb        2620.000000        863.000000  1.10       56.000000
# Dy        2710.000000        540.000000  1.22       61.000000
# Ho        2760.000000        481.000000  1.23       65.000000
# Er        2830.000000        589.000000  1.24       70.000000
# Tm        3723.001515        520.000000  1.25       74.000000
# Yb        1590.000000        206.000000  1.10       24.000000
# Lu        3723.001515       1160.000000  1.27       69.000000
# Hf        3010.000000       1760.000000  1.30       78.000000
# Ta        3400.000000        873.000000  1.50      186.000000
# W         5174.000000       3430.000000  2.36      411.000000
# Re        4700.000000       2450.000000  1.90      463.000000
# Os        4940.000000       2108.307692  2.20      111.786885
# Ir        4825.000000       1760.000000  2.20      528.000000
# Pt        2680.000000        549.000000  2.28      168.000000
# Au        1740.000000        216.000000  2.54       78.000000
# Hg        1407.000000       2108.307692  2.00      111.786885
# Tl         818.000000       2108.307692  1.62        8.000000
# Pb        1260.000000       2108.307692  2.33       16.000000
# Bi        1790.000000       2108.307692  2.02       32.000000
# Ac        3723.001515       2108.307692  1.10      111.786885
# Th        2490.000000        350.000000  1.30       79.000000
# U         3155.000000       1960.000000  1.38      208.000000
#
#     Metallic radius  Electron affinity
# H          1.622591           0.754598
# Li         1.520000           0.618049
# Be         1.120000          -0.520000
# B          1.622591           0.279723
# C          1.622591           1.262114
# N          1.622591          -0.070000
# O          1.622591           1.461105
# F          1.622591           3.401190
# Na         1.860000           0.547926
# Mg         1.600000          -0.420000
# Al         1.430000           0.432835
# Si         1.622591           1.389521
# P          1.622591           0.746607
# S          1.622591           2.077105
# Cl         1.622591           3.612725
# K          2.381000           0.501459
# Ca         1.976000           0.024551
# Sc         1.641000           0.188200
# Ti         1.462000           0.075545
# V          1.347000           0.527662
# Cr         1.285000           0.675841
# Mn         1.292000          -0.520000
# Fe         1.277000           0.153236
# Co         1.250000           0.662265
# Ni         1.246000           1.157161
# Cu         1.278000           1.235784
# Zn         1.340000          -0.620000
# Ga         1.350000           0.301201
# Ge         1.390000           1.232676
# As         1.622591           0.804820
# Se         1.622591           2.020605
# Br         1.140000           3.363588
# Rb         2.537000           0.485916
# Sr         2.151000           0.052066
# Y          1.800000           0.307120
# Zr         1.602000           0.433289
# Nb         1.473000           0.917407
# Mo         1.402000           0.747330
# Tc         1.363000           0.552000
# Ru         1.339000           1.046382
# Rh         1.345000           1.142892
# Pd         1.376000           0.562141
# Ag         1.445000           1.304473
# Cd         1.510000          -0.720000
# In         1.670000           0.383926
# Sn         1.580000           1.112070
# Sb         1.610000           1.047401
# Te         1.622591           1.970876
# I          1.622591           3.059052
# Cs         2.719000           0.471630
# Ba         2.236000           0.144626
# La         1.877000           0.557546
# Ce         1.707000           0.572000
# Pr         1.828000           0.109235
# Nd         1.821000           0.097493
# Sm         1.804000           0.162000
# Eu         2.041000           0.116130
# Gd         1.802000           0.137000
# Tb         1.781000           0.131318
# Dy         1.773000           0.352000
# Ho         1.765000           0.338000
# Er         1.756000           0.312000
# Tm         1.747000           1.029220
# Yb         1.940000          -0.020000
# Lu         1.735000           0.238870
# Hf         1.580000           0.178070
# Ta         1.470000           0.323120
# W          1.410000           0.816268
# Re         1.375000           0.060397
# Os         1.352000           1.077801
# Ir         1.357000           1.564361
# Pt         1.387000           2.125105
# Au         1.442000           2.308610
# Hg         1.510000          -0.520000
# Tl         1.700000           0.320053
# Pb         1.750000           0.356721
# Bi         1.820000           0.942362
# Ac         1.878000           0.350000
# Th         1.798000           1.170000
# U          1.542000           0.530000

# %%
avg_properties_df = pd.DataFrame()

for property in cprops_df.columns:
    individualpropertymean = partial(propertymean, property)
    averages = filt_data_comp['Composition'].apply(individualpropertymean)
    avg_properties_df[("average_" + property)] = averages
    
avg_properties_df.head()

print("Average properties Dimension: ", avg_properties_df.shape)

max_properties = pd.DataFrame()

for property in cprops_df.columns:
    individualpropertymax = partial(maxofproperty, property)
    max = filt_data_comp['Composition'].apply(individualpropertymax)
    max_properties[("max_" + property)] = max
    
min_properties = pd.DataFrame()

for property in cprops_df.columns:
    individualpropertymin = partial(minofproperty, property)
    min = filt_data_comp['Composition'].apply(individualpropertymin)
    min_properties[("min_" + property)] = min
# Out:
# Average properties Dimension:  (5614, 20)

# %%
avg_properties_df
# Out:
#       average_Atomic mass  average_Atomic no  average_Atomic radius  \
# 0               81.397286          35.142857               1.314286
# 1               75.660750          33.000000               1.275000
# 2               29.006728          14.000000               1.262500
# 3               95.250350          39.000000               1.125000
# 4               35.324664          15.294118               0.761765
# ...                   ...                ...                    ...
# 5614            28.311241          13.428571               0.957143
# 5615            30.823657          14.857143               1.000000
# 5616            50.236267          22.000000               0.883333
# 5617            53.823311          22.888889               0.766667
# 5618            28.139700          13.400000               0.835000
#
#       average_Atomic radius calculated  average_Boiling point  \
# 0                             1.241429            1412.142857
# 1                             1.345000            2077.685000
# 2                             1.317500            1538.435000
# 3                             1.375000            4588.000000
# 4                             0.715882             975.668235
# ...                                ...                    ...
# 5614                          0.941429             913.114286
# 5615                          0.997143            1197.971429
# 5616                          0.803333            1018.466667
# 5617                          0.791111            1374.377778
# 5618                          0.810000             769.940000
#
#       average_Bulk modulus  average_Common oxidation states  \
# 0                37.355462                         2.714286
# 1                50.850000                         2.500000
# 2                20.850000                         2.500000
# 3                71.500000                         1.500000
# 4               123.960554                         1.058824
# ...                    ...                              ...
# 5614             93.082353                         1.571429
# 5615            103.368067                         1.285714
# 5616             80.429412                         1.666667
# 5617            153.500980                         1.000000
# 5618            103.150882                         1.200000
#
#       average_Critical temperature  average_Density of solid  \
# 0                      1560.078992               5090.571429
# 1                      1299.758824               5670.250000
# 2                      1784.129412               1860.000000
# 3                      1285.517647               7788.500000
# 4                       518.121799               6906.687349
# ...                            ...                       ...
# 5614                    639.278992               6992.794521
# 5615                    639.278992               7081.365949
# 5616                    531.572549               7815.260274
# 5617                    405.915033              10946.136986
# 5618                    493.875294               7789.523288
#
#       average_Liquid range  average_Melting point  average_Poissons ratio  \
# 0               875.214286             536.928571                0.314077
# 1              1062.812500            1014.872500                0.297135
# 2               777.332500             761.102500                0.290702
# 3              1435.000000            3153.000000                0.332135
# 4               470.282353             505.385882                0.302842
# ...                    ...                    ...                     ...
# 5614            315.942857             597.171429                0.293659
# 5615            489.942857             708.028571                0.295297
# 5616            813.573333             204.893333                0.316179
# 5617            563.088889             811.288889                0.295543
# 5618            226.312000             543.628000                0.272988
#
#       average_Thermal conductivity  average_Van der waals radius  \
# 0                        46.582857                      1.884286
# 1                       104.102500                      1.950000
# 2                        25.352500                      1.892500
# 3                        81.500000                      1.965000
# 4                         8.960729                      1.697059
# ...                            ...                           ...
# 5614                     25.100903                      1.701429
# 5615                     51.443760                      1.781429
# 5616                     22.351053                      1.736667
# 5617                     10.687340                      1.662222
# 5618                     30.818606                      1.677000
#
#       average_Velocity of sound  average_Vickers hardness  average_X  \
# 0                   2918.857143               2108.307692   2.152857
# 1                   3684.751136               1436.403846   2.082500
# 2                   4292.251136               2108.307692   1.875000
# 3                  10680.000000               1934.153846   1.925000
# 4                   5779.942335              10383.312217   3.352941
# ...                         ...                       ...        ...
# 5614                2310.285714               2108.307692   2.595714
# 5615                2128.571429               1679.648352   2.631429
# 5616                1045.000000               2108.307692   2.946667
# 5617                1291.388889               2184.239316   3.097778
# 5618                1780.250000               1898.646154   2.905000
#
#       average_Youngs modulus  average_Metallic radius  \
# 0                  15.285714                 1.632909
# 1                 105.643443                 1.564545
# 2                  75.618443                 1.601545
# 3                  94.893443                 1.601295
# 4                  99.676663                 1.694580
# ...                      ...                      ...
# 5614              126.878220                 1.524909
# 5615              127.021077                 1.574338
# 5616               91.191257                 1.608394
# 5617              189.834244                 1.567571
# 5618              144.850820                 1.526814
#
#       average_Electron affinity
# 0                      1.204324
# 1                      1.407216
# 2                      1.240115
# 3                      0.720092
# 4                      2.498929
# ...                         ...
# 5614                   0.626346
# 5615                   0.882206
# 5616                   1.344760
# 5617                   1.149837
# 5618                   1.095942
#
# [5614 rows x 20 columns]

# %%
min_properties
# Out:
#       min_Atomic mass  min_Atomic no  min_Atomic radius  \
# 0             24.3050           12.0               1.15
# 1             32.0650           16.0               1.00
# 2              6.9410            3.0               1.00
# 3             12.0107            6.0               0.70
# 4             10.8110            5.0               0.50
# ...               ...            ...                ...
# 5614          15.9994            8.0               0.60
# 5615          15.9994            8.0               0.60
# 5616          15.9994            8.0               0.60
# 5617          15.9994            8.0               0.60
# 5618          15.9994            8.0               0.60
#
#       min_Atomic radius calculated  min_Boiling point  min_Bulk modulus  \
# 0                             1.03             958.00          8.300000
# 1                             0.88             717.87          7.700000
# 2                             0.88             717.87          7.700000
# 3                             0.67            4300.00         33.000000
# 4                             0.42              85.03          1.600000
# ...                            ...                ...               ...
# 5614                          0.48              90.20         45.000000
# 5615                          0.48              90.20         17.000000
# 5616                          0.48              90.20         58.000000
# 5617                          0.48              90.20         91.644118
# 5618                          0.48              90.20         70.000000
#
#       min_Common oxidation states  min_Critical temperature  \
# 0                             1.0               1285.517647
# 1                             1.0               1285.517647
# 2                             1.0               1285.517647
# 3                             1.0               1285.517647
# 4                             1.0                144.000000
# ...                           ...                       ...
# 5614                          1.0                154.600000
# 5615                          1.0                154.600000
# 5616                          1.0                154.600000
# 5617                          1.0                154.600000
# 5618                          1.0                154.600000
#
#       min_Density of solid  min_Liquid range  min_Melting point  \
# 0              1738.000000            440.00             429.75
# 1              1960.000000            329.51             388.36
# 2               535.000000            329.51             388.36
# 3              2267.000000            500.00            2506.00
# 4              1879.000000             31.50              53.53
# ...                    ...               ...                ...
# 5614           1738.000000             35.40              54.80
# 5615           1550.000000             35.40              54.80
# 5616           7310.000000             35.40              54.80
# 5617           8067.890411             35.40              54.80
# 5618           7140.000000             35.40              54.80
#
#       min_Poissons ratio  min_Thermal conductivity  min_Van der waals radius  \
# 0               0.290000                   0.52000                      1.73
# 1               0.260000                   0.20500                      1.80
# 2               0.280000                   0.20500                      1.80
# 3               0.294269                  23.00000                      1.70
# 4               0.294269                   0.02770                      1.47
# ...                  ...                       ...                       ...
# 5614            0.290000                   0.02658                      1.52
# 5615            0.290000                   0.02658                      1.52
# 5616            0.294269                   0.02658                      1.52
# 5617            0.294269                   0.02658                      1.52
# 5618            0.210000                   0.02658                      1.52
#
#       min_Velocity of sound  min_Vickers hardness  min_X  min_Youngs modulus  \
# 0               1215.000000           2108.307692   1.31           10.000000
# 1               3570.000000            369.000000   1.27           69.000000
# 2               3723.001515           2108.307692   0.98            4.900000
# 3               3010.000000           1760.000000   1.30           78.000000
# 4               1260.000000           2108.307692   0.79            1.700000
# ...                     ...                   ...    ...                 ...
# 5614             317.500000           2108.307692   1.31           45.000000
# 5615             317.500000            608.000000   1.00           20.000000
# 5616             317.500000           2108.307692   1.96           50.000000
# 5617             317.500000           2108.307692   1.90          111.786885
# 5618             317.500000           1060.000000   1.65          108.000000
#
#       min_Metallic radius  min_Electron affinity
# 0                1.600000              -0.420000
# 1                1.278000               0.238870
# 2                1.520000               0.188200
# 3                1.580000               0.178070
# 4                1.622591               0.279723
# ...                   ...                    ...
# 5614             1.292000              -0.520000
# 5615             1.277000               0.024551
# 5616             1.580000               1.112070
# 5617             1.375000               0.060397
# 5618             1.285000              -0.620000
#
# [5614 rows x 20 columns]

# %%
max_properties
# Out:
#       max_Atomic mass  max_Atomic no  max_Atomic radius  \
# 0          114.818000           49.0               1.55
# 1          174.967000           71.0               1.75
# 2           44.955912           21.0               1.60
# 3          178.490000           72.0               1.55
# 4          207.200000           82.0               2.60
# ...               ...            ...                ...
# 5614        54.938045           25.0               1.50
# 5615        55.845000           26.0               1.80
# 5616       118.710000           50.0               1.45
# 5617       186.207000           75.0               1.35
# 5618        65.409000           30.0               1.40
#
#       max_Atomic radius calculated  max_Boiling point  max_Bulk modulus  \
# 0                             1.56             2345.0         91.644118
# 1                             2.17             3675.0        140.000000
# 2                             1.84             3103.0         57.000000
# 3                             2.08             4876.0        110.000000
# 4                             2.98             4200.0        320.000000
# ...                            ...                ...               ...
# 5614                          1.61             2334.0        120.000000
# 5615                          1.94             3134.0        170.000000
# 5616                          1.45             2875.0         91.644118
# 5617                          1.88             5869.0        370.000000
# 5618                          1.66             2944.0        160.000000
#
#       max_Common oxidation states  max_Critical temperature  \
# 0                             4.0               1766.000000
# 1                             4.0               1314.000000
# 2                             4.0               3223.000000
# 3                             2.0               1285.517647
# 4                             2.0               1938.000000
# ...                           ...                       ...
# 5614                          3.0               1285.517647
# 5615                          2.0               1285.517647
# 5616                          3.0               1285.517647
# 5617                          1.0               1285.517647
# 5618                          2.0               1285.517647
#
#       max_Density of solid  max_Liquid range  max_Melting point  \
# 0              7310.000000           1915.25             923.00
# 1              9841.000000           1842.23            1925.00
# 2              2985.000000           1289.00            1814.00
# 3             13310.000000           2370.00            3800.00
# 4             11340.000000           1851.00            2349.00
# ...                    ...               ...                ...
# 5614           8067.890411            815.00            1519.00
# 5615           8067.890411           1323.00            1811.00
# 5616           8067.890411           2369.92             505.08
# 5617          21020.000000           2410.00            3459.00
# 5618           8067.890411            764.00            2180.00
#
#       max_Poissons ratio  max_Thermal conductivity  max_Van der waals radius  \
# 0               0.330000                     160.0                      1.93
# 1               0.340000                     400.0                      2.24
# 2               0.294269                      85.0                      2.15
# 3               0.370000                     140.0                      2.23
# 4               0.440000                      36.0                      3.43
# ...                  ...                       ...                       ...
# 5614            0.294269                     160.0                      2.05
# 5615            0.310000                     200.0                      2.31
# 5616            0.360000                      67.0                      2.17
# 5617            0.300000                      48.0                      2.16
# 5618            0.294269                     120.0                      2.06
#
#       max_Velocity of sound  max_Vickers hardness  max_X  max_Youngs modulus  \
# 0               4602.000000           2108.307692   2.55           45.000000
# 1               3723.001515           2108.307692   2.58          130.000000
# 2               6000.000000           2108.307692   2.58          111.786885
# 3              18350.000000           2108.307692   2.55          111.786885
# 4              16200.000000          49000.000000   3.98          111.786885
# ...                     ...                   ...    ...                 ...
# 5614            5150.000000           2108.307692   3.44          198.000000
# 5615            4910.000000           2108.307692   3.44          211.000000
# 5616            2500.000000           2108.307692   3.44          111.786885
# 5617            4700.000000           2450.000000   3.44          463.000000
# 5618            5940.000000           2108.307692   3.44          279.000000
#
#       max_Metallic radius  max_Electron affinity
# 0                1.670000               2.020605
# 1                1.735000               2.077105
# 2                1.641000               2.077105
# 3                1.622591               1.262114
# 4                2.719000               3.401190
# ...                   ...                    ...
# 5614             1.622591               1.461105
# 5615             1.976000               1.461105
# 5616             1.622591               1.461105
# 5617             1.622591               1.461105
# 5618             1.622591               1.461105
#
# [5614 rows x 20 columns]

# %%
design_matrix= pd.concat([filt_data_comp, avg_properties_df, min_properties, max_properties], axis=1)
design_matrix.columns

droplist2 = ['volume','energy', 'pretty_formula', 'Composition', 'average_Common oxidation states', 'min_Common oxidation states','max_Common oxidation states']
design_matrix = design_matrix.drop(columns=droplist2)
design_matrix
# Out:
#      material_id  energy_per_atom  formation_energy_per_atom  nsites  \
# 0     mp-1001034        -3.715648                  -0.703661      14
# 1     mp-1001780        -5.591101                  -1.699567       4
# 2     mp-1001786        -5.900228                  -2.103385       4
# 3     mp-1002124        -9.890380                  -0.298402       2
# 4     mp-1004528        -5.614998                  -3.162482      17
# ...          ...              ...                        ...     ...
# 5614    mvc-6916        -7.098949                  -2.307339      14
# 5615    mvc-6928        -6.543137                  -2.192463      14
# 5616    mvc-6946        -6.122609                  -1.961400       6
# 5617    mvc-7040        -8.067357                  -1.999722      18
# 5618    mvc-7383        -6.225146                  -1.597210      20
#
#       nelements   density  band_gap  num_atoms  volume_per_atom  \
# 0             3  5.030727    0.7432        7.0        53.735123
# 1             3  6.400668    1.5031        4.0        19.628830
# 2             3  2.687084    1.5296        4.0        17.925309
# 3             2  9.868236    0.5774        2.0        16.027883
# 4             4  3.068458    6.3125       17.0        19.116437
# ...         ...       ...       ...        ...              ...
# 5614          3  4.200544    0.0516        7.0        22.383730
# 5615          3  4.119621    1.7463        7.0        24.848833
# 5616          2  5.131960    2.1009        3.0        32.509720
# 5617          2  3.840256    3.4689        9.0        46.546747
# 5618          3  2.941999    2.4238       10.0        31.765523
#
#       average_Atomic mass  average_Atomic no  average_Atomic radius  \
# 0               81.397286          35.142857               1.314286
# 1               75.660750          33.000000               1.275000
# 2               29.006728          14.000000               1.262500
# 3               95.250350          39.000000               1.125000
# 4               35.324664          15.294118               0.761765
# ...                   ...                ...                    ...
# 5614            28.311241          13.428571               0.957143
# 5615            30.823657          14.857143               1.000000
# 5616            50.236267          22.000000               0.883333
# 5617            53.823311          22.888889               0.766667
# 5618            28.139700          13.400000               0.835000
#
#       average_Atomic radius calculated  average_Boiling point  \
# 0                             1.241429            1412.142857
# 1                             1.345000            2077.685000
# 2                             1.317500            1538.435000
# 3                             1.375000            4588.000000
# 4                             0.715882             975.668235
# ...                                ...                    ...
# 5614                          0.941429             913.114286
# 5615                          0.997143            1197.971429
# 5616                          0.803333            1018.466667
# 5617                          0.791111            1374.377778
# 5618                          0.810000             769.940000
#
#       average_Bulk modulus  average_Critical temperature  \
# 0                37.355462                   1560.078992
# 1                50.850000                   1299.758824
# 2                20.850000                   1784.129412
# 3                71.500000                   1285.517647
# 4               123.960554                    518.121799
# ...                    ...                           ...
# 5614             93.082353                    639.278992
# 5615            103.368067                    639.278992
# 5616             80.429412                    531.572549
# 5617            153.500980                    405.915033
# 5618            103.150882                    493.875294
#
#       average_Density of solid  average_Liquid range  average_Melting point  \
# 0                  5090.571429            875.214286             536.928571
# 1                  5670.250000           1062.812500            1014.872500
# 2                  1860.000000            777.332500             761.102500
# 3                  7788.500000           1435.000000            3153.000000
# 4                  6906.687349            470.282353             505.385882
# ...                        ...                   ...                    ...
# 5614               6992.794521            315.942857             597.171429
# 5615               7081.365949            489.942857             708.028571
# 5616               7815.260274            813.573333             204.893333
# 5617              10946.136986            563.088889             811.288889
# 5618               7789.523288            226.312000             543.628000
#
#       average_Poissons ratio  average_Thermal conductivity  \
# 0                   0.314077                     46.582857
# 1                   0.297135                    104.102500
# 2                   0.290702                     25.352500
# 3                   0.332135                     81.500000
# 4                   0.302842                      8.960729
# ...                      ...                           ...
# 5614                0.293659                     25.100903
# 5615                0.295297                     51.443760
# 5616                0.316179                     22.351053
# 5617                0.295543                     10.687340
# 5618                0.272988                     30.818606
#
#       average_Van der waals radius  average_Velocity of sound  \
# 0                         1.884286                2918.857143
# 1                         1.950000                3684.751136
# 2                         1.892500                4292.251136
# 3                         1.965000               10680.000000
# 4                         1.697059                5779.942335
# ...                            ...                        ...
# 5614                      1.701429                2310.285714
# 5615                      1.781429                2128.571429
# 5616                      1.736667                1045.000000
# 5617                      1.662222                1291.388889
# 5618                      1.677000                1780.250000
#
#       average_Vickers hardness  average_X  average_Youngs modulus  \
# 0                  2108.307692   2.152857               15.285714
# 1                  1436.403846   2.082500              105.643443
# 2                  2108.307692   1.875000               75.618443
# 3                  1934.153846   1.925000               94.893443
# 4                 10383.312217   3.352941               99.676663
# ...                        ...        ...                     ...
# 5614               2108.307692   2.595714              126.878220
# 5615               1679.648352   2.631429              127.021077
# 5616               2108.307692   2.946667               91.191257
# 5617               2184.239316   3.097778              189.834244
# 5618               1898.646154   2.905000              144.850820
#
#       average_Metallic radius  average_Electron affinity  min_Atomic mass  \
# 0                    1.632909                   1.204324          24.3050
# 1                    1.564545                   1.407216          32.0650
# 2                    1.601545                   1.240115           6.9410
# 3                    1.601295                   0.720092          12.0107
# 4                    1.694580                   2.498929          10.8110
# ...                       ...                        ...              ...
# 5614                 1.524909                   0.626346          15.9994
# 5615                 1.574338                   0.882206          15.9994
# 5616                 1.608394                   1.344760          15.9994
# 5617                 1.567571                   1.149837          15.9994
# 5618                 1.526814                   1.095942          15.9994
#
#       min_Atomic no  min_Atomic radius  min_Atomic radius calculated  \
# 0              12.0               1.15                          1.03
# 1              16.0               1.00                          0.88
# 2               3.0               1.00                          0.88
# 3               6.0               0.70                          0.67
# 4               5.0               0.50                          0.42
# ...             ...                ...                           ...
# 5614            8.0               0.60                          0.48
# 5615            8.0               0.60                          0.48
# 5616            8.0               0.60                          0.48
# 5617            8.0               0.60                          0.48
# 5618            8.0               0.60                          0.48
#
#       min_Boiling point  min_Bulk modulus  min_Critical temperature  \
# 0                958.00          8.300000               1285.517647
# 1                717.87          7.700000               1285.517647
# 2                717.87          7.700000               1285.517647
# 3               4300.00         33.000000               1285.517647
# 4                 85.03          1.600000                144.000000
# ...                 ...               ...                       ...
# 5614              90.20         45.000000                154.600000
# 5615              90.20         17.000000                154.600000
# 5616              90.20         58.000000                154.600000
# 5617              90.20         91.644118                154.600000
# 5618              90.20         70.000000                154.600000
#
#       min_Density of solid  min_Liquid range  min_Melting point  \
# 0              1738.000000            440.00             429.75
# 1              1960.000000            329.51             388.36
# 2               535.000000            329.51             388.36
# 3              2267.000000            500.00            2506.00
# 4              1879.000000             31.50              53.53
# ...                    ...               ...                ...
# 5614           1738.000000             35.40              54.80
# 5615           1550.000000             35.40              54.80
# 5616           7310.000000             35.40              54.80
# 5617           8067.890411             35.40              54.80
# 5618           7140.000000             35.40              54.80
#
#       min_Poissons ratio  min_Thermal conductivity  min_Van der waals radius  \
# 0               0.290000                   0.52000                      1.73
# 1               0.260000                   0.20500                      1.80
# 2               0.280000                   0.20500                      1.80
# 3               0.294269                  23.00000                      1.70
# 4               0.294269                   0.02770                      1.47
# ...                  ...                       ...                       ...
# 5614            0.290000                   0.02658                      1.52
# 5615            0.290000                   0.02658                      1.52
# 5616            0.294269                   0.02658                      1.52
# 5617            0.294269                   0.02658                      1.52
# 5618            0.210000                   0.02658                      1.52
#
#       min_Velocity of sound  min_Vickers hardness  min_X  min_Youngs modulus  \
# 0               1215.000000           2108.307692   1.31           10.000000
# 1               3570.000000            369.000000   1.27           69.000000
# 2               3723.001515           2108.307692   0.98            4.900000
# 3               3010.000000           1760.000000   1.30           78.000000
# 4               1260.000000           2108.307692   0.79            1.700000
# ...                     ...                   ...    ...                 ...
# 5614             317.500000           2108.307692   1.31           45.000000
# 5615             317.500000            608.000000   1.00           20.000000
# 5616             317.500000           2108.307692   1.96           50.000000
# 5617             317.500000           2108.307692   1.90          111.786885
# 5618             317.500000           1060.000000   1.65          108.000000
#
#       min_Metallic radius  min_Electron affinity  max_Atomic mass  \
# 0                1.600000              -0.420000       114.818000
# 1                1.278000               0.238870       174.967000
# 2                1.520000               0.188200        44.955912
# 3                1.580000               0.178070       178.490000
# 4                1.622591               0.279723       207.200000
# ...                   ...                    ...              ...
# 5614             1.292000              -0.520000        54.938045
# 5615             1.277000               0.024551        55.845000
# 5616             1.580000               1.112070       118.710000
# 5617             1.375000               0.060397       186.207000
# 5618             1.285000              -0.620000        65.409000
#
#       max_Atomic no  max_Atomic radius  max_Atomic radius calculated  \
# 0              49.0               1.55                          1.56
# 1              71.0               1.75                          2.17
# 2              21.0               1.60                          1.84
# 3              72.0               1.55                          2.08
# 4              82.0               2.60                          2.98
# ...             ...                ...                           ...
# 5614           25.0               1.50                          1.61
# 5615           26.0               1.80                          1.94
# 5616           50.0               1.45                          1.45
# 5617           75.0               1.35                          1.88
# 5618           30.0               1.40                          1.66
#
#       max_Boiling point  max_Bulk modulus  max_Critical temperature  \
# 0                2345.0         91.644118               1766.000000
# 1                3675.0        140.000000               1314.000000
# 2                3103.0         57.000000               3223.000000
# 3                4876.0        110.000000               1285.517647
# 4                4200.0        320.000000               1938.000000
# ...                 ...               ...                       ...
# 5614             2334.0        120.000000               1285.517647
# 5615             3134.0        170.000000               1285.517647
# 5616             2875.0         91.644118               1285.517647
# 5617             5869.0        370.000000               1285.517647
# 5618             2944.0        160.000000               1285.517647
#
#       max_Density of solid  max_Liquid range  max_Melting point  \
# 0              7310.000000           1915.25             923.00
# 1              9841.000000           1842.23            1925.00
# 2              2985.000000           1289.00            1814.00
# 3             13310.000000           2370.00            3800.00
# 4             11340.000000           1851.00            2349.00
# ...                    ...               ...                ...
# 5614           8067.890411            815.00            1519.00
# 5615           8067.890411           1323.00            1811.00
# 5616           8067.890411           2369.92             505.08
# 5617          21020.000000           2410.00            3459.00
# 5618           8067.890411            764.00            2180.00
#
#       max_Poissons ratio  max_Thermal conductivity  max_Van der waals radius  \
# 0               0.330000                     160.0                      1.93
# 1               0.340000                     400.0                      2.24
# 2               0.294269                      85.0                      2.15
# 3               0.370000                     140.0                      2.23
# 4               0.440000                      36.0                      3.43
# ...                  ...                       ...                       ...
# 5614            0.294269                     160.0                      2.05
# 5615            0.310000                     200.0                      2.31
# 5616            0.360000                      67.0                      2.17
# 5617            0.300000                      48.0                      2.16
# 5618            0.294269                     120.0                      2.06
#
#       max_Velocity of sound  max_Vickers hardness  max_X  max_Youngs modulus  \
# 0               4602.000000           2108.307692   2.55           45.000000
# 1               3723.001515           2108.307692   2.58          130.000000
# 2               6000.000000           2108.307692   2.58          111.786885
# 3              18350.000000           2108.307692   2.55          111.786885
# 4              16200.000000          49000.000000   3.98          111.786885
# ...                     ...                   ...    ...                 ...
# 5614            5150.000000           2108.307692   3.44          198.000000
# 5615            4910.000000           2108.307692   3.44          211.000000
# 5616            2500.000000           2108.307692   3.44          111.786885
# 5617            4700.000000           2450.000000   3.44          463.000000
# 5618            5940.000000           2108.307692   3.44          279.000000
#
#       max_Metallic radius  max_Electron affinity
# 0                1.670000               2.020605
# 1                1.735000               2.077105
# 2                1.641000               2.077105
# 3                1.622591               1.262114
# 4                2.719000               3.401190
# ...                   ...                    ...
# 5614             1.622591               1.461105
# 5615             1.976000               1.461105
# 5616             1.622591               1.461105
# 5617             1.622591               1.461105
# 5618             1.622591               1.461105
#
# [5614 rows x 66 columns]

# %%
#train[train['material_id'].isin(design_matrix['material_id'])]
# #train
# train[train.material_id.isin(design_matrix.material_id)]

# train.material_id

# %%
IDs = list(filt_data["material_id"])
IDs = pd.DataFrame(IDs)

train_filt = train[train.index.isin(IDs.index)] 
train_filt
# y_jojo = train_filt.drop('material_id', axis=1)
#y_jojo = y_jojo.rename(index=IDs)
#y_jojo


# targets = df.loc[:,["energy",
#         "energy_per_atom",
#         "volume",
#         "formation_energy_per_atom",
#         "nsites",
#         "nelements",
#         "density",
#         "band_gap"]]

# # x_jojo = df[targets]
# # x_jojo

# cols = ["energy",
#         "energy_per_atom",
#         "volume",
#         "formation_energy_per_atom",
#         "nsites",
#         "nelements",
#         "density",
#         "band_gap"] 
# design_matrix= df[cols]
train
# Out:
#      material_id  dielectric_poly_total
# 0      mp-555903               8.337936
# 1      mp-752658              14.735277
# 2        mp-3439              17.195305
# 3       mp-16135              21.593507
# 4       mp-36447               9.507068
# ...          ...                    ...
# 5614   mp-643378              20.365294
# 5615     mp-3536               8.476483
# 5616   mp-760402              27.401830
# 5617    mp-28109               8.384639
# 5618   mp-545482               6.801796
#
# [5619 rows x 2 columns]

# %%
train_filt
# Out:
#      material_id  dielectric_poly_total
# 0      mp-555903               8.337936
# 1      mp-752658              14.735277
# 2        mp-3439              17.195305
# 3       mp-16135              21.593507
# 4       mp-36447               9.507068
# ...          ...                    ...
# 5609   mp-754117              13.378949
# 5610  mp-1539137              16.908907
# 5611  mp-1079559              11.776195
# 5612   mp-555908               6.241000
# 5613    mp-11653               5.887169
#
# [5614 rows x 2 columns]

# %%
design_matrix
# Out:
#      material_id  energy_per_atom  formation_energy_per_atom  nsites  \
# 0     mp-1001034        -3.715648                  -0.703661      14
# 1     mp-1001780        -5.591101                  -1.699567       4
# 2     mp-1001786        -5.900228                  -2.103385       4
# 3     mp-1002124        -9.890380                  -0.298402       2
# 4     mp-1004528        -5.614998                  -3.162482      17
# ...          ...              ...                        ...     ...
# 5614    mvc-6916        -7.098949                  -2.307339      14
# 5615    mvc-6928        -6.543137                  -2.192463      14
# 5616    mvc-6946        -6.122609                  -1.961400       6
# 5617    mvc-7040        -8.067357                  -1.999722      18
# 5618    mvc-7383        -6.225146                  -1.597210      20
#
#       nelements   density  band_gap  num_atoms  volume_per_atom  \
# 0             3  5.030727    0.7432        7.0        53.735123
# 1             3  6.400668    1.5031        4.0        19.628830
# 2             3  2.687084    1.5296        4.0        17.925309
# 3             2  9.868236    0.5774        2.0        16.027883
# 4             4  3.068458    6.3125       17.0        19.116437
# ...         ...       ...       ...        ...              ...
# 5614          3  4.200544    0.0516        7.0        22.383730
# 5615          3  4.119621    1.7463        7.0        24.848833
# 5616          2  5.131960    2.1009        3.0        32.509720
# 5617          2  3.840256    3.4689        9.0        46.546747
# 5618          3  2.941999    2.4238       10.0        31.765523
#
#       average_Atomic mass  average_Atomic no  average_Atomic radius  \
# 0               81.397286          35.142857               1.314286
# 1               75.660750          33.000000               1.275000
# 2               29.006728          14.000000               1.262500
# 3               95.250350          39.000000               1.125000
# 4               35.324664          15.294118               0.761765
# ...                   ...                ...                    ...
# 5614            28.311241          13.428571               0.957143
# 5615            30.823657          14.857143               1.000000
# 5616            50.236267          22.000000               0.883333
# 5617            53.823311          22.888889               0.766667
# 5618            28.139700          13.400000               0.835000
#
#       average_Atomic radius calculated  average_Boiling point  \
# 0                             1.241429            1412.142857
# 1                             1.345000            2077.685000
# 2                             1.317500            1538.435000
# 3                             1.375000            4588.000000
# 4                             0.715882             975.668235
# ...                                ...                    ...
# 5614                          0.941429             913.114286
# 5615                          0.997143            1197.971429
# 5616                          0.803333            1018.466667
# 5617                          0.791111            1374.377778
# 5618                          0.810000             769.940000
#
#       average_Bulk modulus  average_Critical temperature  \
# 0                37.355462                   1560.078992
# 1                50.850000                   1299.758824
# 2                20.850000                   1784.129412
# 3                71.500000                   1285.517647
# 4               123.960554                    518.121799
# ...                    ...                           ...
# 5614             93.082353                    639.278992
# 5615            103.368067                    639.278992
# 5616             80.429412                    531.572549
# 5617            153.500980                    405.915033
# 5618            103.150882                    493.875294
#
#       average_Density of solid  average_Liquid range  average_Melting point  \
# 0                  5090.571429            875.214286             536.928571
# 1                  5670.250000           1062.812500            1014.872500
# 2                  1860.000000            777.332500             761.102500
# 3                  7788.500000           1435.000000            3153.000000
# 4                  6906.687349            470.282353             505.385882
# ...                        ...                   ...                    ...
# 5614               6992.794521            315.942857             597.171429
# 5615               7081.365949            489.942857             708.028571
# 5616               7815.260274            813.573333             204.893333
# 5617              10946.136986            563.088889             811.288889
# 5618               7789.523288            226.312000             543.628000
#
#       average_Poissons ratio  average_Thermal conductivity  \
# 0                   0.314077                     46.582857
# 1                   0.297135                    104.102500
# 2                   0.290702                     25.352500
# 3                   0.332135                     81.500000
# 4                   0.302842                      8.960729
# ...                      ...                           ...
# 5614                0.293659                     25.100903
# 5615                0.295297                     51.443760
# 5616                0.316179                     22.351053
# 5617                0.295543                     10.687340
# 5618                0.272988                     30.818606
#
#       average_Van der waals radius  average_Velocity of sound  \
# 0                         1.884286                2918.857143
# 1                         1.950000                3684.751136
# 2                         1.892500                4292.251136
# 3                         1.965000               10680.000000
# 4                         1.697059                5779.942335
# ...                            ...                        ...
# 5614                      1.701429                2310.285714
# 5615                      1.781429                2128.571429
# 5616                      1.736667                1045.000000
# 5617                      1.662222                1291.388889
# 5618                      1.677000                1780.250000
#
#       average_Vickers hardness  average_X  average_Youngs modulus  \
# 0                  2108.307692   2.152857               15.285714
# 1                  1436.403846   2.082500              105.643443
# 2                  2108.307692   1.875000               75.618443
# 3                  1934.153846   1.925000               94.893443
# 4                 10383.312217   3.352941               99.676663
# ...                        ...        ...                     ...
# 5614               2108.307692   2.595714              126.878220
# 5615               1679.648352   2.631429              127.021077
# 5616               2108.307692   2.946667               91.191257
# 5617               2184.239316   3.097778              189.834244
# 5618               1898.646154   2.905000              144.850820
#
#       average_Metallic radius  average_Electron affinity  min_Atomic mass  \
# 0                    1.632909                   1.204324          24.3050
# 1                    1.564545                   1.407216          32.0650
# 2                    1.601545                   1.240115           6.9410
# 3                    1.601295                   0.720092          12.0107
# 4                    1.694580                   2.498929          10.8110
# ...                       ...                        ...              ...
# 5614                 1.524909                   0.626346          15.9994
# 5615                 1.574338                   0.882206          15.9994
# 5616                 1.608394                   1.344760          15.9994
# 5617                 1.567571                   1.149837          15.9994
# 5618                 1.526814                   1.095942          15.9994
#
#       min_Atomic no  min_Atomic radius  min_Atomic radius calculated  \
# 0              12.0               1.15                          1.03
# 1              16.0               1.00                          0.88
# 2               3.0               1.00                          0.88
# 3               6.0               0.70                          0.67
# 4               5.0               0.50                          0.42
# ...             ...                ...                           ...
# 5614            8.0               0.60                          0.48
# 5615            8.0               0.60                          0.48
# 5616            8.0               0.60                          0.48
# 5617            8.0               0.60                          0.48
# 5618            8.0               0.60                          0.48
#
#       min_Boiling point  min_Bulk modulus  min_Critical temperature  \
# 0                958.00          8.300000               1285.517647
# 1                717.87          7.700000               1285.517647
# 2                717.87          7.700000               1285.517647
# 3               4300.00         33.000000               1285.517647
# 4                 85.03          1.600000                144.000000
# ...                 ...               ...                       ...
# 5614              90.20         45.000000                154.600000
# 5615              90.20         17.000000                154.600000
# 5616              90.20         58.000000                154.600000
# 5617              90.20         91.644118                154.600000
# 5618              90.20         70.000000                154.600000
#
#       min_Density of solid  min_Liquid range  min_Melting point  \
# 0              1738.000000            440.00             429.75
# 1              1960.000000            329.51             388.36
# 2               535.000000            329.51             388.36
# 3              2267.000000            500.00            2506.00
# 4              1879.000000             31.50              53.53
# ...                    ...               ...                ...
# 5614           1738.000000             35.40              54.80
# 5615           1550.000000             35.40              54.80
# 5616           7310.000000             35.40              54.80
# 5617           8067.890411             35.40              54.80
# 5618           7140.000000             35.40              54.80
#
#       min_Poissons ratio  min_Thermal conductivity  min_Van der waals radius  \
# 0               0.290000                   0.52000                      1.73
# 1               0.260000                   0.20500                      1.80
# 2               0.280000                   0.20500                      1.80
# 3               0.294269                  23.00000                      1.70
# 4               0.294269                   0.02770                      1.47
# ...                  ...                       ...                       ...
# 5614            0.290000                   0.02658                      1.52
# 5615            0.290000                   0.02658                      1.52
# 5616            0.294269                   0.02658                      1.52
# 5617            0.294269                   0.02658                      1.52
# 5618            0.210000                   0.02658                      1.52
#
#       min_Velocity of sound  min_Vickers hardness  min_X  min_Youngs modulus  \
# 0               1215.000000           2108.307692   1.31           10.000000
# 1               3570.000000            369.000000   1.27           69.000000
# 2               3723.001515           2108.307692   0.98            4.900000
# 3               3010.000000           1760.000000   1.30           78.000000
# 4               1260.000000           2108.307692   0.79            1.700000
# ...                     ...                   ...    ...                 ...
# 5614             317.500000           2108.307692   1.31           45.000000
# 5615             317.500000            608.000000   1.00           20.000000
# 5616             317.500000           2108.307692   1.96           50.000000
# 5617             317.500000           2108.307692   1.90          111.786885
# 5618             317.500000           1060.000000   1.65          108.000000
#
#       min_Metallic radius  min_Electron affinity  max_Atomic mass  \
# 0                1.600000              -0.420000       114.818000
# 1                1.278000               0.238870       174.967000
# 2                1.520000               0.188200        44.955912
# 3                1.580000               0.178070       178.490000
# 4                1.622591               0.279723       207.200000
# ...                   ...                    ...              ...
# 5614             1.292000              -0.520000        54.938045
# 5615             1.277000               0.024551        55.845000
# 5616             1.580000               1.112070       118.710000
# 5617             1.375000               0.060397       186.207000
# 5618             1.285000              -0.620000        65.409000
#
#       max_Atomic no  max_Atomic radius  max_Atomic radius calculated  \
# 0              49.0               1.55                          1.56
# 1              71.0               1.75                          2.17
# 2              21.0               1.60                          1.84
# 3              72.0               1.55                          2.08
# 4              82.0               2.60                          2.98
# ...             ...                ...                           ...
# 5614           25.0               1.50                          1.61
# 5615           26.0               1.80                          1.94
# 5616           50.0               1.45                          1.45
# 5617           75.0               1.35                          1.88
# 5618           30.0               1.40                          1.66
#
#       max_Boiling point  max_Bulk modulus  max_Critical temperature  \
# 0                2345.0         91.644118               1766.000000
# 1                3675.0        140.000000               1314.000000
# 2                3103.0         57.000000               3223.000000
# 3                4876.0        110.000000               1285.517647
# 4                4200.0        320.000000               1938.000000
# ...                 ...               ...                       ...
# 5614             2334.0        120.000000               1285.517647
# 5615             3134.0        170.000000               1285.517647
# 5616             2875.0         91.644118               1285.517647
# 5617             5869.0        370.000000               1285.517647
# 5618             2944.0        160.000000               1285.517647
#
#       max_Density of solid  max_Liquid range  max_Melting point  \
# 0              7310.000000           1915.25             923.00
# 1              9841.000000           1842.23            1925.00
# 2              2985.000000           1289.00            1814.00
# 3             13310.000000           2370.00            3800.00
# 4             11340.000000           1851.00            2349.00
# ...                    ...               ...                ...
# 5614           8067.890411            815.00            1519.00
# 5615           8067.890411           1323.00            1811.00
# 5616           8067.890411           2369.92             505.08
# 5617          21020.000000           2410.00            3459.00
# 5618           8067.890411            764.00            2180.00
#
#       max_Poissons ratio  max_Thermal conductivity  max_Van der waals radius  \
# 0               0.330000                     160.0                      1.93
# 1               0.340000                     400.0                      2.24
# 2               0.294269                      85.0                      2.15
# 3               0.370000                     140.0                      2.23
# 4               0.440000                      36.0                      3.43
# ...                  ...                       ...                       ...
# 5614            0.294269                     160.0                      2.05
# 5615            0.310000                     200.0                      2.31
# 5616            0.360000                      67.0                      2.17
# 5617            0.300000                      48.0                      2.16
# 5618            0.294269                     120.0                      2.06
#
#       max_Velocity of sound  max_Vickers hardness  max_X  max_Youngs modulus  \
# 0               4602.000000           2108.307692   2.55           45.000000
# 1               3723.001515           2108.307692   2.58          130.000000
# 2               6000.000000           2108.307692   2.58          111.786885
# 3              18350.000000           2108.307692   2.55          111.786885
# 4              16200.000000          49000.000000   3.98          111.786885
# ...                     ...                   ...    ...                 ...
# 5614            5150.000000           2108.307692   3.44          198.000000
# 5615            4910.000000           2108.307692   3.44          211.000000
# 5616            2500.000000           2108.307692   3.44          111.786885
# 5617            4700.000000           2450.000000   3.44          463.000000
# 5618            5940.000000           2108.307692   3.44          279.000000
#
#       max_Metallic radius  max_Electron affinity
# 0                1.670000               2.020605
# 1                1.735000               2.077105
# 2                1.641000               2.077105
# 3                1.622591               1.262114
# 4                2.719000               3.401190
# ...                   ...                    ...
# 5614             1.622591               1.461105
# 5615             1.976000               1.461105
# 5616             1.622591               1.461105
# 5617             1.622591               1.461105
# 5618             1.622591               1.461105
#
# [5614 rows x 66 columns]

# %%
train_filt.set_index('material_id')
# Out:
#              dielectric_poly_total
# material_id
# mp-555903                 8.337936
# mp-752658                14.735277
# mp-3439                  17.195305
# mp-16135                 21.593507
# mp-36447                  9.507068
# ...                            ...
# mp-754117                13.378949
# mp-1539137               16.908907
# mp-1079559               11.776195
# mp-555908                 6.241000
# mp-11653                  5.887169
#
# [5614 rows x 1 columns]

# %%
design_matrix.set_index('material_id',inplace=True)
design_matrix
# Out:
#              energy_per_atom  formation_energy_per_atom  nsites  nelements  \
# material_id
# mp-1001034         -3.715648                  -0.703661      14          3
# mp-1001780         -5.591101                  -1.699567       4          3
# mp-1001786         -5.900228                  -2.103385       4          3
# mp-1002124         -9.890380                  -0.298402       2          2
# mp-1004528         -5.614998                  -3.162482      17          4
# ...                      ...                        ...     ...        ...
# mvc-6916           -7.098949                  -2.307339      14          3
# mvc-6928           -6.543137                  -2.192463      14          3
# mvc-6946           -6.122609                  -1.961400       6          2
# mvc-7040           -8.067357                  -1.999722      18          2
# mvc-7383           -6.225146                  -1.597210      20          3
#
#               density  band_gap  num_atoms  volume_per_atom  \
# material_id
# mp-1001034   5.030727    0.7432        7.0        53.735123
# mp-1001780   6.400668    1.5031        4.0        19.628830
# mp-1001786   2.687084    1.5296        4.0        17.925309
# mp-1002124   9.868236    0.5774        2.0        16.027883
# mp-1004528   3.068458    6.3125       17.0        19.116437
# ...               ...       ...        ...              ...
# mvc-6916     4.200544    0.0516        7.0        22.383730
# mvc-6928     4.119621    1.7463        7.0        24.848833
# mvc-6946     5.131960    2.1009        3.0        32.509720
# mvc-7040     3.840256    3.4689        9.0        46.546747
# mvc-7383     2.941999    2.4238       10.0        31.765523
#
#              average_Atomic mass  average_Atomic no  average_Atomic radius  \
# material_id
# mp-1001034             81.397286          35.142857               1.314286
# mp-1001780             75.660750          33.000000               1.275000
# mp-1001786             29.006728          14.000000               1.262500
# mp-1002124             95.250350          39.000000               1.125000
# mp-1004528             35.324664          15.294118               0.761765
# ...                          ...                ...                    ...
# mvc-6916               28.311241          13.428571               0.957143
# mvc-6928               30.823657          14.857143               1.000000
# mvc-6946               50.236267          22.000000               0.883333
# mvc-7040               53.823311          22.888889               0.766667
# mvc-7383               28.139700          13.400000               0.835000
#
#              average_Atomic radius calculated  average_Boiling point  \
# material_id
# mp-1001034                           1.241429            1412.142857
# mp-1001780                           1.345000            2077.685000
# mp-1001786                           1.317500            1538.435000
# mp-1002124                           1.375000            4588.000000
# mp-1004528                           0.715882             975.668235
# ...                                       ...                    ...
# mvc-6916                             0.941429             913.114286
# mvc-6928                             0.997143            1197.971429
# mvc-6946                             0.803333            1018.466667
# mvc-7040                             0.791111            1374.377778
# mvc-7383                             0.810000             769.940000
#
#              average_Bulk modulus  average_Critical temperature  \
# material_id
# mp-1001034              37.355462                   1560.078992
# mp-1001780              50.850000                   1299.758824
# mp-1001786              20.850000                   1784.129412
# mp-1002124              71.500000                   1285.517647
# mp-1004528             123.960554                    518.121799
# ...                           ...                           ...
# mvc-6916                93.082353                    639.278992
# mvc-6928               103.368067                    639.278992
# mvc-6946                80.429412                    531.572549
# mvc-7040               153.500980                    405.915033
# mvc-7383               103.150882                    493.875294
#
#              average_Density of solid  average_Liquid range  \
# material_id
# mp-1001034                5090.571429            875.214286
# mp-1001780                5670.250000           1062.812500
# mp-1001786                1860.000000            777.332500
# mp-1002124                7788.500000           1435.000000
# mp-1004528                6906.687349            470.282353
# ...                               ...                   ...
# mvc-6916                  6992.794521            315.942857
# mvc-6928                  7081.365949            489.942857
# mvc-6946                  7815.260274            813.573333
# mvc-7040                 10946.136986            563.088889
# mvc-7383                  7789.523288            226.312000
#
#              average_Melting point  average_Poissons ratio  \
# material_id
# mp-1001034              536.928571                0.314077
# mp-1001780             1014.872500                0.297135
# mp-1001786              761.102500                0.290702
# mp-1002124             3153.000000                0.332135
# mp-1004528              505.385882                0.302842
# ...                            ...                     ...
# mvc-6916                597.171429                0.293659
# mvc-6928                708.028571                0.295297
# mvc-6946                204.893333                0.316179
# mvc-7040                811.288889                0.295543
# mvc-7383                543.628000                0.272988
#
#              average_Thermal conductivity  average_Van der waals radius  \
# material_id
# mp-1001034                      46.582857                      1.884286
# mp-1001780                     104.102500                      1.950000
# mp-1001786                      25.352500                      1.892500
# mp-1002124                      81.500000                      1.965000
# mp-1004528                       8.960729                      1.697059
# ...                                   ...                           ...
# mvc-6916                        25.100903                      1.701429
# mvc-6928                        51.443760                      1.781429
# mvc-6946                        22.351053                      1.736667
# mvc-7040                        10.687340                      1.662222
# mvc-7383                        30.818606                      1.677000
#
#              average_Velocity of sound  average_Vickers hardness  average_X  \
# material_id
# mp-1001034                 2918.857143               2108.307692   2.152857
# mp-1001780                 3684.751136               1436.403846   2.082500
# mp-1001786                 4292.251136               2108.307692   1.875000
# mp-1002124                10680.000000               1934.153846   1.925000
# mp-1004528                 5779.942335              10383.312217   3.352941
# ...                                ...                       ...        ...
# mvc-6916                   2310.285714               2108.307692   2.595714
# mvc-6928                   2128.571429               1679.648352   2.631429
# mvc-6946                   1045.000000               2108.307692   2.946667
# mvc-7040                   1291.388889               2184.239316   3.097778
# mvc-7383                   1780.250000               1898.646154   2.905000
#
#              average_Youngs modulus  average_Metallic radius  \
# material_id
# mp-1001034                15.285714                 1.632909
# mp-1001780               105.643443                 1.564545
# mp-1001786                75.618443                 1.601545
# mp-1002124                94.893443                 1.601295
# mp-1004528                99.676663                 1.694580
# ...                             ...                      ...
# mvc-6916                 126.878220                 1.524909
# mvc-6928                 127.021077                 1.574338
# mvc-6946                  91.191257                 1.608394
# mvc-7040                 189.834244                 1.567571
# mvc-7383                 144.850820                 1.526814
#
#              average_Electron affinity  min_Atomic mass  min_Atomic no  \
# material_id
# mp-1001034                    1.204324          24.3050           12.0
# mp-1001780                    1.407216          32.0650           16.0
# mp-1001786                    1.240115           6.9410            3.0
# mp-1002124                    0.720092          12.0107            6.0
# mp-1004528                    2.498929          10.8110            5.0
# ...                                ...              ...            ...
# mvc-6916                      0.626346          15.9994            8.0
# mvc-6928                      0.882206          15.9994            8.0
# mvc-6946                      1.344760          15.9994            8.0
# mvc-7040                      1.149837          15.9994            8.0
# mvc-7383                      1.095942          15.9994            8.0
#
#              min_Atomic radius  min_Atomic radius calculated  \
# material_id
# mp-1001034                1.15                          1.03
# mp-1001780                1.00                          0.88
# mp-1001786                1.00                          0.88
# mp-1002124                0.70                          0.67
# mp-1004528                0.50                          0.42
# ...                        ...                           ...
# mvc-6916                  0.60                          0.48
# mvc-6928                  0.60                          0.48
# mvc-6946                  0.60                          0.48
# mvc-7040                  0.60                          0.48
# mvc-7383                  0.60                          0.48
#
#              min_Boiling point  min_Bulk modulus  min_Critical temperature  \
# material_id
# mp-1001034              958.00          8.300000               1285.517647
# mp-1001780              717.87          7.700000               1285.517647
# mp-1001786              717.87          7.700000               1285.517647
# mp-1002124             4300.00         33.000000               1285.517647
# mp-1004528               85.03          1.600000                144.000000
# ...                        ...               ...                       ...
# mvc-6916                 90.20         45.000000                154.600000
# mvc-6928                 90.20         17.000000                154.600000
# mvc-6946                 90.20         58.000000                154.600000
# mvc-7040                 90.20         91.644118                154.600000
# mvc-7383                 90.20         70.000000                154.600000
#
#              min_Density of solid  min_Liquid range  min_Melting point  \
# material_id
# mp-1001034            1738.000000            440.00             429.75
# mp-1001780            1960.000000            329.51             388.36
# mp-1001786             535.000000            329.51             388.36
# mp-1002124            2267.000000            500.00            2506.00
# mp-1004528            1879.000000             31.50              53.53
# ...                           ...               ...                ...
# mvc-6916              1738.000000             35.40              54.80
# mvc-6928              1550.000000             35.40              54.80
# mvc-6946              7310.000000             35.40              54.80
# mvc-7040              8067.890411             35.40              54.80
# mvc-7383              7140.000000             35.40              54.80
#
#              min_Poissons ratio  min_Thermal conductivity  \
# material_id
# mp-1001034             0.290000                   0.52000
# mp-1001780             0.260000                   0.20500
# mp-1001786             0.280000                   0.20500
# mp-1002124             0.294269                  23.00000
# mp-1004528             0.294269                   0.02770
# ...                         ...                       ...
# mvc-6916               0.290000                   0.02658
# mvc-6928               0.290000                   0.02658
# mvc-6946               0.294269                   0.02658
# mvc-7040               0.294269                   0.02658
# mvc-7383               0.210000                   0.02658
#
#              min_Van der waals radius  min_Velocity of sound  \
# material_id
# mp-1001034                       1.73            1215.000000
# mp-1001780                       1.80            3570.000000
# mp-1001786                       1.80            3723.001515
# mp-1002124                       1.70            3010.000000
# mp-1004528                       1.47            1260.000000
# ...                               ...                    ...
# mvc-6916                         1.52             317.500000
# mvc-6928                         1.52             317.500000
# mvc-6946                         1.52             317.500000
# mvc-7040                         1.52             317.500000
# mvc-7383                         1.52             317.500000
#
#              min_Vickers hardness  min_X  min_Youngs modulus  \
# material_id
# mp-1001034            2108.307692   1.31           10.000000
# mp-1001780             369.000000   1.27           69.000000
# mp-1001786            2108.307692   0.98            4.900000
# mp-1002124            1760.000000   1.30           78.000000
# mp-1004528            2108.307692   0.79            1.700000
# ...                           ...    ...                 ...
# mvc-6916              2108.307692   1.31           45.000000
# mvc-6928               608.000000   1.00           20.000000
# mvc-6946              2108.307692   1.96           50.000000
# mvc-7040              2108.307692   1.90          111.786885
# mvc-7383              1060.000000   1.65          108.000000
#
#              min_Metallic radius  min_Electron affinity  max_Atomic mass  \
# material_id
# mp-1001034              1.600000              -0.420000       114.818000
# mp-1001780              1.278000               0.238870       174.967000
# mp-1001786              1.520000               0.188200        44.955912
# mp-1002124              1.580000               0.178070       178.490000
# mp-1004528              1.622591               0.279723       207.200000
# ...                          ...                    ...              ...
# mvc-6916                1.292000              -0.520000        54.938045
# mvc-6928                1.277000               0.024551        55.845000
# mvc-6946                1.580000               1.112070       118.710000
# mvc-7040                1.375000               0.060397       186.207000
# mvc-7383                1.285000              -0.620000        65.409000
#
#              max_Atomic no  max_Atomic radius  max_Atomic radius calculated  \
# material_id
# mp-1001034            49.0               1.55                          1.56
# mp-1001780            71.0               1.75                          2.17
# mp-1001786            21.0               1.60                          1.84
# mp-1002124            72.0               1.55                          2.08
# mp-1004528            82.0               2.60                          2.98
# ...                    ...                ...                           ...
# mvc-6916              25.0               1.50                          1.61
# mvc-6928              26.0               1.80                          1.94
# mvc-6946              50.0               1.45                          1.45
# mvc-7040              75.0               1.35                          1.88
# mvc-7383              30.0               1.40                          1.66
#
#              max_Boiling point  max_Bulk modulus  max_Critical temperature  \
# material_id
# mp-1001034              2345.0         91.644118               1766.000000
# mp-1001780              3675.0        140.000000               1314.000000
# mp-1001786              3103.0         57.000000               3223.000000
# mp-1002124              4876.0        110.000000               1285.517647
# mp-1004528              4200.0        320.000000               1938.000000
# ...                        ...               ...                       ...
# mvc-6916                2334.0        120.000000               1285.517647
# mvc-6928                3134.0        170.000000               1285.517647
# mvc-6946                2875.0         91.644118               1285.517647
# mvc-7040                5869.0        370.000000               1285.517647
# mvc-7383                2944.0        160.000000               1285.517647
#
#              max_Density of solid  max_Liquid range  max_Melting point  \
# material_id
# mp-1001034            7310.000000           1915.25             923.00
# mp-1001780            9841.000000           1842.23            1925.00
# mp-1001786            2985.000000           1289.00            1814.00
# mp-1002124           13310.000000           2370.00            3800.00
# mp-1004528           11340.000000           1851.00            2349.00
# ...                           ...               ...                ...
# mvc-6916              8067.890411            815.00            1519.00
# mvc-6928              8067.890411           1323.00            1811.00
# mvc-6946              8067.890411           2369.92             505.08
# mvc-7040             21020.000000           2410.00            3459.00
# mvc-7383              8067.890411            764.00            2180.00
#
#              max_Poissons ratio  max_Thermal conductivity  \
# material_id
# mp-1001034             0.330000                     160.0
# mp-1001780             0.340000                     400.0
# mp-1001786             0.294269                      85.0
# mp-1002124             0.370000                     140.0
# mp-1004528             0.440000                      36.0
# ...                         ...                       ...
# mvc-6916               0.294269                     160.0
# mvc-6928               0.310000                     200.0
# mvc-6946               0.360000                      67.0
# mvc-7040               0.300000                      48.0
# mvc-7383               0.294269                     120.0
#
#              max_Van der waals radius  max_Velocity of sound  \
# material_id
# mp-1001034                       1.93            4602.000000
# mp-1001780                       2.24            3723.001515
# mp-1001786                       2.15            6000.000000
# mp-1002124                       2.23           18350.000000
# mp-1004528                       3.43           16200.000000
# ...                               ...                    ...
# mvc-6916                         2.05            5150.000000
# mvc-6928                         2.31            4910.000000
# mvc-6946                         2.17            2500.000000
# mvc-7040                         2.16            4700.000000
# mvc-7383                         2.06            5940.000000
#
#              max_Vickers hardness  max_X  max_Youngs modulus  \
# material_id
# mp-1001034            2108.307692   2.55           45.000000
# mp-1001780            2108.307692   2.58          130.000000
# mp-1001786            2108.307692   2.58          111.786885
# mp-1002124            2108.307692   2.55          111.786885
# mp-1004528           49000.000000   3.98          111.786885
# ...                           ...    ...                 ...
# mvc-6916              2108.307692   3.44          198.000000
# mvc-6928              2108.307692   3.44          211.000000
# mvc-6946              2108.307692   3.44          111.786885
# mvc-7040              2450.000000   3.44          463.000000
# mvc-7383              2108.307692   3.44          279.000000
#
#              max_Metallic radius  max_Electron affinity
# material_id
# mp-1001034              1.670000               2.020605
# mp-1001780              1.735000               2.077105
# mp-1001786              1.641000               2.077105
# mp-1002124              1.622591               1.262114
# mp-1004528              2.719000               3.401190
# ...                          ...                    ...
# mvc-6916                1.622591               1.461105
# mvc-6928                1.976000               1.461105
# mvc-6946                1.622591               1.461105
# mvc-7040                1.622591               1.461105
# mvc-7383                1.622591               1.461105
#
# [5614 rows x 65 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(design_matrix, 
                                                    train_filt,
                                                    test_size=0.1, 
                                                    random_state=42)

# %% [markdown]
# # Test Data Querying

# %%
# Using material IDs provided in training data to get corresponding information from MPD
data = mpr.query(criteria={"task_id": {"$in":test["material_id"].to_list()}}, properties=["material_id","energy",
        "energy_per_atom",
        "volume",
        "formation_energy_per_atom",
        "nsites",
        "pretty_formula",                                                                                  
        "nelements",
        "density",  "band_gap"])
df_X = pd.DataFrame(data)
display(df_X)
# Out:
# 0 of 1400 done 0.0%
# 500 of 1400 done 35.7%
# 1000 of 1400 done 71.4%
# 1400 of 1400 done 100.0%
#      material_id      energy  energy_per_atom      volume  \
# 0        mp-1000   -8.646946        -4.323473   89.091084
# 1       mp-10044  -11.376365        -5.688183   27.982045
# 2       mp-10086  -42.877615        -7.146269   99.212472
# 3     mp-1008858  -16.665812        -5.555271   80.958490
# 4     mp-1008867  -11.760729        -3.920243   38.301187
# ...          ...         ...              ...         ...
# 1395    mvc-5908  -73.434572        -7.343457  120.736933
# 1396    mvc-5921  -64.816637        -6.481664  143.204106
# 1397    mvc-7386 -129.945458        -6.497273  386.834593
# 1398    mvc-7701 -147.825353        -5.685591  330.380852
# 1399    mvc-7761 -165.292243        -6.357394  383.421127
#
#       formation_energy_per_atom  nsites pretty_formula  nelements   density  \
# 0                     -1.792337       2           BaTe          2  4.937886
# 1                     -0.019233       2            BAs          2  5.087631
# 2                     -3.359731       6            YSF          3  4.685387
# 3                     -0.944922       3         NdBiPd          3  9.427722
# 4                     -0.701211       3          NaCuO          3  4.445388
# ...                         ...     ...            ...        ...       ...
# 1395                  -2.771448      10       Ca2CrWO6          4  5.666228
# 1396                  -2.354943      10       Mg2SnWO6          4  5.185052
# 1397                  -1.936434      20        ZnMo2O7          3  3.170408
# 1398                  -1.957811      26       Zn2Sn3O8          3  6.181576
# 1399                  -2.515768      26       Ca2Sn3O8          3  4.887634
#
#       band_gap
# 0       1.8555
# 1       1.2522
# 2       1.3137
# 3       0.0900
# 4       0.0017
# ...        ...
# 1395    1.6101
# 1396    2.2892
# 1397    3.7020
# 1398    1.2507
# 1399    2.0677
#
# [1400 rows x 10 columns]

# %%
# Remove noble gases 
filt_data_X = df_X

# #Iterating through data and using pandas drop function to filter out materials containing noble gas elements 
# for i in nobles:
#     filt_data_X = filt_data_X.drop(filt_data_X[filt_data_X['pretty_formula'].str.contains(i)].index)
    
        
# n = len(filt_data_X)
# print(f'There are {n} materials left')    
# display(filt_data_X)


# print(f'There are {n} materials left')    
# display(filt_data_X)

# %%
filt_data_X
filt_data_X['Composition']
# Out:
# 0                    (Ba, Te)
# 1                     (B, As)
# 2                   (Y, S, F)
# 3                (Nd, Bi, Pd)
# 4                 (Na, Cu, O)
# 5                (Be, Si, As)
# 6             (Na, Sr, Ga, P)
# 7                     (Zr, C)
# 8              (Na, Co, P, O)
# 9                         (P)
# 10                (Zr, Zn, N)
# 11               (Na, Al, Se)
# 12                 (Hf, S, N)
# 13                 (K, In, O)
# 14                   (Mg, Se)
# 15            (Ca, Ga, Ge, H)
# 16                (Li, Zn, P)
# 17               (Ca, Be, As)
# 18              (Cs, H, S, O)
# 19                 (K, Mg, P)
# 20                 (Al, B, N)
# 21        (Ba, Sr, Mg, Si, O)
# 22                (Ca, Si, N)
# 23                (Ce, Zr, O)
# 24                (La, Si, N)
# 25              (Li, P, N, O)
# 26            (Li, Ca, Al, N)
# 27                 (Mg, S, O)
# 28              (Y, Si, P, O)
# 29                  (Y, P, O)
# 30                (Cd, S, Cl)
# 31                  (Y, O, F)
# 32             (K, Cu, Cl, F)
# 33                    (Te, W)
# 34               (Cs, Ca, Br)
# 35                (Nb, Cl, O)
# 36         (Te, Mo, W, Se, S)
# 37                (Ca, Zn, N)
# 38                 (V, Zn, N)
# 39                (Sr, Zr, N)
# 40                (Li, Sn, N)
# 41                (Zn, Sb, N)
# 42                (Li, Sn, N)
# 43                (Mg, Nb, N)
# 44                (Na, Mo, N)
# 45                (Li, In, N)
# 46                 (Li, Y, N)
# 47                (Mg, Re, N)
# 48                 (Y, Si, N)
# 49                 (Sr, W, N)
# 50                (Hf, Mg, N)
# 51                 (K, Re, N)
# 52                 (K, Os, N)
# 53                 (Rb, W, N)
# 54            (Sr, Ge, Te, O)
# 55                    (Nb, O)
# 56            (Na, Sr, Sb, O)
# 57             (Li, Sc, P, O)
# 58                    (Cs, H)
# 59                (Ba, Li, P)
# 60                (Y, Tl, Te)
# 61               (Sr, Mg, Bi)
# 62                 (Al, P, S)
# 63               (Cs, Pd, Cl)
# 64          (K, Zn, B, Cl, O)
# 65                (Na, Nb, O)
# 66               (Ba, Zn, As)
# 67               (Ba, Zn, Sb)
# 68                (Li, Au, F)
# 69                (K, As, Pt)
# 70                    (Cs, S)
# 71            (Ba, Ta, In, O)
# 72            (K, Cd, Sn, Se)
# 73            (Sr, Zn, As, F)
# 74                (Cs, Sr, I)
# 75                (Ag, Sn, F)
# 76                (K, Bi, Au)
# 77                 (K, Zn, P)
# 78               (Nb, Co, Sn)
# 79                    (Cd, S)
# 80                (Li, Ga, H)
# 81                (Cs, Ag, O)
# 82               (Ta, Sn, Rh)
# 83             (Rb, Cd, N, O)
# 84               (Sr, Li, As)
# 85                (Na, Al, F)
# 86                (Sc, Ag, O)
# 87                 (P, Os, S)
# 88               (Hf, Tl, Se)
# 89             (Ba, B, Cl, F)
# 90            (Ba, Sc, Cu, S)
# 91         (Ba, Li, Mn, V, O)
# 92                    (P, Os)
# 93               (Cs, Ge, Se)
# 94                 (Ca, H, F)
# 95            (Hg, Bi, S, Cl)
# 96                (Cs, Au, S)
# 97                (Na, Ge, P)
# 98                (Ba, Hf, S)
# 99               (Tl, Hg, Se)
# 100               (Ba, Ga, P)
# 101            (Ba, Ir, C, N)
# 102               (Li, Al, S)
# 103           (Cs, Y, Hg, Se)
# 104          (Cs, Ag, Sb, Cl)
# 105           (Cs, Tl, Ag, F)
# 106           (Cs, Sc, Ag, F)
# 107           (Cs, Ga, Ag, F)
# 108           (Cs, In, Ag, F)
# 109           (Rb, Ga, Ag, F)
# 110           (Rb, Al, Ag, F)
# 111           (Rb, Li, In, F)
# 112           (Rb, Li, Sb, F)
# 113               (Ca, P, Ir)
# 114                (Cs, W, N)
# 115                (K, Sn, S)
# 116              (Cs, Hf, Cl)
# 117                (K, Zn, S)
# 118                (K, V, Se)
# 119              (Li, Ga, Se)
# 120               (Rb, Pd, S)
# 121                   (Si, C)
# 122                   (Rb, F)
# 123                (Na, P, O)
# 124             (Na, P, S, O)
# 125               (Cs, Br, O)
# 126               (Cs, Ti, O)
# 127               (Cs, Cd, H)
# 128            (Cs, As, H, O)
# 129                   (Mg, S)
# 130               (K, Ni, Se)
# 131              (Rb, Sb, Se)
# 132           (Ca, Sc, Sb, O)
# 133           (Ca, Cr, Sb, O)
# 134              (La, Sb, Au)
# 135               (Ca, Se, O)
# 136               (Li, Sn, S)
# 137           (Na, Nb, Se, O)
# 138            (Ba, Cd, B, O)
# 139           (Cu, Ni, Sb, S)
# 140               (Mg, Be, N)
# 141          (Rb, Ta, Cu, Se)
# 142               (Cs, Y, Cl)
# 143            (Li, Mg, H, N)
# 144                (Ti, I, O)
# 145              (Ca, Al, As)
# 146           (Ba, Pd, Se, O)
# 147               (Cs, Fe, O)
# 148               (Ta, Sb, O)
# 149               (Cs, Br, O)
# 150               (Li, Sn, F)
# 151           (La, Bi, Cl, O)
# 152               (K, Te, Pd)
# 153           (Cs, Rb, Cu, F)
# 154           (Sr, Ti, Mn, O)
# 155               (Ca, H, Os)
# 156              (Zr, Sb, Pt)
# 157            (V, Cd, Bi, O)
# 158               (Tl, Ge, F)
# 159           (Sr, Al, Se, O)
# 160           (Sr, Li, Cr, F)
# 161               (Sr, Hf, S)
# 162           (Sr, Sc, Ta, O)
# 163              (Sb, Se, Br)
# 164            (Rb, Cr, S, O)
# 165               (Rb, Cd, O)
# 166               (Pd, Pb, F)
# 167            (Na, Cr, P, S)
# 168                (Na, I, O)
# 169               (Na, Re, O)
# 170           (Li, Mn, Ge, O)
# 171               (Li, Ca, P)
# 172             (K, Y, Be, F)
# 173              (K, Y, C, O)
# 174               (K, Ca, Cl)
# 175                (K, Bi, F)
# 176           (Ti, Ni, Ge, O)
# 177                (K, Cr, S)
# 178               (Ba, Sn, S)
# 179              (Re, Mo, Se)
# 180           (Rb, Mn, Cu, S)
# 181           (Rb, Al, Ni, F)
# 182           (Rb, Sb, Mo, O)
# 183             (Rb, W, O, F)
# 184               (Na, La, S)
# 185           (Na, La, Mo, O)
# 186            (Na, Bi, I, O)
# 187            (Na, V, Bi, O)
# 188           (Na, Ge, Pb, S)
# 189          (Mn, Cr, Cd, Se)
# 190            (Mg, Mn, B, O)
# 191               (Ca, Te, O)
# 192           (Mg, Mn, Ni, O)
# 193               (Li, Fe, F)
# 194               (Li, Au, O)
# 195            (Li, As, S, I)
# 196           (Li, Mg, Cd, P)
# 197                (K, Bi, S)
# 198          (In, Ag, Ge, Se)
# 199               (Cs, Ti, F)
# 200           (Cs, Li, Zn, S)
# 201           (Cs, Mg, Al, F)
# 202                (Co, P, S)
# 203           (Cs, Ge, Te, O)
# 204           (Cr, Co, Sb, O)
# 205               (Sr, Cu, F)
# 206              (Bi, Te, Ir)
# 207           (Ba, Ga, Si, S)
# 208        (Ba, Al, Si, N, O)
# 209            (Ba, Bi, N, O)
# 210                (Al, B, C)
# 211              (As, Ir, Se)
# 212            (Sr, Y, Ta, O)
# 213                   (Mo, O)
# 214                (Ag, P, S)
# 215               (Ca, Te, N)
# 216               (Ba, Sb, N)
# 217                   (Pt, O)
# 218          (Cu, Hg, Ge, Se)
# 219            (Al, Fe, W, O)
# 220           (Ba, La, Ta, O)
# 221                  (Co, Sb)
# 222                 (K, Y, F)
# 223              (Ho, Ge, Au)
# 224                (Cd, B, O)
# 225              (Zr, Ge, Te)
# 226                (Y, Ge, O)
# 227               (Tl, Pt, O)
# 228               (Ba, Ge, O)
# 229                   (Pd, F)
# 230               (Sr, Cu, O)
# 231                   (Zn, P)
# 232              (Cd, Ga, Te)
# 233           (Cd, Cu, Ge, S)
# 234               (Cd, Pd, F)
# 235               (Li, Pd, F)
# 236               (Cs, Pt, S)
# 237           (Na, Tl, Rh, F)
# 238           (Rb, Na, Rh, F)
# 239             (K, Mg, P, O)
# 240               (Cs, Al, O)
# 241              (Al, Ag, Se)
# 242               (Li, Rh, O)
# 243                (K, Hf, F)
# 244                (K, Th, F)
# 245              (Tl, Si, Se)
# 246                   (Sr, P)
# 247              (Cs, Ni, Se)
# 248           (Rb, Li, As, O)
# 249                (As, P, O)
# 250               (Sb, As, O)
# 251            (Ca, Sn, B, O)
# 252           (Pr, Be, Ge, O)
# 253               (K, Ge, Se)
# 254                (Hf, P, S)
# 255              (Ba, Si, Se)
# 256               (Sr, Nb, O)
# 257                (K, P, Au)
# 258          (Cs, Nb, Ag, Se)
# 259               (Tb, Ge, O)
# 260               (Li, Ta, N)
# 261              (Na, Mn, Se)
# 262              (Ge, Te, As)
# 263                (K, Co, S)
# 264               (Li, Nb, N)
# 265            (Cs, Ti, P, O)
# 266               (Si, P, Ru)
# 267                (Rb, B, S)
# 268               (Cs, Ca, F)
# 269            (Rb, V, Cu, S)
# 270                   (Ta, O)
# 271              (Cs, Pt, Cl)
# 272              (Cs, Pb, Cl)
# 273               (Ca, Mo, O)
# 274               (Ca, Ag, O)
# 275               (Ca, Ti, O)
# 276                  (Be, Se)
# 277              (Cs, Sn, Se)
# 278               (Mg, Sn, F)
# 279                   (Te, F)
# 280                (Ca, V, F)
# 281            (Rb, Sb, W, O)
# 282                  (Na, Se)
# 283            (K, Li, Al, F)
# 284          (Na, Ca, Al, As)
# 285                  (As, Ir)
# 286                   (Sc, C)
# 287               (Li, Y, Se)
# 288             (Zn, P, S, N)
# 289            (Sr, Al, B, O)
# 290                   (Na, P)
# 291           (Ba, Na, Nb, O)
# 292                   (Si, S)
# 293               (Tl, B, Se)
# 294              (Ba, Ca, Si)
# 295              (Li, Ca, Sb)
# 296               (Ca, Sb, O)
# 297              (Tm, Sb, Pt)
# 298              (Ga, Hg, Te)
# 299           (Ba, Ag, Te, F)
# 300       (Be, Cd, Si, Se, O)
# 301            (Li, Ca, P, O)
# 302           (Ba, La, Al, O)
# 303           (Sr, Cu, Sn, S)
# 304                   (Al, N)
# 305                   (Sb, O)
# 306                (Y, Te, O)
# 307               (K, Ge, Au)
# 308            (Cs, Tb, P, O)
# 309                  (Fe, Si)
# 310                    (K, S)
# 311           (Rb, Be, Zn, F)
# 312               (Na, Ge, F)
# 313           (K, Hg, Ge, Se)
# 314          (Pr, Si, Ag, Se)
# 315                (Er, W, O)
# 316                   (K, Te)
# 317               (Ca, Mn, N)
# 318               (Sr, Nb, N)
# 319           (Na, Zn, Si, O)
# 320            (Y, Cu, Sn, S)
# 321          (Nd, Si, Ag, Se)
# 322               (Ca, Ga, N)
# 323            (Na, Y, Si, O)
# 324            (Zn, Hg, O, F)
# 325             (Ba, V, S, O)
# 326           (Li, Nb, Zn, O)
# 327          (Tb, Cu, Sn, Se)
# 328           (Li, Ga, Si, O)
# 329               (Cd, Si, S)
# 330                   (Si, F)
# 331                   (W, Se)
# 332           (Sr, Sc, Rh, O)
# 333               (Ho, Ag, S)
# 334            (Rb, Zn, P, O)
# 335                  (Te, Ru)
# 336            (Sr, Y, Rh, O)
# 337               (K, Sn, Au)
# 338           (Tl, Zn, As, O)
# 339                (Y, Cr, O)
# 340           (Rb, Li, Cr, O)
# 341                   (Mn, O)
# 342                (Fe, P, O)
# 343           (Sr, Co, Mo, O)
# 344                 (V, P, O)
# 345            (K, Sc, Mo, O)
# 346           (Ca, Fe, Rh, O)
# 347                (V, Ag, O)
# 348                  (Si, Ru)
# 349                (K, Mo, O)
# 350                (Zn, W, O)
# 351                (Ba, V, O)
# 352              (K, V, P, O)
# 353           (Ba, Mn, Te, O)
# 354                   (Mn, O)
# 355                   (Ni, O)
# 356               (Cd, Mo, O)
# 357               (Ho, Mn, O)
# 358               (Ba, Co, O)
# 359            (Ca, Al, W, O)
# 360                (Sr, W, O)
# 361               (Co, Ag, O)
# 362               (Ca, Cr, O)
# 363               (Sr, Fe, O)
# 364             (Ba, W, O, F)
# 365               (Mg, Mn, O)
# 366                (K, Ni, O)
# 367                (Li, W, O)
# 368               (Ba, Mn, O)
# 369               (Li, Ni, O)
# 370               (Ca, Mo, O)
# 371               (Hg, Mo, O)
# 372               (Ni, As, O)
# 373                (V, Ag, O)
# 374                (K, Cr, O)
# 375                (Ca, W, O)
# 376             (Rb, V, P, O)
# 377                   (Zn, O)
# 378                (Cr, W, O)
# 379            (La, Ge, B, O)
# 380               (As, Pb, O)
# 381                   (Pb, O)
# 382               (Na, Pb, O)
# 383               (Ba, Pb, O)
# 384               (Ag, Pb, O)
# 385                   (Ru, S)
# 386              (Sr, In, Te)
# 387                (Y, Cr, B)
# 388               (Pt, Pb, F)
# 389               (Ti, Pb, O)
# 390               (Ba, In, O)
# 391              (In, Ag, Se)
# 392                   (K, Te)
# 393              (Sr, Ca, Sn)
# 394           (Dy, Be, Ge, O)
# 395              (Li, In, Te)
# 396               (Pd, Pb, F)
# 397              (Zn, In, Te)
# 398               (Ni, Pb, F)
# 399                   (Sb, O)
# 400                  (Ba, Te)
# 401                  (Sb, Se)
# 402               (Zn, In, S)
# 403               (Na, Pt, O)
# 404                (K, Pb, O)
# 405             (K, In, P, S)
# 406                  (In, Se)
# 407                (K, Pb, O)
# 408                  (In, Br)
# 409                  (Sb, Cl)
# 410                   (P, Br)
# 411                   (Cs, I)
# 412                  (Zn, Cl)
# 413                   (Cu, I)
# 414                    (K, I)
# 415                  (Cu, Cl)
# 416              (Rb, Cd, Cl)
# 417               (Cs, Br, F)
# 418               (K, Te, Br)
# 419               (Bi, Te, I)
# 420                (C, Cl, F)
# 421               (Na, Cl, O)
# 422              (Cs, Mg, Cl)
# 423               (La, Cl, O)
# 424               (K, Se, Br)
# 425               (Cs, V, Br)
# 426                (Zr, I, N)
# 427              (Rb, Sn, Cl)
# 428               (Cs, Pt, I)
# 429                (Bi, O, F)
# 430               (Si, Cl, O)
# 431             (K, As, I, O)
# 432                  (Zr, Cl)
# 433                  (Bi, Se)
# 434                  (Hg, Br)
# 435                   (Hg, I)
# 436                   (K, Cl)
# 437                   (Bi, O)
# 438                  (La, Br)
# 439                  (Be, Cl)
# 440                   (Te, I)
# 441                  (Pt, Cl)
# 442               (Hg, Cl, O)
# 443              (Cs, Mn, Cl)
# 444               (Na, Br, O)
# 445               (Bi, Pt, O)
# 446                (Bi, B, O)
# 447              (Ga, Se, Br)
# 448               (Hg, S, Cl)
# 449               (Ti, Bi, O)
# 450               (Ge, Bi, O)
# 451              (Cs, Au, Cl)
# 452              (Na, In, Cl)
# 453               (Rb, Pb, I)
# 454             (K, B, Br, O)
# 455       (Na, Ga, Si, Cl, O)
# 456                (H, Br, N)
# 457                (Li, H, N)
# 458                (K, Mg, H)
# 459                   (Si, H)
# 460             (Sm, H, C, O)
# 461            (K, Li, Al, H)
# 462                (Al, H, O)
# 463                (Na, H, N)
# 464                   (Na, H)
# 465            (Sr, Ge, H, O)
# 466                (Na, H, O)
# 467                   (Ba, S)
# 468                (Cr, H, O)
# 469               (Rb, Ca, H)
# 470              (H, S, N, O)
# 471             (Be, H, S, O)
# 472            (Rb, H, Br, O)
# 473                (Cr, H, O)
# 474            (Sr, H, Cl, O)
# 475                (Ca, H, N)
# 476                (Cs, B, H)
# 477            (Li, H, Se, O)
# 478                   (Ir, F)
# 479                (H, Cl, O)
# 480           (Na, Li, Al, H)
# 481                (Si, H, O)
# 482            (Zn, H, Se, O)
# 483                  (As, Os)
# 484             (K, H, Br, O)
# 485            (Rb, B, H, Cl)
# 486                   (Mn, O)
# 487                (Fe, P, O)
# 488                    (V, O)
# 489                (Mn, B, O)
# 490                  (Li, Te)
# 491               (Ti, Si, O)
# 492               (Li, Ni, O)
# 493          (Li, V, P, O, F)
# 494         (Li, Mn, P, O, F)
# 495                   (Te, O)
# 496                    (S, N)
# 497            (Li, Mn, P, O)
# 498                (Mn, P, O)
# 499                (Cr, P, O)
# 500            (Li, Mn, P, O)
# 501            (Li, Cu, P, O)
# 502            (Li, Cu, P, O)
# 503              (Na, Mn, Cl)
# 504               (K, Pd, Br)
# 505              (Cs, In, Cl)
# 506              (Na, Mn, Cl)
# 507                (Hg, P, S)
# 508              (Cs, Sn, Br)
# 509               (K, Pt, Br)
# 510                   (P, Br)
# 511              (Rb, Mn, Br)
# 512              (Ca, As, Br)
# 513               (Nb, S, Cl)
# 514              (Rb, Ge, Cl)
# 515                  (Ir, Br)
# 516                   (Ca, F)
# 517               (Li, Bi, F)
# 518               (Na, Bi, F)
# 519               (Li, Sb, O)
# 520                   (Y, Cl)
# 521               (Na, Fe, F)
# 522               (Na, Cd, O)
# 523               (Rb, In, O)
# 524               (Na, Mn, O)
# 525                  (Te, Cl)
# 526                  (Te, Br)
# 527                  (Ir, Cl)
# 528                (H, Cl, O)
# 529                (K, Tl, O)
# 530                (P, I, Cl)
# 531              (Rb, Zr, Cl)
# 532              (Tl, Te, Cl)
# 533              (Hg, Te, Cl)
# 534               (Ta, Cl, F)
# 535                (Ni, H, O)
# 536                  (Cd, Br)
# 537                (Tl, S, I)
# 538                   (Br, F)
# 539               (K, Cu, Sb)
# 540               (Ba, Hg, S)
# 541                   (Mn, I)
# 542                   (Tc, P)
# 543                   (S, Cl)
# 544                   (S, Br)
# 545                (Hg, I, O)
# 546              (Li, Mn, Br)
# 547                (Rb, H, O)
# 548                   (P, Pd)
# 549                  (Mn, Br)
# 550                   (Rb, I)
# 551                   (Li, P)
# 552                  (Si, Cl)
# 553               (K, Tc, Cl)
# 554                (H, Pb, O)
# 555               (Ba, Br, O)
# 556              (Rb, Sn, Te)
# 557                (Si, H, I)
# 558               (Eu, Cl, O)
# 559               (Li, Ge, O)
# 560              (Ag, Pd, Cl)
# 561              (Rb, Pb, Br)
# 562               (Li, Bi, F)
# 563                (Y, N, Cl)
# 564                (Cs, B, H)
# 565               (K, Na, Se)
# 566               (Ba, Bi, O)
# 567                 (S, O, F)
# 568              (Cu, Se, Br)
# 569                (Y, H, Se)
# 570               (Rb, Br, O)
# 571              (Hg, As, Br)
# 572               (Al, Fe, F)
# 573               (Li, Br, N)
# 574                (Ta, I, O)
# 575                   (K, Sb)
# 576               (Ba, Si, N)
# 577              (Nb, Si, Te)
# 578               (Al, Zn, O)
# 579               (Ag, Te, S)
# 580               (Hg, Au, F)
# 581                (Au, C, N)
# 582                 (Y, B, O)
# 583               (La, Tl, O)
# 584               (Si, H, Se)
# 585               (Cu, Pb, O)
# 586                  (Hf, Cl)
# 587               (Na, Tl, O)
# 588               (Rb, Cl, O)
# 589               (Cs, Bi, O)
# 590               (Cs, Xe, F)
# 591               (Li, Au, I)
# 592               (K, Be, As)
# 593               (K, Cd, As)
# 594                (Sn, O, F)
# 595                (Na, P, N)
# 596                (Ca, P, O)
# 597               (Sr, Pd, O)
# 598               (Ca, Ge, N)
# 599               (Ag, Hg, O)
# 600              (Cs, Hg, Cl)
# 601                (K, Re, H)
# 602                (V, Re, O)
# 603               (Cs, Cl, O)
# 604                (K, Bi, O)
# 605                  (Be, Br)
# 606                (Si, C, N)
# 607                (Y, Ag, O)
# 608                 (Y, P, O)
# 609              (Sr, Li, Bi)
# 610                    (B, O)
# 611               (Ag, P, Se)
# 612               (Mg, P, Se)
# 613               (Sr, Si, O)
# 614                (Na, Y, O)
# 615                (Ba, I, O)
# 616                (La, I, O)
# 617                  (Rb, Te)
# 618               (Ta, Cu, S)
# 619               (Ba, Zr, N)
# 620                   (Ag, S)
# 621               (La, Sc, O)
# 622               (Na, Co, O)
# 623               (Ca, Bi, N)
# 624                (K, Fe, O)
# 625                (In, P, O)
# 626                  (Ba, As)
# 627                (K, Zn, F)
# 628                 (C, O, F)
# 629                  (Rb, Ga)
# 630              (Li, Al, Si)
# 631              (Hg, Ge, Se)
# 632               (Li, Zr, N)
# 633               (Cs, Ti, S)
# 634                   (H, Br)
# 635                   (Cu, I)
# 636               (Fe, Cu, O)
# 637               (Na, Ga, O)
# 638              (Ba, Pr, Se)
# 639                (Y, Sn, O)
# 640              (Bi, Te, Br)
# 641              (Er, Ag, Se)
# 642               (Ba, P, Br)
# 643               (K, Na, As)
# 644               (Na, Al, F)
# 645              (Zn, In, Se)
# 646               (Cs, Ta, N)
# 647                    (B, N)
# 648               (Ag, Au, S)
# 649               (Zn, Ga, S)
# 650               (Pr, Ag, S)
# 651               (K, Sn, As)
# 652               (Ag, Au, S)
# 653                (Zr, S, O)
# 654                   (Hf, O)
# 655                (Li, P, N)
# 656               (Zn, Pt, O)
# 657                (Zn, C, N)
# 658              (La, Tl, Te)
# 659                   (Cu, O)
# 660                (Na, H, S)
# 661                 (P, S, O)
# 662               (Al, Cd, O)
# 663               (Pr, Cd, S)
# 664              (Sr, Al, Te)
# 665               (Ag, As, F)
# 666                (Sm, O, F)
# 667               (Li, Nb, O)
# 668               (Na, Nb, O)
# 669               (Li, N, Cl)
# 670               (Mg, Ge, O)
# 671                (V, Cu, S)
# 672               (Ca, Si, O)
# 673               (Mg, Ti, O)
# 674              (La, Tl, Se)
# 675               (Li, Mg, N)
# 676                (Al, P, O)
# 677                 (K, H, S)
# 678               (Hg, As, O)
# 679               (Sr, Pr, S)
# 680                (Mg, I, O)
# 681               (Ca, Tb, S)
# 682              (Ba, Al, Te)
# 683               (Li, Bi, O)
# 684               (Na, Be, F)
# 685               (Ga, As, O)
# 686         (Si, Ni, H, O, F)
# 687                   (Cd, P)
# 688                (K, Cr, S)
# 689                (Al, P, O)
# 690              (Ta, Cu, Se)
# 691         (Na, Ti, P, O, F)
# 692       (Ba, Li, Pr, Te, O)
# 693        (Na, Al, Si, S, O)
# 694                (Ge, N, O)
# 695         (K, Na, Ti, O, F)
# 696        (Na, Ca, Nb, O, F)
# 697               (Ba, Zn, O)
# 698               (Ga, Cu, O)
# 699      (K, Cu, H, N, Cl, O)
# 700               (Ba, Ga, S)
# 701               (Sr, Pd, O)
# 702               (Na, Cd, F)
# 703               (Rb, Au, O)
# 704               (Na, Nb, O)
# 705               (K, Li, Te)
# 706                (Si, N, O)
# 707               (Na, Nb, O)
# 708                (Na, N, O)
# 709               (Na, Cu, O)
# 710              (Li, Al, Te)
# 711               (Sr, Ti, O)
# 712                (Ag, C, O)
# 713                (Na, S, O)
# 714               (Li, Te, O)
# 715               (Ga, Hg, S)
# 716               (Y, Sb, Pt)
# 717                (Mg, B, O)
# 718                   (As, S)
# 719               (Ba, Ti, O)
# 720               (K, Cd, Pb)
# 721              (Li, Ga, Te)
# 722           (Ba, Fe, Si, O)
# 723                (K, Ni, O)
# 724            (Er, Cu, W, O)
# 725            (Li, Cr, H, O)
# 726         (Cs, Sb, S, O, F)
# 727              (Nb, Sb, Ru)
# 728              (Co, As, Se)
# 729                (Pb, C, O)
# 730               (Li, Re, O)
# 731              (Na, Li, Sb)
# 732               (Cs, Au, O)
# 733               (Rb, Au, O)
# 734               (Fe, Cu, O)
# 735              (Cs, Ge, Au)
# 736                   (Cs, N)
# 737           (Li, Co, Si, O)
# 738               (Cd, Ge, S)
# 739                (K, Be, F)
# 740               (Cd, Sn, P)
# 741                (K, Nb, O)
# 742                (Ca, B, N)
# 743               (Ga, Ag, S)
# 744               (Cs, Cr, S)
# 745            (K, Ta, Ge, O)
# 746           (Rb, Nb, Ge, O)
# 747           (Ba, Sn, Ge, O)
# 748                   (Pb, I)
# 749                (B, Pd, O)
# 750               (Cs, Te, I)
# 751              (Ca, Ga, As)
# 752            (Zr, Pb, O, F)
# 753              (Al, Ga, Cl)
# 754           (Ba, La, Ga, O)
# 755               (Cs, Bi, S)
# 756                 (K, S, O)
# 757               (Zn, In, S)
# 758             (Na, P, S, O)
# 759                      (Se)
# 760                (K, B, Se)
# 761                  (Ga, Te)
# 762               (Ba, Te, O)
# 763              (K, V, S, O)
# 764                   (Sn, O)
# 765               (Ag, Sb, O)
# 766               (Cr, Bi, O)
# 767                (Li, C, O)
# 768             (Na, C, N, O)
# 769                (K, Cr, O)
# 770             (Sn, P, O, F)
# 771               (Tl, Pd, O)
# 772            (Ba, Zn, S, O)
# 773            (Ba, Zn, W, O)
# 774               (Li, In, O)
# 775           (La, Zn, As, O)
# 776                   (Mg, O)
# 777                (Nb, I, O)
# 778                (V, Cd, O)
# 779                (Sr, I, O)
# 780            (Y, Bi, Cl, O)
# 781           (Ca, Bi, Cl, O)
# 782            (Y, Bi, Br, O)
# 783               (Nd, Se, O)
# 784         (Cs, Be, B, O, F)
# 785            (Li, Re, O, F)
# 786               (Rb, Cr, F)
# 787            (Rb, Ta, P, O)
# 788             (P, N, Cl, F)
# 789             (Mg, B, O, F)
# 790               (Cu, Ge, S)
# 791               (Ba, Br, O)
# 792          (K, Sb, S, O, F)
# 793       (Li, Al, Ge, Br, O)
# 794               (Na, Zn, O)
# 795            (K, Al, Sb, O)
# 796           (Rb, Na, Au, O)
# 797            (Ba, Be, B, O)
# 798             (K, Ta, B, O)
# 799                (Li, C, O)
# 800            (Cs, Nb, P, O)
# 801                 (P, N, F)
# 802                   (As, O)
# 803                       (S)
# 804               (Li, As, S)
# 805               (Si, Sn, O)
# 806            (Rb, Tl, S, O)
# 807           (Rb, Na, Ti, O)
# 808                 (H, I, O)
# 809            (Ca, Ta, N, O)
# 810               (Ta, Sn, O)
# 811                   (Mn, F)
# 812             (K, Sb, P, S)
# 813           (Na, Sr, Fe, F)
# 814                   (Hg, O)
# 815                   (Si, O)
# 816                   (Fe, F)
# 817             (K, Sr, V, O)
# 818                   (Li, S)
# 819               (Ta, Pb, F)
# 820                 (K, V, F)
# 821                   (Zn, S)
# 822            (Na, Ca, C, O)
# 823               (Li, Fe, F)
# 824            (Ba, Si, N, O)
# 825                   (Si, O)
# 826            (Li, Ca, B, O)
# 827                   (Mo, F)
# 828                   (Si, O)
# 829                (Zr, V, F)
# 830            (K, Cd, Au, S)
# 831                    (N, O)
# 832             (K, Ni, P, O)
# 833               (Cs, Mn, F)
# 834        (Ca, Mg, As, O, F)
# 835             (Sr, B, P, O)
# 836           (Sm, Cu, Sn, S)
# 837                   (Rb, S)
# 838            (K, Li, Si, O)
# 839            (K, Rb, Mn, F)
# 840             (P, Cl, O, F)
# 841               (Li, Te, S)
# 842               (Rb, Mn, F)
# 843             (Bi, B, O, F)
# 844           (Li, Al, Si, O)
# 845             (K, Nb, B, O)
# 846           (Na, Ni, As, O)
# 847            (Li, Mo, I, O)
# 848                   (Si, O)
# 849           (Na, Zr, Cu, F)
# 850               (Cd, In, S)
# 851            (Sr, Ca, C, O)
# 852           (Ca, Al, Si, O)
# 853           (Li, Bi, Pd, O)
# 854                 (P, N, F)
# 855                   (Ag, S)
# 856           (Sr, Fe, Se, O)
# 857                (Al, P, O)
# 858           (Ba, Mg, Si, O)
# 859                   (Si, O)
# 860                   (Cr, F)
# 861                   (Zn, S)
# 862           (Re, Pb, Cl, O)
# 863            (K, Cu, Si, O)
# 864                   (Se, O)
# 865           (Rb, Na, Cr, F)
# 866            (Cs, K, Cr, F)
# 867               (Rb, Si, O)
# 868               (Na, Mn, F)
# 869               (Rb, Ni, F)
# 870               (Co, Sn, F)
# 871           (Na, Zr, Ag, F)
# 872                (Ca, C, O)
# 873           (Na, Fe, Se, O)
# 874            (Cs, K, Rh, F)
# 875           (Sr, Co, Te, O)
# 876                   (Te, F)
# 877               (Cs, Sn, S)
# 878           (Na, Co, Au, O)
# 879               (Cs, Ag, S)
# 880               (Cs, Ta, O)
# 881               (Nb, Cu, S)
# 882            (Cs, Mo, O, F)
# 883               (Na, Pb, O)
# 884               (Na, P, Se)
# 885                      (Te)
# 886                   (Pb, I)
# 887                   (Ge, I)
# 888               (Nb, Te, I)
# 889                   (Ag, I)
# 890              (Hf, Ge, Te)
# 891                (Cd, S, O)
# 892                   (I, Cl)
# 893           (Ca, Al, Si, H)
# 894             (K, Na, B, H)
# 895               (Ca, Ti, N)
# 896                   (Si, C)
# 897                  (Cd, Br)
# 898           (K, Sn, Ir, Cl)
# 899                  (Zr, Cl)
# 900                   (Mn, P)
# 901              (Cs, Au, Br)
# 902          (Tl, Hg, Pd, Cl)
# 903           (Hg, As, Se, I)
# 904                (Na, C, N)
# 905                  (Mg, Cl)
# 906                  (Sn, As)
# 907          (Cs, Ti, Cu, Se)
# 908              (Ag, Te, Au)
# 909                  (Mn, Br)
# 910                  (Zn, Te)
# 911           (Ca, Zn, Cu, P)
# 912                   (Sn, I)
# 913                    (Y, I)
# 914               (K, Sn, Cl)
# 915               (K, Zn, As)
# 916                  (Cs, Cl)
# 917              (Cs, Au, Se)
# 918               (Na, Mo, O)
# 919               (Ca, Mg, N)
# 920                   (Ag, I)
# 921            (Li, Mn, P, O)
# 922               (Li, Si, N)
# 923                (Al, P, O)
# 924              (Tl, Ag, Te)
# 925                (K, Zn, F)
# 926                   (Ga, F)
# 927               (Co, Sb, S)
# 928                (K, Ca, F)
# 929               (Al, Cd, S)
# 930               (Na, Sb, F)
# 931                   (Si, O)
# 932                   (Si, O)
# 933                   (Si, O)
# 934                  (Te, Mo)
# 935              (P, H, N, O)
# 936         (Na, Fe, H, S, O)
# 937              (Cs, Li, Br)
# 938           (Ca, Mg, Si, O)
# 939              (Cs, Mn, Te)
# 940             (Hg, C, S, N)
# 941             (As, N, O, F)
# 942               (Ba, Ni, F)
# 943                   (Cs, I)
# 944                   (Mn, F)
# 945                (Cs, V, O)
# 946           (Ca, Be, Si, O)
# 947           (Cs, Nb, S, Cl)
# 948                (Re, H, O)
# 949                 (P, H, O)
# 950                 (P, H, O)
# 951                (Al, H, O)
# 952                (Nd, H, O)
# 953                (Zn, H, O)
# 954                 (H, N, O)
# 955                (Be, H, O)
# 956                (Mn, H, O)
# 957                (Fe, H, O)
# 958                 (Y, H, O)
# 959                 (P, H, O)
# 960                (Na, H, O)
# 961                (Fe, H, O)
# 962                 (K, H, O)
# 963                (H, Pt, O)
# 964           (Ba, Ti, Ge, O)
# 965                       (H)
# 966                   (H, Cl)
# 967         (Na, Te, H, O, F)
# 968              (H, C, S, N)
# 969                (Ca, P, I)
# 970              (Cs, Zr, Cl)
# 971                   (Si, O)
# 972                   (As, S)
# 973           (Na, Mg, Si, O)
# 974             (Rb, P, H, O)
# 975               (Cs, H, Pd)
# 976            (Ba, H, Br, O)
# 977                (Rb, H, O)
# 978                 (H, I, N)
# 979             (Zn, H, S, O)
# 980               (Rb, H, Pt)
# 981            (Li, H, Cl, O)
# 982             (Ba, H, I, O)
# 983             (Sr, H, I, O)
# 984               (Mg, Mn, H)
# 985             (Li, H, I, O)
# 986            (H, Pb, Br, O)
# 987             (Ga, H, N, F)
# 988             (Rb, P, H, O)
# 989               (Cs, Mg, H)
# 990           (Li, Al, Si, O)
# 991            (Cd, H, Cl, O)
# 992               (Sr, Mg, H)
# 993          (K, Al, H, C, O)
# 994                    (C, O)
# 995         (Cs, V, H, Cl, O)
# 996                   (P, Br)
# 997                   (Na, S)
# 998              (K, S, O, F)
# 999           (Sr, Mg, Si, O)
# 1000              (Yb, Be, F)
# 1001          (Sr, Li, Al, F)
# 1002            (Na, C, S, N)
# 1003          (Ba, Ti, Si, O)
# 1004                  (Si, O)
# 1005           (Li, Nb, P, O)
# 1006           (Li, Sb, P, O)
# 1007               (Cs, P, F)
# 1008              (Ca, Nb, N)
# 1009             (Li, Mn, Br)
# 1010              (Nd, Pb, S)
# 1011                (K, N, O)
# 1012               (K, Bi, F)
# 1013              (Tb, Pb, S)
# 1014               (Al, N, O)
# 1015              (Zn, Ge, S)
# 1016              (Li, Ti, P)
# 1017               (Y, Ta, O)
# 1018               (Ag, S, I)
# 1019              (Li, Br, N)
# 1020               (Li, S, O)
# 1021                (K, N, O)
# 1022              (Al, Sb, O)
# 1023      (Ba, La, Zn, Ru, O)
# 1024          (K, P, H, S, O)
# 1025             (Li, Ti, Sb)
# 1026                  (Na, F)
# 1027       (Ba, Na, Cu, C, O)
# 1028                   (H, O)
# 1029       (Cs, Ti, Nb, O, F)
# 1030                  (Sc, S)
# 1031                  (B, Br)
# 1032       (Be, Zn, Si, S, O)
# 1033              (Li, Ti, N)
# 1034        (Rb, P, H, Se, O)
# 1035         (K, Ca, C, O, F)
# 1036               (Mn, C, O)
# 1037           (Na, P, Pb, O)
# 1038                (K, N, O)
# 1039                  (Si, O)
# 1040               (K, Na, O)
# 1041                  (In, F)
# 1042              (Rb, Cd, F)
# 1043                 (Cd, Cl)
# 1044             (Rb, Si, As)
# 1045           (Li, Si, P, O)
# 1046            (H, C, N, Cl)
# 1047             (B, H, O, F)
# 1048             (B, H, O, F)
# 1049           (Cs, K, Cu, F)
# 1050              (La, H, Br)
# 1051               (K, Ga, H)
# 1052       (Li, Al, Si, H, O)
# 1053               (Y, Cu, O)
# 1054              (Sc, Cu, S)
# 1055       (Li, Al, Si, H, O)
# 1056                  (Si, O)
# 1057           (La, Zn, P, O)
# 1058            (Mg, H, I, O)
# 1059          (Cs, Sr, Ta, O)
# 1060              (Sr, Ga, N)
# 1061              (Sr, P, Se)
# 1062           (Ca, Zn, S, O)
# 1063               (Cd, B, O)
# 1064            (H, Se, N, O)
# 1065            (Be, H, N, F)
# 1066                 (Zn, As)
# 1067               (Nd, P, O)
# 1068              (Er, Ga, S)
# 1069                  (P, Pt)
# 1070       (Cs, Mg, Fe, C, N)
# 1071              (Na, Au, F)
# 1072              (Na, Sb, O)
# 1073             (Na, Cu, Te)
# 1074                 (Cs, Se)
# 1075                  (Sn, F)
# 1076              (Rb, Cu, O)
# 1077              (Li, Au, O)
# 1078               (La, B, O)
# 1079              (Na, Si, O)
# 1080              (Li, Fe, O)
# 1081               (Yb, B, O)
# 1082            (Li, V, O, F)
# 1083           (Na, Fe, P, O)
# 1084          (Li, Cr, Si, O)
# 1085               (Sb, O, F)
# 1086               (Li, V, F)
# 1087           (Li, Mn, C, O)
# 1088                  (Al, O)
# 1089       (Li, Mn, Sb, W, O)
# 1090               (Li, V, O)
# 1091              (Li, Mn, F)
# 1092               (Fe, O, F)
# 1093                (V, O, F)
# 1094        (Li, Cr, P, H, O)
# 1095               (Li, W, S)
# 1096                (V, O, F)
# 1097              (Mg, Fe, O)
# 1098              (Fe, Co, O)
# 1099          (Li, Co, Si, O)
# 1100           (Li, Mn, O, F)
# 1101              (Ca, Cd, O)
# 1102               (Dy, B, O)
# 1103           (Li, Ni, O, F)
# 1104          (Li, Cr, Si, O)
# 1105              (Ba, Ca, I)
# 1106              (Li, Co, O)
# 1107                (V, O, F)
# 1108               (Li, V, F)
# 1109               (Sb, O, F)
# 1110          (Li, Fe, Si, O)
# 1111              (Na, Mg, O)
# 1112           (Li, Fe, C, O)
# 1113           (Li, Mn, O, F)
# 1114           (K, Li, Mn, S)
# 1115              (Hg, Sb, O)
# 1116              (Tm, Cl, O)
# 1117          (Li, Bi, Cl, O)
# 1118              (Nb, Fe, O)
# 1119          (Li, Si, Ni, O)
# 1120              (Li, Cr, O)
# 1121      (Li, Zr, Nb, Te, O)
# 1122              (Ba, Hf, O)
# 1123           (Li, Ti, B, O)
# 1124            (B, Cl, O, F)
# 1125              (Li, Lu, O)
# 1126           (Li, V, Cr, O)
# 1127                  (Te, O)
# 1128              (Sr, Ca, I)
# 1129               (N, Cl, O)
# 1130              (Li, Fe, O)
# 1131                  (Al, O)
# 1132               (Hf, N, O)
# 1133           (Li, Cr, C, O)
# 1134              (Ta, As, O)
# 1135               (Ga, N, O)
# 1136              (Cr, Sb, O)
# 1137              (Li, Ta, O)
# 1138          (Li, Cr, Fe, O)
# 1139               (Cr, O, F)
# 1140               (Fe, O, F)
# 1141               (Zr, N, O)
# 1142       (Li, Nb, Fe, W, O)
# 1143           (Ta, Cr, N, O)
# 1144               (Ni, I, O)
# 1145              (Sr, Sb, O)
# 1146              (Lu, Ga, O)
# 1147              (Ba, Na, O)
# 1148              (Cd, Bi, O)
# 1149           (Na, Cu, P, O)
# 1150           (Li, Nb, O, F)
# 1151          (Li, Cr, Ga, O)
# 1152              (Mn, Sb, O)
# 1153              (Er, Ta, O)
# 1154              (Ba, Sc, O)
# 1155              (Li, Cr, O)
# 1156              (Na, As, O)
# 1157          (Li, Ti, Te, O)
# 1158              (Rb, Zr, O)
# 1159              (Ba, Sr, I)
# 1160          (Li, Mn, Fe, O)
# 1161                   (W, O)
# 1162        (Na, Ge, P, C, O)
# 1163              (Sr, Ca, I)
# 1164          (Li, Mn, Cr, O)
# 1165          (Li, Al, Co, O)
# 1166              (Rb, Sn, O)
# 1167               (In, P, O)
# 1168               (Nb, O, F)
# 1169               (Mn, P, O)
# 1170              (Mg, Mn, O)
# 1171           (Li, Zn, B, O)
# 1172              (Li, Sb, O)
# 1173                 (Li, As)
# 1174          (Li, Fe, Si, O)
# 1175    (Li, Mn, Fe, P, C, O)
# 1176               (Li, V, F)
# 1177          (Ba, Zn, Ge, O)
# 1178           (Li, Fe, P, O)
# 1179               (Hg, S, F)
# 1180            (Li, P, W, O)
# 1181              (Li, Ag, F)
# 1182                  (Ge, S)
# 1183               (Fe, O, F)
# 1184          (Li, Fe, Si, O)
# 1185          (Li, Co, Si, O)
# 1186           (Li, Sb, P, O)
# 1187          (Li, Fe, Si, O)
# 1188         (Na, H, C, N, O)
# 1189          (Li, Co, Si, O)
# 1190           (Li, Co, O, F)
# 1191          (Li, Fe, Si, O)
# 1192                   (V, F)
# 1193        (Li, Mn, P, O, F)
# 1194           (Li, Mn, P, O)
# 1195               (Fe, O, F)
# 1196           (Li, Bi, P, O)
# 1197           (Li, Mn, O, F)
# 1198              (Nb, Ga, O)
# 1199           (Li, Mn, O, F)
# 1200                (V, O, F)
# 1201               (Hf, N, O)
# 1202               (Li, V, S)
# 1203               (Lu, B, O)
# 1204                (P, N, O)
# 1205              (Li, Ag, F)
# 1206              (Li, Pd, O)
# 1207     (K, Li, Mn, P, C, O)
# 1208          (Li, Ti, Co, O)
# 1209              (Na, Bi, O)
# 1210              (Hf, Sn, O)
# 1211              (Na, Sn, O)
# 1212           (Li, Co, P, O)
# 1213           (Li, Co, B, O)
# 1214            (Li, V, P, O)
# 1215              (Na, Cu, P)
# 1216               (Cr, O, F)
# 1217          (Li, Co, Si, O)
# 1218           (Li, Mn, P, O)
# 1219                (V, O, F)
# 1220               (Mn, O, F)
# 1221          (Na, Li, Mn, O)
# 1222       (Li, V, Si, Ge, O)
# 1223                 (As, Ru)
# 1224              (Li, Sb, S)
# 1225                  (Be, H)
# 1226              (Rb, Sb, O)
# 1227              (La, Bi, O)
# 1228             (Tl, As, Se)
# 1229               (Li, V, S)
# 1230           (Li, Cr, B, O)
# 1231          (Li, Cd, Ge, O)
# 1232              (Sr, Te, O)
# 1233              (Sc, Cl, O)
# 1234          (Li, Al, Fe, O)
# 1235                  (Zn, F)
# 1236        (Na, Zn, P, C, O)
# 1237              (Rb, Cr, O)
# 1238              (Cd, Se, O)
# 1239            (Li, V, O, F)
# 1240              (Li, Cr, O)
# 1241              (Li, Cr, O)
# 1242        (Li, Mg, P, C, O)
# 1243        (Li, Yb, P, C, O)
# 1244       (Li, V, Si, Ge, O)
# 1245        (Li, Tl, P, H, O)
# 1246          (Li, Co, Sb, O)
# 1247               (W, Br, O)
# 1248              (Li, Fe, O)
# 1249              (Li, Cr, O)
# 1250            (Li, S, O, F)
# 1251               (Na, V, O)
# 1252          (Li, Nb, Cr, O)
# 1253            (Sn, P, H, O)
# 1254              (Ag, Cl, O)
# 1255                  (Sc, O)
# 1256              (Li, Sb, S)
# 1257           (Li, Mn, P, O)
# 1258           (Li, V, Cr, O)
# 1259              (Li, Fe, F)
# 1260              (Li, Fe, F)
# 1261                  (Rb, O)
# 1262              (Li, Fe, F)
# 1263          (Li, Mn, Te, O)
# 1264          (Li, Co, Si, O)
# 1265              (Sc, Pt, O)
# 1266               (Ge, N, O)
# 1267              (Cs, Cu, S)
# 1268              (Ba, Ge, O)
# 1269              (Li, Mn, F)
# 1270              (Li, Ge, F)
# 1271        (Li, Mn, P, H, O)
# 1272                   (H, N)
# 1273              (Tm, Te, O)
# 1274           (Li, Fe, O, F)
# 1275               (K, Ge, F)
# 1276                  (Cs, O)
# 1277              (Al, Hg, S)
# 1278              (Be, Si, N)
# 1279              (Rb, Ge, F)
# 1280               (K, Os, F)
# 1281              (Zr, Ge, O)
# 1282          (Li, Be, Si, O)
# 1283              (Na, Sn, F)
# 1284              (K, As, Pd)
# 1285           (Na, Hg, P, O)
# 1286                  (Hg, F)
# 1287               (K, Zn, O)
# 1288               (K, Sc, O)
# 1289                  (Ag, P)
# 1290              (Na, Zn, S)
# 1291              (Ba, Al, S)
# 1292              (Ba, Mg, P)
# 1293                  (Sn, F)
# 1294              (Ba, Sn, F)
# 1295              (Ba, Ti, F)
# 1296          (Cs, Li, Ge, O)
# 1297              (Na, Zn, S)
# 1298              (Tl, Sb, S)
# 1299               (K, Hf, F)
# 1300               (K, Li, S)
# 1301           (Li, Ti, V, O)
# 1302               (Co, P, O)
# 1303           (Li, Mn, P, O)
# 1304        (Li, Mn, V, P, O)
# 1305                   (S, F)
# 1306              (Rb, Ag, O)
# 1307             (Ca, Sb, Au)
# 1308              (K, Pt, Se)
# 1309                 (In, Cl)
# 1310              (Sb, Ir, S)
# 1311                     (Hg)
# 1312                 (Br, Cl)
# 1313            (Mn, P, H, O)
# 1314             (Na, Li, Bi)
# 1315         (Lu, Cu, Pb, Se)
# 1316                  (Ac, N)
# 1317             (Sr, Sb, Au)
# 1318             (Sr, Bi, Au)
# 1319          (Li, Sn, Te, O)
# 1320              (K, Sb, Se)
# 1321              (Rb, Mn, S)
# 1322               (K, Hg, P)
# 1323              (Ca, Zn, N)
# 1324           (Ca, Al, S, O)
# 1325                 (Al, As)
# 1326                 (Zn, Te)
# 1327              (Li, In, F)
# 1328                  (Pt, F)
# 1329              (Rb, Hg, F)
# 1330               (K, Sn, S)
# 1331          (K, Ta, Cu, Se)
# 1332           (Na, P, Pd, O)
# 1333          (K, Nb, Cu, Se)
# 1334               (Ca, V, N)
# 1335           (K, Li, Ta, O)
# 1336                 (As, Se)
# 1337          (Na, Zr, Cu, S)
# 1338              (Cd, Hg, O)
# 1339               (Mg, C, N)
# 1340            (K, Se, O, F)
# 1341              (Cu, Si, S)
# 1342             (Rb, Li, Se)
# 1343              (Cs, Pt, F)
# 1344                  (Cu, P)
# 1345             (Rb, Sb, Au)
# 1346              (Ba, Hf, S)
# 1347          (Sr, Al, Te, O)
# 1348             (Nb, Fe, Sb)
# 1349               (K, Al, F)
# 1350                 (Ge, As)
# 1351             (Li, Be, As)
# 1352              (K, Sb, Se)
# 1353               (K, Zn, F)
# 1354                  (Li, P)
# 1355             (Ti, Fe, Te)
# 1356             (Ti, Sn, Pd)
# 1357                     (Si)
# 1358          (Na, Ni, Sb, O)
# 1359                   (C, N)
# 1360                  (V, Br)
# 1361             (Rb, Au, Se)
# 1362              (Li, Se, N)
# 1363                  (Ru, F)
# 1364               (B, Pb, O)
# 1365             (Na, Sr, As)
# 1366              (Sr, Si, O)
# 1367          (Sr, Al, Ge, H)
# 1368               (Zn, C, O)
# 1369              (Cs, As, F)
# 1370           (K, Li, Al, F)
# 1371              (Ca, H, Cl)
# 1372                  (B, As)
# 1373             (Cs, Zr, Se)
# 1374              (Sb, Br, O)
# 1375               (La, W, N)
# 1376          (Rb, Na, Sb, F)
# 1377          (Cs, Tl, Ga, F)
# 1378          (Cs, Li, Tl, F)
# 1379               (Y, Mo, N)
# 1380               (Ca, W, N)
# 1381               (Ba, W, N)
# 1382               (Sr, W, N)
# 1383              (Na, Zr, O)
# 1384               (K, Sb, S)
# 1385                  (Ti, S)
# 1386              (Cr, Au, O)
# 1387               (K, Ag, O)
# 1388          (La, Al, In, O)
# 1389             (Cs, Sr, Cl)
# 1390             (In, Ge, Cl)
# 1391                      (N)
# 1392              (Ca, Cr, N)
# 1393           (Ca, Mn, W, O)
# 1394          (Zn, Sb, As, O)
# 1395           (Ca, Cr, W, O)
# 1396           (Mg, Sn, W, O)
# 1397              (Zn, Mo, O)
# 1398              (Zn, Sn, O)
# 1399              (Ca, Sn, O)
# Name: Composition, dtype: object

# %%
listA_X = [a for a in filt_data_X["pretty_formula"]]
listB_X = [Composition(a) for a in listA_X]
listC_X = [a.elements for a in listB_X]

editC_X = [item for sublist in listC_X for item in sublist]
unique_editC_X = set(editC_X)
unique_editC_X

UL_editC_X = [a for a in unique_editC_X]
cprops_X = [a.data for a in UL_editC_X]

peel=set(UL_editC_X)
sy_editC_X = [a.symbol for a in UL_editC_X]
sy_editC_X


pd.set_option('display.max_rows', None)

cprops_df_X = pd.DataFrame(cprops_X, index=sy_editC_X)

droplist2 = droplist + ['Max oxidation state', 'Min oxidation state']

droplist2

cprops_df_X = cprops_df_X.drop(columns=droplist2)
cprops_df_X
# Out:
#     Atomic mass  Atomic no Atomic radius Atomic radius calculated  \
# H      1.007940          1          0.25                     0.53
# Li     6.941000          3          1.45                     1.67
# Be     9.012182          4          1.05                     1.12
# B     10.811000          5          0.85                     0.87
# C     12.010700          6           0.7                     0.67
# N     14.006700          7          0.65                     0.56
# O     15.999400          8           0.6                     0.48
# F     18.998403          9           0.5                     0.42
# Na    22.989769         11           1.8                      1.9
# Mg    24.305000         12           1.5                     1.45
# Al    26.981539         13          1.25                     1.18
# Si    28.085500         14           1.1                     1.11
# P     30.973762         15           1.0                     0.98
# S     32.065000         16           1.0                     0.88
# Cl    35.453000         17           1.0                     0.79
# K     39.098300         19           2.2                     2.43
# Ca    40.078000         20           1.8                     1.94
# Sc    44.955912         21           1.6                     1.84
# Ti    47.867000         22           1.4                     1.76
# V     50.941500         23          1.35                     1.71
# Cr    51.996100         24           1.4                     1.66
# Mn    54.938045         25           1.4                     1.61
# Fe    55.845000         26           1.4                     1.56
# Co    58.933195         27          1.35                     1.52
# Ni    58.693400         28          1.35                     1.49
# Cu    63.546000         29          1.35                     1.45
# Zn    65.409000         30          1.35                     1.42
# Ga    69.723000         31           1.3                     1.36
# Ge    72.640000         32          1.25                     1.25
# As    74.921600         33          1.15                     1.14
# Se    78.960000         34          1.15                     1.03
# Br    79.904000         35          1.15                     0.94
# Rb    85.467800         37          2.35                     2.65
# Sr    87.620000         38           2.0                     2.19
# Y     88.905850         39           1.8                     2.12
# Zr    91.224000         40          1.55                     2.06
# Nb    92.906380         41          1.45                     1.98
# Mo    95.940000         42          1.45                      1.9
# Tc    98.000000         43          1.35                     1.83
# Ru   101.070000         44           1.3                     1.78
# Rh   102.905500         45          1.35                     1.73
# Pd   106.420000         46           1.4                     1.69
# Ag   107.868200         47           1.6                     1.65
# Cd   112.411000         48          1.55                     1.61
# In   114.818000         49          1.55                     1.56
# Sn   118.710000         50          1.45                     1.45
# Sb   121.760000         51          1.45                     1.33
# Te   127.600000         52           1.4                     1.23
# I    126.904470         53           1.4                     1.15
# Xe   131.293000         54       no data                     1.08
# Cs   132.905452         55           2.6                     2.98
# Ba   137.327000         56          2.15                     2.53
# La   138.905470         57          1.95                  no data
# Ce   140.116000         58          1.85                  no data
# Pr   140.907650         59          1.85                     2.47
# Nd   144.242000         60          1.85                     2.06
# Sm   150.360000         62          1.85                     2.38
# Eu   151.964000         63          1.85                     2.31
# Tb   158.925350         65          1.75                     2.25
# Dy   162.500000         66          1.75                     2.28
# Ho   164.930320         67          1.75                  no data
# Er   167.259000         68          1.75                     2.26
# Tm   168.934210         69          1.75                     2.22
# Yb   173.040000         70          1.75                     2.22
# Lu   174.967000         71          1.75                     2.17
# Hf   178.490000         72          1.55                     2.08
# Ta   180.947880         73          1.45                      2.0
# W    183.840000         74          1.35                     1.93
# Re   186.207000         75          1.35                     1.88
# Os   190.230000         76           1.3                     1.85
# Ir   192.217000         77          1.35                      1.8
# Pt   195.084000         78          1.35                     1.77
# Au   196.966569         79          1.35                     1.74
# Hg   200.590000         80           1.5                     1.71
# Tl   204.383300         81           1.9                     1.56
# Pb   207.200000         82           1.8                     1.54
# Bi   208.980400         83           1.6                     1.43
# Ac   227.000000         89          1.95                  no data
# Th   232.038060         90           1.8                  no data
#
#    Boiling point     Bulk modulus Common oxidation states  \
# H        20.28 K      no data GPa                 [-1, 1]
# Li        1615 K           11 GPa                     [1]
# Be        2742 K          130 GPa                     [2]
# B         4200 K          320 GPa                     [3]
# C         4300 K           33 GPa                 [-4, 4]
# N        77.36 K      no data GPa              [-3, 3, 5]
# O         90.2 K      no data GPa                    [-2]
# F        85.03 K      no data GPa                    [-1]
# Na        1156 K          6.3 GPa                     [1]
# Mg        1363 K           45 GPa                     [2]
# Al        2792 K           76 GPa                     [3]
# Si        3173 K          100 GPa                 [-4, 4]
# P          550 K           11 GPa              [-3, 3, 5]
# S       717.87 K          7.7 GPa           [-2, 2, 4, 6]
# Cl      239.11 K  1.1 (liquid)GPa        [-1, 1, 3, 5, 7]
# K         1032 K          3.1 GPa                     [1]
# Ca        1757 K           17 GPa                     [2]
# Sc        3103 K           57 GPa                     [3]
# Ti        3560 K          110 GPa                     [4]
# V         3680 K          160 GPa                     [5]
# Cr        2944 K          160 GPa                  [3, 6]
# Mn        2334 K          120 GPa               [2, 4, 7]
# Fe        3134 K          170 GPa                  [2, 3]
# Co        3200 K          180 GPa                  [2, 3]
# Ni        3186 K          180 GPa                     [2]
# Cu        3200 K          140 GPa                     [2]
# Zn        1180 K           70 GPa                     [2]
# Ga        2477 K      no data GPa                     [3]
# Ge        3093 K      no data GPa              [-4, 2, 4]
# As         887 K           22 GPa              [-3, 3, 5]
# Se         958 K          8.3 GPa           [-2, 2, 4, 6]
# Br         332 K          1.9 GPa        [-1, 1, 3, 5, 7]
# Rb         961 K          2.5 GPa                     [1]
# Sr        1655 K      no data GPa                     [2]
# Y         3609 K           41 GPa                     [3]
# Zr        4682 K      no data GPa                     [4]
# Nb        5017 K          170 GPa                     [5]
# Mo        4912 K          230 GPa                  [4, 6]
# Tc        4538 K      no data GPa                  [4, 7]
# Ru        4423 K          220 GPa                  [3, 4]
# Rh        3968 K          380 GPa                     [3]
# Pd        3236 K          180 GPa                  [2, 4]
# Ag        2435 K          100 GPa                     [1]
# Cd        1040 K           42 GPa                     [2]
# In        2345 K      no data GPa                     [3]
# Sn        2875 K           58 GPa              [-4, 2, 4]
# Sb        1860 K           42 GPa              [-3, 3, 5]
# Te        1261 K           65 GPa           [-2, 2, 4, 6]
# I        457.4 K          7.7 GPa        [-1, 1, 3, 5, 7]
# Xe       165.1 K      no data GPa                     NaN
# Cs         944 K          1.6 GPa                     [1]
# Ba        2143 K          9.6 GPa                     [2]
# La        3743 K           28 GPa                     [3]
# Ce        3633 K           22 GPa                  [3, 4]
# Pr        3563 K           29 GPa                     [3]
# Nd        3373 K           32 GPa                     [3]
# Sm        2076 K           38 GPa                     [3]
# Eu        1800 K          8.3 GPa                  [2, 3]
# Tb        3503 K         38.7 GPa                     [3]
# Dy        2840 K           41 GPa                     [3]
# Ho        2993 K           40 GPa                     [3]
# Er        3141 K           44 GPa                     [3]
# Tm        2223 K           45 GPa                     [3]
# Yb        1469 K           31 GPa                     [3]
# Lu        3675 K           48 GPa                     [3]
# Hf        4876 K          110 GPa                     [4]
# Ta        5731 K          200 GPa                     [5]
# W         5828 K          310 GPa                  [4, 6]
# Re        5869 K          370 GPa                     [4]
# Os        5285 K      no data GPa                     [4]
# Ir        4701 K          320 GPa                  [3, 4]
# Pt        4098 K          230 GPa                  [2, 4]
# Au        3129 K          220 GPa                     [3]
# Hg      629.88 K           25 GPa                  [1, 2]
# Tl        1746 K           43 GPa                  [1, 3]
# Pb        2022 K           46 GPa                  [2, 4]
# Bi        1837 K           31 GPa                     [3]
# Ac        3573 K      no data GPa                     [3]
# Th        5093 K           54 GPa                     [4]
#
#    Critical temperature           Density of solid Liquid range  \
# H                  33 K  no data kg m<sup>-3</sup>       6.27 K
# Li               3223 K      535 kg m<sup>-3</sup>    1161.31 K
# Be            no data K     1848 kg m<sup>-3</sup>       1182 K
# B             no data K     2460 kg m<sup>-3</sup>       1851 K
# C             no data K     2267 kg m<sup>-3</sup>        500 K
# N               126.2 K  no data kg m<sup>-3</sup>      14.31 K
# O               154.6 K  no data kg m<sup>-3</sup>       35.4 K
# F                 144 K  no data kg m<sup>-3</sup>       31.5 K
# Na               2573 K      968 kg m<sup>-3</sup>     785.13 K
# Mg            no data K     1738 kg m<sup>-3</sup>        440 K
# Al            no data K     2700 kg m<sup>-3</sup>    1858.53 K
# Si            no data K     2330 kg m<sup>-3</sup>       1486 K
# P                 994 K     1823 kg m<sup>-3</sup>      232.7 K
# S                1314 K     1960 kg m<sup>-3</sup>     329.51 K
# Cl                417 K  no data kg m<sup>-3</sup>      67.51 K
# K                2223 K      856 kg m<sup>-3</sup>     695.47 K
# Ca            no data K     1550 kg m<sup>-3</sup>        642 K
# Sc            no data K     2985 kg m<sup>-3</sup>       1289 K
# Ti            no data K     4507 kg m<sup>-3</sup>       1619 K
# V             no data K     6110 kg m<sup>-3</sup>       1497 K
# Cr            no data K     7140 kg m<sup>-3</sup>        764 K
# Mn            no data K     7470 kg m<sup>-3</sup>        815 K
# Fe            no data K     7874 kg m<sup>-3</sup>       1323 K
# Co            no data K     8900 kg m<sup>-3</sup>       1432 K
# Ni            no data K     8908 kg m<sup>-3</sup>       1458 K
# Cu            no data K     8920 kg m<sup>-3</sup>    1842.23 K
# Zn            no data K     7140 kg m<sup>-3</sup>     487.32 K
# Ga            no data K     5904 kg m<sup>-3</sup>    2174.09 K
# Ge            no data K     5323 kg m<sup>-3</sup>     1881.6 K
# As               1700 K     5727 kg m<sup>-3</sup>        203 K
# Se               1766 K     4819 kg m<sup>-3</sup>        464 K
# Br                586 K  no data kg m<sup>-3</sup>       66.2 K
# Rb               2093 K     1532 kg m<sup>-3</sup>     648.54 K
# Sr            no data K     2630 kg m<sup>-3</sup>        605 K
# Y             no data K     4472 kg m<sup>-3</sup>       1810 K
# Zr            no data K     6511 kg m<sup>-3</sup>       2554 K
# Nb            no data K     8570 kg m<sup>-3</sup>       2267 K
# Mo            no data K    10280 kg m<sup>-3</sup>       2016 K
# Tc            no data K    11500 kg m<sup>-3</sup>       2108 K
# Ru            no data K    12370 kg m<sup>-3</sup>       1816 K
# Rh            no data K    12450 kg m<sup>-3</sup>       1731 K
# Pd            no data K    12023 kg m<sup>-3</sup>    1407.95 K
# Ag            no data K    10490 kg m<sup>-3</sup>    1200.07 K
# Cd            no data K     8650 kg m<sup>-3</sup>     445.78 K
# In            no data K     7310 kg m<sup>-3</sup>    1915.25 K
# Sn            no data K     7310 kg m<sup>-3</sup>    2369.92 K
# Sb            no data K     6697 kg m<sup>-3</sup>     956.22 K
# Te            no data K     6240 kg m<sup>-3</sup>     538.34 K
# I                 819 K     4940 kg m<sup>-3</sup>      70.55 K
# Xe              289.7 K  no data kg m<sup>-3</sup>        3.7 K
# Cs               1938 K     1879 kg m<sup>-3</sup>     642.41 K
# Ba            no data K     3510 kg m<sup>-3</sup>       1143 K
# La            no data K     6146 kg m<sup>-3</sup>       2550 K
# Ce            no data K     6689 kg m<sup>-3</sup>       2565 K
# Pr            no data K     6640 kg m<sup>-3</sup>       2355 K
# Nd            no data K     6800 kg m<sup>-3</sup>       2076 K
# Sm            no data K     7353 kg m<sup>-3</sup>        731 K
# Eu            no data K     5244 kg m<sup>-3</sup>        701 K
# Tb            no data K     8219 kg m<sup>-3</sup>       1874 K
# Dy            no data K     8551 kg m<sup>-3</sup>       1160 K
# Ho            no data K     8795 kg m<sup>-3</sup>       1259 K
# Er            no data K     9066 kg m<sup>-3</sup>       1371 K
# Tm            no data K     9321 kg m<sup>-3</sup>        405 K
# Yb            no data K     6570 kg m<sup>-3</sup>        372 K
# Lu            no data K     9841 kg m<sup>-3</sup>       1750 K
# Hf            no data K    13310 kg m<sup>-3</sup>       2370 K
# Ta            no data K    16650 kg m<sup>-3</sup>       2441 K
# W             no data K    19250 kg m<sup>-3</sup>       2133 K
# Re            no data K    21020 kg m<sup>-3</sup>       2410 K
# Os            no data K    22610 kg m<sup>-3</sup>       1979 K
# Ir            no data K    22650 kg m<sup>-3</sup>       1962 K
# Pt            no data K    21090 kg m<sup>-3</sup>     2056.6 K
# Au            no data K    19300 kg m<sup>-3</sup>    1791.67 K
# Hg               1750 K  no data kg m<sup>-3</sup>     395.56 K
# Tl            no data K    11850 kg m<sup>-3</sup>       1169 K
# Pb            no data K    11340 kg m<sup>-3</sup>    1421.39 K
# Bi            no data K     9780 kg m<sup>-3</sup>     1292.6 K
# Ac            no data K    10070 kg m<sup>-3</sup>       2250 K
# Th            no data K    11724 kg m<sup>-3</sup>       2978 K
#
#         Melting point Poissons ratio                     Thermal conductivity  \
# H             14.01 K        no data   0.1805 W m<sup>-1</sup> K<sup>-1</sup>
# Li           453.69 K        no data       85 W m<sup>-1</sup> K<sup>-1</sup>
# Be             1560 K          0.032      190 W m<sup>-1</sup> K<sup>-1</sup>
# B              2349 K        no data       27 W m<sup>-1</sup> K<sup>-1</sup>
# C              3800 K        no data      140 W m<sup>-1</sup> K<sup>-1</sup>
# N             63.05 K        no data  0.02583 W m<sup>-1</sup> K<sup>-1</sup>
# O              54.8 K        no data  0.02658 W m<sup>-1</sup> K<sup>-1</sup>
# F             53.53 K        no data   0.0277 W m<sup>-1</sup> K<sup>-1</sup>
# Na           370.87 K        no data      140 W m<sup>-1</sup> K<sup>-1</sup>
# Mg              923 K           0.29      160 W m<sup>-1</sup> K<sup>-1</sup>
# Al           933.47 K           0.35      235 W m<sup>-1</sup> K<sup>-1</sup>
# Si             1687 K        no data      150 W m<sup>-1</sup> K<sup>-1</sup>
# P   (white P) 317.3 K        no data    0.236 W m<sup>-1</sup> K<sup>-1</sup>
# S            388.36 K        no data    0.205 W m<sup>-1</sup> K<sup>-1</sup>
# Cl            171.6 K        no data   0.0089 W m<sup>-1</sup> K<sup>-1</sup>
# K            336.53 K        no data      100 W m<sup>-1</sup> K<sup>-1</sup>
# Ca             1115 K           0.31      200 W m<sup>-1</sup> K<sup>-1</sup>
# Sc             1814 K           0.28       16 W m<sup>-1</sup> K<sup>-1</sup>
# Ti             1941 K           0.32       22 W m<sup>-1</sup> K<sup>-1</sup>
# V              2183 K           0.37       31 W m<sup>-1</sup> K<sup>-1</sup>
# Cr             2180 K           0.21       94 W m<sup>-1</sup> K<sup>-1</sup>
# Mn             1519 K        no data      7.8 W m<sup>-1</sup> K<sup>-1</sup>
# Fe             1811 K           0.29       80 W m<sup>-1</sup> K<sup>-1</sup>
# Co             1768 K           0.31      100 W m<sup>-1</sup> K<sup>-1</sup>
# Ni             1728 K           0.31       91 W m<sup>-1</sup> K<sup>-1</sup>
# Cu          1357.77 K           0.34      400 W m<sup>-1</sup> K<sup>-1</sup>
# Zn           692.68 K           0.25      120 W m<sup>-1</sup> K<sup>-1</sup>
# Ga           302.91 K        no data       29 W m<sup>-1</sup> K<sup>-1</sup>
# Er                  2.29     2830 m s<sup>-1</sup>      589 MN m<sup>-2</sup>
# Tm                  2.27  no data m s<sup>-1</sup>      520 MN m<sup>-2</sup>
# Yb                  2.26     1590 m s<sup>-1</sup>      206 MN m<sup>-2</sup>
# Lu                  2.24  no data m s<sup>-1</sup>     1160 MN m<sup>-2</sup>
# Hf                  2.23     3010 m s<sup>-1</sup>     1760 MN m<sup>-2</sup>
# Ta                  2.22     3400 m s<sup>-1</sup>      873 MN m<sup>-2</sup>
# W                   2.18     5174 m s<sup>-1</sup>     3430 MN m<sup>-2</sup>
# Re                  2.16     4700 m s<sup>-1</sup>     2450 MN m<sup>-2</sup>
# Os                  2.16     4940 m s<sup>-1</sup>  no data MN m<sup>-2</sup>
# Ir                  2.13     4825 m s<sup>-1</sup>     1760 MN m<sup>-2</sup>
# Pt                  2.13     2680 m s<sup>-1</sup>      549 MN m<sup>-2</sup>
# Au                  2.14     1740 m s<sup>-1</sup>      216 MN m<sup>-2</sup>
# Hg                  2.23     1407 m s<sup>-1</sup>  no data MN m<sup>-2</sup>
# Tl                  1.96      818 m s<sup>-1</sup>  no data MN m<sup>-2</sup>
# Pb                  2.02     1260 m s<sup>-1</sup>  no data MN m<sup>-2</sup>
# Bi                  2.07     1790 m s<sup>-1</sup>  no data MN m<sup>-2</sup>
# Ac                  2.47  no data m s<sup>-1</sup>  no data MN m<sup>-2</sup>
# Th                  2.45     2490 m s<sup>-1</sup>      350 MN m<sup>-2</sup>
#
#        X Youngs modulus Metallic radius  \
# H   2.20    no data GPa         no data
# Li  0.98        4.9 GPa            1.52
# Be  1.57        287 GPa            1.12
# B   2.04    no data GPa         no data
# C   2.55    no data GPa         no data
# N   3.04    no data GPa         no data
# O   3.44    no data GPa         no data
# F   3.98    no data GPa         no data
# Na  0.93         10 GPa            1.86
# Mg  1.31         45 GPa             1.6
# Al  1.61         70 GPa            1.43
# Si  1.90         47 GPa         no data
# P   2.19    no data GPa         no data
# S   2.58    no data GPa         no data
# Cl  3.16    no data GPa         no data
# K   0.82    no data GPa           2.381
# Ca  1.00         20 GPa           1.976
# Sc  1.36         74 GPa           1.641
# Ti  1.54        116 GPa           1.462
# V   1.63        128 GPa           1.347
# Cr  1.66        279 GPa           1.285
# Mn  1.55        198 GPa           1.292
# Fe  1.83        211 GPa           1.277
# Co  1.88        209 GPa            1.25
# Ni  1.91        200 GPa           1.246
# Cu  1.90        130 GPa           1.278
# Zn  1.65        108 GPa            1.34
# Ga  1.81    no data GPa            1.35
# Ge  2.01    no data GPa            1.39
# As  2.18          8 GPa         no data
# Se  2.55         10 GPa         no data
# Br  2.96    no data GPa            1.14
# Rb  0.82        2.4 GPa           2.537
# Sr  0.95    no data GPa           2.151
# Y   1.22         64 GPa             1.8
# Zr  1.33         68 GPa           1.602
# Nb  1.60        105 GPa           1.473
# Mo  2.16        329 GPa           1.402
# Tc  1.90    no data GPa           1.363
# Ru  2.20        447 GPa           1.339
# Rh  2.28        275 GPa           1.345
# Pd  2.20        121 GPa           1.376
# Ag  1.93         83 GPa           1.445
# Cd  1.69         50 GPa            1.51
# In  1.78         11 GPa            1.67
# Sn  1.96         50 GPa            1.58
# Sb  2.05         55 GPa            1.61
# Te  2.10         43 GPa         no data
# I   2.66    no data GPa         no data
# Xe  2.60    no data GPa         no data
# Cs  0.79        1.7 GPa           2.719
# Ba  0.89         13 GPa           2.236
# La  1.10         37 GPa           1.877
# Ce  1.12         34 GPa           1.707
# Pr  1.13         37 GPa           1.828
# Nd  1.14         41 GPa           1.821
# Sm  1.17         50 GPa           1.804
# Eu  1.20         18 GPa           2.041
# Tb  1.10         56 GPa           1.781
# Dy  1.22         61 GPa           1.773
# Ho  1.23         65 GPa           1.765
# Er  1.24         70 GPa           1.756
# Tm  1.25         74 GPa           1.747
# Yb  1.10         24 GPa            1.94
# Lu  1.27         69 GPa           1.735
# Hf  1.30         78 GPa            1.58
# Ta  1.50        186 GPa            1.47
# W   2.36        411 GPa            1.41
# Re  1.90        463 GPa           1.375
# Os  2.20    no data GPa           1.352
# Ir  2.20        528 GPa           1.357
# Pt  2.28        168 GPa           1.387
# Au  2.54         78 GPa           1.442
# Hg  2.00    no data GPa            1.51
# Tl  1.62          8 GPa             1.7
# Pb  2.33         16 GPa            1.75
# Bi  2.02         32 GPa            1.82
# Ac  1.10    no data GPa           1.878
# Th  1.30         79 GPa           1.798
#
#                                   Ionization energies  Electron affinity
# H                                   [13.598434599702]           0.754598
# Li             [5.391714996, 75.640097, 122.45435914]           0.618049
# Be      [9.322699, 18.21115, 153.896205, 217.7185861]          -0.520000
# B   [8.298019, 25.15483, 37.93059, 259.3715, 340.2...           0.279723
# C   [11.260288, 24.383154, 47.88778, 64.49352, 392...           1.262114
# N   [14.53413, 29.60125, 47.4453, 77.4735, 97.8901...          -0.070000
# O   [13.618055, 35.12112, 54.93554, 77.4135, 113.8...           1.461105
# F   [17.42282, 34.97081, 62.70798, 87.175, 114.249...           3.401190
# Na  [5.13907696, 47.28636, 71.62, 98.936, 138.404,...           0.547926
# Mg  [7.646236, 15.035271, 80.1436, 109.2654, 141.3...          -0.420000
# Al  [5.985769, 18.82855, 28.447642, 119.9924, 153....           0.432835
# Si  [8.15168, 16.34585, 33.493, 45.14179, 166.767,...           1.389521
# P   [10.486686, 19.76949, 30.20264, 51.44387, 65.0...           0.746607
# S   [10.36001, 23.33788, 34.86, 47.222, 72.5945, 8...           2.077105
# Cl  [12.967633, 23.81364, 39.8, 53.24, 67.68, 96.9...           3.612725
# K   [4.34066373, 31.625, 45.8031, 60.917, 82.66, 9...           0.501459
# Ca  [6.11315547, 11.871719, 50.91316, 67.2732, 84....           0.024551
# Sc  [6.56149, 12.79977, 24.756839, 73.4894, 91.95,...           0.188200
# Ti  [6.82812, 13.5755, 27.49171, 43.26717, 99.299,...           0.075545
# V   [6.746187, 14.634, 29.3111, 46.709, 65.28165, ...           0.527662
# Cr  [6.76651, 16.486305, 30.959, 49.16, 69.46, 90....           0.675841
# Mn  [7.434038, 15.63999, 33.668, 51.21, 72.41, 95....          -0.520000
# Tb  [5.8638, 11.513, 21.82, 39.33, 66.5, 90.0, 108...           0.131318
# Dy  [5.93905, 11.647, 22.89, 41.23, 62.1, 93.0, 11...           0.352000
# Ho  [6.0215, 11.781, 22.79, 42.52, 63.9, 95.0, 112...           0.338000
# Er  [6.1077, 11.916, 22.7, 42.42, 65.1, 96.0, 114....           0.312000
# Tm  [6.18431, 12.065, 23.66, 42.41, 65.4, 98.0, 11...           1.029220
# Yb  [6.25416, 12.179185, 25.053, 43.61, 65.6, 99.0...          -0.020000
# Lu  [5.425871, 14.13, 20.9594, 45.249, 66.8, 98.0,...           0.238870
# Hf  [6.82507, 14.61, 22.55, 33.37, 68.37, 98.0, 11...           0.178070
# Ta  [7.549571, 16.2, 23.1, 35.0, 48.272, 94.01, 11...           0.323120
# W   [7.86403, 16.37, 26.0, 38.2, 51.6, 64.77, 122....           0.816268
# Re  [7.83352, 16.6, 27.0, 39.1, 51.9, 67.0, 82.71,...           0.060397
# Os  [8.43823, 17.0, 25.0, 41.0, 55.0, 70.1, 85.1, ...           1.077801
# Ir  [8.96702, 17.0, 28.0, 40.0, 57.0, 72.0, 89.0, ...           1.564361
# Pt  [8.95883, 18.56, 29.0, 43.0, 56.0, 75.0, 91.0,...           2.125105
# Au  [9.225554, 20.203, 30.0, 45.0, 60.0, 74.0, 94....           2.308610
# Hg  [10.437504, 18.75688, 34.49, 48.55, 61.2, 76.6...          -0.520000
# Tl  [6.1082873, 20.4283, 29.852, 51.14, 62.6, 80.0...           0.320053
# Pb  [7.4166799, 15.032499, 31.9373, 42.33256, 68.8...           0.356721
# Bi  [7.285516, 16.703, 25.57075, 45.37, 54.856, 88...           0.942362
# Ac  [5.380226, 11.75, 17.431, 44.8, 55.0, 67.0, 79...           0.350000
# Th  [6.3067, 12.1, 18.32, 28.648, 58.0, 69.1, 82.0...           1.170000

# %%
cprops_df_X['Boiling point'] = [(a.replace('K', '', 1)) for a in cprops_df_X['Boiling point']]
cprops_df_X['Bulk modulus'] = cprops_df_X["Bulk modulus"].str.replace("GPa", "")
cprops_df_X['Critical temperature'] = cprops_df_X["Critical temperature"].str.replace("K", "")
cprops_df_X['Density of solid'] = cprops_df_X['Density of solid'].str.replace("no data", "NaN")
cprops_df_X['Density of solid'] = cprops_df_X["Density of solid"].str.replace("kg m<sup>-3</sup>", "")
cprops_df_X['Liquid range'] = [(a.replace('K', '', 1)) for a in cprops_df_X['Liquid range']]
cprops_df_X['Poissons ratio'] = [(a.replace('no data', 'NaN', 1)) for a in cprops_df_X['Poissons ratio']]
cprops_df_X['Poissons ratio'] = cprops_df_X['Poissons ratio'].str.replace("no data", "").astype(float)
cprops_df_X['Thermal conductivity'] = [float(a.replace('W m<sup>-1</sup> K<sup>-1</sup>', "", 1)) for a in cprops_df_X['Thermal conductivity']]
cprops_df_X['Velocity of sound'] = cprops_df_X['Velocity of sound'].str.replace("no data","NaN")
cprops_df_X['Velocity of sound'] = [(a.replace('m s<sup>-1</sup>', '', 1)) for a in cprops_df_X['Velocity of sound']]
cprops_df_X['Vickers hardness'] = cprops_df_X['Vickers hardness'].str.replace("no data", "NaN")
cprops_df_X['Vickers hardness'] = [(a.replace('MN m<sup>-2</sup>', '', 1)) for a in cprops_df_X['Vickers hardness']]
cprops_df_X['Youngs modulus'] = cprops_df_X['Youngs modulus'].str.replace("no data", "NaN")
cprops_df_X['Youngs modulus'] = [(a.replace('GPa', '', 1)) for a in cprops_df_X['Youngs modulus']]
cprops_df_X['Bulk modulus'] = [(a.replace('no data', 'NaN', 1)) for a in cprops_df_X['Bulk modulus']]
cprops_df_X['Bulk modulus'] = [(a.replace('liquid', '', 1)) for a in cprops_df_X['Bulk modulus']]
cprops_df_X['Bulk modulus'] = cprops_df_X['Bulk modulus'].str.replace(r"\(.*\)","",  regex=True).astype(float)
cprops_df_X['Melting point'] = cprops_df_X['Melting point'].str.replace("K", "")
cprops_df_X['Melting point'] = cprops_df_X['Melting point'].str.replace("white P", "")
cprops_df_X['Melting point'] = cprops_df_X['Melting point'].str.replace(r"\(.*\)","",  regex=True).astype(float)
cprops_df_X['Metallic radius'] = cprops_df_X['Metallic radius'].astype(str)
cprops_df_X['Metallic radius'] = [(a.replace('no data', 'NaN', 1)) for a in cprops_df_X['Metallic radius']]
cprops_df_X['Metallic radius'] = cprops_df_X['Metallic radius'].astype(float)
cprops_df_X['First Ionization Energy'] = [a[0] for a in cprops_df_X['Ionization energies']]
cprops_df_X = cprops_df_X.drop("Ionization energies", axis=1)
cprops_df_X['Critical temperature'] = [(a.replace('no data', 'NaN', 1)) for a in cprops_df_X['Critical temperature']]

cprops_df_X = cprops_df_X.apply(pd.to_numeric, errors='coerce')

# %%
# Computing mean values using mean function 
mvals_X = dict(cprops_df_X.mean())
mvals_X

for key, value in mvals_X.items():
    cprops_df_X.loc[cprops_df_X[key].isnull(),key] = value

display(cprops_df_X)
# Out:
#     Atomic mass  Atomic no  Atomic radius  Atomic radius calculated  \
# H      1.007940        1.0       0.250000                  0.530000
# Li     6.941000        3.0       1.450000                  1.670000
# Be     9.012182        4.0       1.050000                  1.120000
# B     10.811000        5.0       0.850000                  0.870000
# C     12.010700        6.0       0.700000                  0.670000
# N     14.006700        7.0       0.650000                  0.560000
# O     15.999400        8.0       0.600000                  0.480000
# F     18.998403        9.0       0.500000                  0.420000
# Na    22.989769       11.0       1.800000                  1.900000
# Mg    24.305000       12.0       1.500000                  1.450000
# Al    26.981539       13.0       1.250000                  1.180000
# Si    28.085500       14.0       1.100000                  1.110000
# P     30.973762       15.0       1.000000                  0.980000
# S     32.065000       16.0       1.000000                  0.880000
# Cl    35.453000       17.0       1.000000                  0.790000
# K     39.098300       19.0       2.200000                  2.430000
# Ca    40.078000       20.0       1.800000                  1.940000
# Sc    44.955912       21.0       1.600000                  1.840000
# Ti    47.867000       22.0       1.400000                  1.760000
# V     50.941500       23.0       1.350000                  1.710000
# Cr    51.996100       24.0       1.400000                  1.660000
# Mn    54.938045       25.0       1.400000                  1.610000
# Fe    55.845000       26.0       1.400000                  1.560000
# F           85.03     92.330303                      NaN
# Na        1156.00      6.300000                      NaN
# Mg        1363.00     45.000000                      NaN
# Al        2792.00     76.000000                      NaN
# Si        3173.00    100.000000                      NaN
# P          550.00     11.000000                      NaN
# S          717.87      7.700000                      NaN
# Cl         239.11      1.100000                      NaN
# K         1032.00      3.100000                      NaN
# Ca        1757.00     17.000000                      NaN
# Sc        3103.00     57.000000                      NaN
# Ti        3560.00    110.000000                      NaN
# V         3680.00    160.000000                      NaN
# Cr        2944.00    160.000000                      NaN
# Mn        2334.00    120.000000                      NaN
# Fe        3134.00    170.000000                      NaN
# Co        3200.00    180.000000                      NaN
# Ni        3186.00    180.000000                      NaN
# Cu        3200.00    140.000000                      NaN
# Zn        1180.00     70.000000                      NaN
# Ga        2477.00     92.330303                      NaN
# Ge        3093.00     92.330303                      NaN
# As         887.00     22.000000                      NaN
# Se         958.00      8.300000                      NaN
# Br         332.00      1.900000                      NaN
# Rb         961.00      2.500000                      NaN
# Sr        1655.00     92.330303                      NaN
# Y         3609.00     41.000000                      NaN
# Zr        4682.00     92.330303                      NaN
# Nb        5017.00    170.000000                      NaN
# Mo        4912.00    230.000000                      NaN
# Tc        4538.00     92.330303                      NaN
# Ru        4423.00    220.000000                      NaN
# Rh        3968.00    380.000000                      NaN
# Pd        3236.00    180.000000                      NaN
# Ag        2435.00    100.000000                      NaN
# Cd        1040.00     42.000000                      NaN
# In        2345.00     92.330303                      NaN
# Sn        2875.00     58.000000                      NaN
# Sb        1860.00     42.000000                      NaN
# Te        1261.00     65.000000                      NaN
# I          457.40      7.700000                      NaN
# Xe         165.10     92.330303                      NaN
# Cs         944.00      1.600000                      NaN
# Ba        2143.00      9.600000                      NaN
# La        3743.00     28.000000                      NaN
# Ce        3633.00     22.000000                      NaN
# Pr        3563.00     29.000000                      NaN
# Nd        3373.00     32.000000                      NaN
# Sm        2076.00     38.000000                      NaN
# Eu        1800.00      8.300000                      NaN
# Tb        3503.00     38.700000                      NaN
# Dy        2840.00     41.000000                      NaN
# Ho        2993.00     40.000000                      NaN
# Er        3141.00     44.000000                      NaN
# Tm        2223.00     45.000000                      NaN
# Yb        1469.00     31.000000                      NaN
# Lu        3675.00     48.000000                      NaN
# Hf        4876.00    110.000000                      NaN
# Ta        5731.00    200.000000                      NaN
# W         5828.00    310.000000                      NaN
# Re        5869.00    370.000000                      NaN
# Os        5285.00     92.330303                      NaN
# Ir        4701.00    320.000000                      NaN
# Pt        4098.00    230.000000                      NaN
# Au        3129.00    220.000000                      NaN
# Hg         629.88     25.000000                      NaN
# Tl        1746.00     43.000000                      NaN
# Pb        2022.00     46.000000                      NaN
# Bi        1837.00     31.000000                      NaN
# Ac        3573.00     92.330303                      NaN
# Th        5093.00     54.000000                      NaN
#
#     Critical temperature  Density of solid  Liquid range  Melting point  \
# H              33.000000        7915.56338          6.27          14.01
# Li           3223.000000         535.00000       1161.31         453.69
# Be           1230.194444        1848.00000       1182.00        1560.00
# B            1230.194444        2460.00000       1851.00        2349.00
# C            1230.194444        2267.00000        500.00        3800.00
# Rb         2.537000           0.485916                 4.177128
# Sr         2.151000           0.052066                 5.694867
# Y          1.800000           0.307120                 6.217260
# Zr         1.602000           0.433289                 6.634126
# Nb         1.473000           0.917407                 6.758850
# Mo         1.402000           0.747330                 7.092430
# Tc         1.363000           0.552000                 7.119380
# Ru         1.339000           1.046382                 7.360500
# Rh         1.345000           1.142892                 7.458900
# Pd         1.376000           0.562141                 8.336839
# Ag         1.445000           1.304473                 7.576234
# Cd         1.510000          -0.720000                 8.993820
# In         1.670000           0.383926                 5.786356
# Sn         1.580000           1.112070                 7.343918
# Sb         1.610000           1.047401                 8.608389
# Te         1.621047           1.970876                 9.009808
# I          1.621047           3.059052                10.451260
# Xe         1.621047          -0.820000                12.129844
# Cs         2.719000           0.471630                 3.893906
# Ba         2.236000           0.144626                 5.211665
# La         1.877000           0.557546                 5.576900
# Ce         1.707000           0.572000                 5.538600
# Pr         1.828000           0.109235                 5.470200
# Nd         1.821000           0.097493                 5.525000
# Sm         1.804000           0.162000                 5.643710
# Eu         2.041000           0.116130                 5.670385
# Tb         1.781000           0.131318                 5.863800
# Dy         1.773000           0.352000                 5.939050
# Ho         1.765000           0.338000                 6.021500
# Er         1.756000           0.312000                 6.107700
# Tm         1.747000           1.029220                 6.184310
# Yb         1.940000          -0.020000                 6.254160
# Lu         1.735000           0.238870                 5.425871
# Hf         1.580000           0.178070                 6.825070
# Ta         1.470000           0.323120                 7.549571
# W          1.410000           0.816268                 7.864030
# Re         1.375000           0.060397                 7.833520
# Os         1.352000           1.077801                 8.438230
# Ir         1.357000           1.564361                 8.967020
# Pt         1.387000           2.125105                 8.958830
# Au         1.442000           2.308610                 9.225554
# Hg         1.510000          -0.520000                10.437504
# Tl         1.700000           0.320053                 6.108287
# Pb         1.750000           0.356721                 7.416680
# Bi         1.820000           0.942362                 7.285516
# Ac         1.878000           0.350000                 5.380226
# Th         1.798000           1.170000                 6.306700

# %%
filt_data_comp_X = filt_data_X
filt_data_comp_X['Composition'] = [Composition(c) for c in filt_data_comp_X["pretty_formula"]]
filt_data_comp_X['num_atoms'] = [c.num_atoms for c in filt_data_comp_X['Composition']]
filt_data_comp_X['volume_per_atom'] = filt_data_comp_X['volume']/filt_data_comp_X['num_atoms']
filt_data_comp_X

# %%
cprops_df_X
# Out:
#     Atomic mass  Atomic no  Atomic radius  Atomic radius calculated  \
# H      1.007940        1.0       0.250000                  0.530000
# Li     6.941000        3.0       1.450000                  1.670000
# Be     9.012182        4.0       1.050000                  1.120000
# B     10.811000        5.0       0.850000                  0.870000
# C     12.010700        6.0       0.700000                  0.670000
# N     14.006700        7.0       0.650000                  0.560000
# O     15.999400        8.0       0.600000                  0.480000
# F     18.998403        9.0       0.500000                  0.420000
# Na    22.989769       11.0       1.800000                  1.900000
# Mg    24.305000       12.0       1.500000                  1.450000
# Al    26.981539       13.0       1.250000                  1.180000
# Si    28.085500       14.0       1.100000                  1.110000
# P     30.973762       15.0       1.000000                  0.980000
# S     32.065000       16.0       1.000000                  0.880000
# Ac   227.000000       89.0       1.950000                  1.636892
# Th   232.038060       90.0       1.800000                  1.636892
#
#     Boiling point  Bulk modulus  Common oxidation states  \
# H           20.28     92.330303                      NaN
# Li        1615.00     11.000000                      NaN
# Be        2742.00    130.000000                      NaN
# B         4200.00    320.000000                      NaN
# C         4300.00     33.000000                      NaN
# N           77.36     92.330303                      NaN
# O           90.20     92.330303                      NaN
# F           85.03     92.330303                      NaN
# Na        1156.00      6.300000                      NaN
# Mg        1363.00     45.000000                      NaN
# Al        2792.00     76.000000                      NaN
# Si        3173.00    100.000000                      NaN
# P          550.00     11.000000                      NaN
# S          717.87      7.700000                      NaN
# Cl         239.11      1.100000                      NaN
# K         1032.00      3.100000                      NaN
# Ca        1757.00     17.000000                      NaN
# Sc        3103.00     57.000000                      NaN
# Ti        3560.00    110.000000                      NaN
# V         3680.00    160.000000                      NaN
# Cr        2944.00    160.000000                      NaN
# Mn        2334.00    120.000000                      NaN
# Fe        3134.00    170.000000                      NaN
# Co        3200.00    180.000000                      NaN
# Ni        3186.00    180.000000                      NaN
# Cu        3200.00    140.000000                      NaN
# Zn        1180.00     70.000000                      NaN
# Ga        2477.00     92.330303                      NaN
# Ge        3093.00     92.330303                      NaN
# As         887.00     22.000000                      NaN
# Se         958.00      8.300000                      NaN
# Br         332.00      1.900000                      NaN
# Rb         961.00      2.500000                      NaN
# Sr        1655.00     92.330303                      NaN
# Y         3609.00     41.000000                      NaN
# Zr        4682.00     92.330303                      NaN
# Nb        5017.00    170.000000                      NaN
# Mo        4912.00    230.000000                      NaN
# Tc        4538.00     92.330303                      NaN
# Ru        4423.00    220.000000                      NaN
# Rh        3968.00    380.000000                      NaN
# Pd        3236.00    180.000000                      NaN
# Ag        2435.00    100.000000                      NaN
# Cd        1040.00     42.000000                      NaN
# In        2345.00     92.330303                      NaN
# Sn        2875.00     58.000000                      NaN
# Sb        1860.00     42.000000                      NaN
# Te        1261.00     65.000000                      NaN
# I          457.40      7.700000                      NaN
# Xe         165.10     92.330303                      NaN
# Cs         944.00      1.600000                      NaN
# Ba        2143.00      9.600000                      NaN
# La        3743.00     28.000000                      NaN
# Ce        3633.00     22.000000                      NaN
# Pr        3563.00     29.000000                      NaN
# Nd        3373.00     32.000000                      NaN
# Sm        2076.00     38.000000                      NaN
# Eu        1800.00      8.300000                      NaN
# Tb        3503.00     38.700000                      NaN
# Dy        2840.00     41.000000                      NaN
# Ho        2993.00     40.000000                      NaN
# Er        3141.00     44.000000                      NaN
# Tm        2223.00     45.000000                      NaN
# Yb        1469.00     31.000000                      NaN
# Lu        3675.00     48.000000                      NaN
# Hf        4876.00    110.000000                      NaN
# Ta        5731.00    200.000000                      NaN
# W         5828.00    310.000000                      NaN
# Re        5869.00    370.000000                      NaN
# Os        5285.00     92.330303                      NaN
# Ir        4701.00    320.000000                      NaN
# Pt        4098.00    230.000000                      NaN
# Au        3129.00    220.000000                      NaN
# Hg         629.88     25.000000                      NaN
# Tl        1746.00     43.000000                      NaN
# Fe         1.277000           0.153236                 7.902468
# Co         1.250000           0.662265                 7.881010
# Ni         1.246000           1.157161                 7.639878
# Cu         1.278000           1.235784                 7.726380
# Zn         1.340000          -0.620000                 9.394197
# Ga         1.350000           0.301201                 5.999302
# Ge         1.390000           1.232676                 7.899435
# As         1.621047           0.804820                 9.788550
# Se         1.621047           2.020605                 9.752392
# Br         1.140000           3.363588                11.813810
# Rb         2.537000           0.485916                 4.177128
# Sr         2.151000           0.052066                 5.694867
# Y          1.800000           0.307120                 6.217260
# Zr         1.602000           0.433289                 6.634126
# Nb         1.473000           0.917407                 6.758850
# Mo         1.402000           0.747330                 7.092430
# Tc         1.363000           0.552000                 7.119380
# Ru         1.339000           1.046382                 7.360500
# Rh         1.345000           1.142892                 7.458900
# Pd         1.376000           0.562141                 8.336839
# Ag         1.445000           1.304473                 7.576234
# Cd         1.510000          -0.720000                 8.993820
# In         1.670000           0.383926                 5.786356
# Sn         1.580000           1.112070                 7.343918
# Sb         1.610000           1.047401                 8.608389
# Te         1.621047           1.970876                 9.009808
# I          1.621047           3.059052                10.451260
# Xe         1.621047          -0.820000                12.129844
# Cs         2.719000           0.471630                 3.893906
# Ba         2.236000           0.144626                 5.211665
# La         1.877000           0.557546                 5.576900
# Ce         1.707000           0.572000                 5.538600
# Pr         1.828000           0.109235                 5.470200
# Nd         1.821000           0.097493                 5.525000
# Sm         1.804000           0.162000                 5.643710
# Eu         2.041000           0.116130                 5.670385
# Tb         1.781000           0.131318                 5.863800
# Dy         1.773000           0.352000                 5.939050
# Ho         1.765000           0.338000                 6.021500
# Er         1.756000           0.312000                 6.107700
# Tm         1.747000           1.029220                 6.184310
# Yb         1.940000          -0.020000                 6.254160
# Lu         1.735000           0.238870                 5.425871
# Hf         1.580000           0.178070                 6.825070
# Ta         1.470000           0.323120                 7.549571
# W          1.410000           0.816268                 7.864030
# Re         1.375000           0.060397                 7.833520
# Os         1.352000           1.077801                 8.438230
# Ir         1.357000           1.564361                 8.967020
# Pt         1.387000           2.125105                 8.958830
# Au         1.442000           2.308610                 9.225554
# Hg         1.510000          -0.520000                10.437504
# Tl         1.700000           0.320053                 6.108287
# Pb         1.750000           0.356721                 7.416680
# Bi         1.820000           0.942362                 7.285516
# Ac         1.878000           0.350000                 5.380226
# Th         1.798000           1.170000                 6.306700

# %%
cprops_df_dict_X = cprops_df_X.to_dict()

rad_dict_X = cprops_df_dict_X['Atomic radius']

atomic_radius_X = filt_data_comp_X['Composition'].apply(radius_mean)
atomic_radius_X

# %%
avg_properties_df_X = pd.DataFrame()

for property in cprops_df_X.columns:
    individualpropertymean_X = partial(propertymean, property)
    averages_X = filt_data_comp_X['Composition'].apply(individualpropertymean_X)
    avg_properties_df_X[("average_" + property)] = averages_X
    
avg_properties_df_X.head()
print("Average properties Dimension: ", avg_properties_df_X.shape)

max_properties_X = pd.DataFrame()

for property in cprops_df_X.columns:
    individualpropertymax_X = partial(maxofproperty, property)
    max = filt_data_comp_X['Composition'].apply(individualpropertymax_X)
    max_properties_X[("max_" + property)] = max
    
min_properties_X = pd.DataFrame()

for property in cprops_df.columns:
    individualpropertymin_X = partial(minofproperty, property)
    min = filt_data_comp_X['Composition'].apply(individualpropertymin_X)
    min_properties_X[("min_" + property)] = min

# %%
design_matrix_X= pd.concat([filt_data_comp_X, avg_properties_df_X, min_properties_X, max_properties_X], axis=1)
design_matrix_X.columns

design_matrix_X = design_matrix_X.drop(columns=droplist2)
design_matrix_X

# %%
design_matrix_X.set_index('material_id',inplace=True)
design_matrix_X
# Out:
#              energy_per_atom  formation_energy_per_atom  nsites  nelements  \
# material_id
# mp-1000            -4.323473                  -1.792337       2          2
# mp-10044           -5.688183                  -0.019233       2          2
# mp-10086           -7.146269                  -3.359731       6          3
# mp-1008858         -5.555271                  -0.944922       3          3
# mp-1008867         -3.920243                  -0.701211       3          3
# ...                      ...                        ...     ...        ...
# mvc-5908           -7.343457                  -2.771448      10          4
# mvc-5921           -6.481664                  -2.354943      10          4
# mvc-7386           -6.497273                  -1.936434      20          3
# mvc-7701           -5.685591                  -1.957811      26          3
# mvc-7761           -6.357394                  -2.515768      26          3
#
#               density  band_gap  num_atoms  volume_per_atom  \
# material_id
# mp-1000      4.937886    1.8555        2.0        44.545542
# mp-10044     5.087631    1.2522        2.0        13.991023
# mp-10086     4.685387    1.3137        3.0        33.070824
# mp-1008858   9.427722    0.0900        3.0        26.986163
# mp-1008867   4.445388    0.0017        3.0        12.767062
# ...               ...       ...        ...              ...
# mvc-5908     5.666228    1.6101       10.0        12.073693
# mvc-5921     5.185052    2.2892       10.0        14.320411
# mvc-7386     3.170408    3.7020       10.0        38.683459
# mvc-7701     6.181576    1.2507       13.0        25.413912
# mvc-7761     4.887634    2.0677       13.0        29.493933
#
#              average_Atomic mass  average_Atomic no  average_Atomic radius  \
# material_id
# mp-1000               132.463500          54.000000               1.775000
# mp-10044               42.866300          19.000000               1.000000
# mp-10086               46.656418          21.333333               1.100000
# mp-1008858            153.214133          63.000000               1.616667
# mp-1008867             34.178390          16.000000               1.250000
# ...                          ...                ...                    ...
# mvc-5908               41.198850          18.600000               0.995000
# mvc-5921               44.715640          19.600000               0.940000
# mvc-7386               36.928480          17.000000               0.845000
# mvc-7701               47.303323          21.076923               0.911538
# mvc-7761               43.406246          19.538462               0.980769
#
#              average_Atomic radius calculated  average_Boiling point  \
# material_id
# mp-1000                              1.880000            1702.000000
# mp-10044                             1.005000            2543.500000
# mp-10086                             1.140000            1470.633333
# mp-1008858                           1.726667            2815.333333
# mp-1008867                           1.276667            1482.066667
# ...                                       ...                    ...
# mvc-5908                             1.035000            1282.720000
# mvc-5921                             0.916000            1197.020000
# mvc-7386                             0.858000            1163.540000
# mvc-7701                             0.848462             900.507692
# mvc-7761                             0.928462             989.276923
#
#              average_Bulk modulus  average_Critical temperature  \
# material_id
# mp-1000                 37.300000                   1285.517647
# mp-10044               171.000000                   1492.758824
# mp-10086                46.781373                    914.505882
# mp-1008858              81.000000                   1285.517647
# mp-1008867              79.314706                   1337.705882
# ...                           ...                           ...
# mvc-5908               105.386471                    606.967059
# mvc-5921               100.786471                    606.967059
# mvc-7386               117.150882                    493.875294
# mvc-7701                80.550226                    589.568326
# mvc-7761                72.396380                    589.568326
#
#              average_Density of solid  average_Liquid range  \
# material_id
# mp-1000                   4875.000000            840.670000
# mp-10044                  4093.500000           1027.000000
# mp-10086                  4833.296804            723.670000
# mp-1008858                9534.333333           1592.183333
# mp-1008867                5985.296804            887.586667
# ...                               ...                   ...
# mvc-5908                  7789.734247            439.340000
# mvc-5921                  7844.334247            559.532000
# mvc-7386                  8417.523288            476.712000
# mvc-7701                  7750.240253            643.661538
# mvc-7761                  6890.240253            667.458462
#
#              average_Melting point  average_Poissons ratio  \
# material_id
# mp-1000                 861.330000                0.294269
# mp-10044               1719.500000                0.294269
# mp-10086                746.963333                0.276179
# mp-1008858             1223.150000                0.333333
# mp-1008867              594.480000                0.309513
# ...                            ...                     ...
# mvc-5908                843.380000                0.287562
# mvc-5921                637.488000                0.298562
# mvc-7386                686.828000                0.292988
# mvc-7701                256.846154                0.302627
# mvc-7761                321.818462                0.311858
#
#              average_Thermal conductivity  average_Van der waals radius  \
# material_id
# mp-1000                         10.500000                      2.370000
# mp-10044                        38.500000                      1.885000
# mp-10086                         5.744233                      1.863333
# mp-1008858                      32.333333                      2.186667
# mp-1008867                     180.008860                      1.916667
# ...                                   ...                           ...
# mvc-5908                        66.415948                      1.798000
# mvc-5921                        55.715948                      1.693000
# mvc-7386                        39.818606                      1.699000
# mvc-7701                        33.939434                      1.745385
# mvc-7761                        46.247126                      1.791538
#
#              average_Velocity of sound  average_Vickers hardness  average_X  \
# material_id
# mp-1000                    2115.000000               2108.307692   1.495000
# mp-10044                   9961.500758              25554.153846   2.110000
# mp-10086                   3582.001010               2108.307692   2.593333
# mp-1008858                 2396.666667                970.769231   1.786667
# mp-1008867                 2362.500000               1528.538462   2.090000
# ...                                ...                       ...        ...
# mvc-5908                   2063.900000               2135.646154   2.666000
# mvc-5921                   1878.300000               2240.476923   2.758000
# mvc-7386                   1830.250000               1992.646154   3.005000
# mvc-7701                   1341.538462               2108.307692   2.823077
# mvc-7761                   1358.461538               2108.307692   2.723077
#
#              average_Youngs modulus  average_Metallic radius  \
# material_id
# mp-1000                   28.000000                 1.929295
# mp-10044                  59.893443                 1.622591
# mp-10086                  95.857923                 1.681727
# mp-1008858                64.666667                 1.672333
# mp-1008867                83.928962                 1.586864
# ...                             ...                      ...
# mvc-5908                 140.072131                 1.638255
# mvc-5921                 122.172131                 1.592555
# mvc-7386                 154.850820                 1.550214
# mvc-7701                  96.945776                 1.569287
# mvc-7761                  83.407314                 1.667133
#
#              average_Electron affinity  average_First Ionization Energy  \
# material_id
# mp-1000                       1.057751                         7.110736
# mp-10044                      0.542272                         9.043285
# mp-10086                      1.928471                        11.333363
# mp-1008858                    0.533999                         7.049118
# mp-1008867                    1.081605                         8.827837
# ...                                ...                              ...
# mvc-5908                      1.030784                        10.856518
# mvc-5921                      0.985497                        11.220875
# mvc-7386                      1.110240                        11.890544
# mvc-7701                      1.060389                        11.520353
# mvc-7761                      1.159550                        11.015577
#
#              min_Atomic mass  min_Atomic no  min_Atomic radius  \
# material_id
# mp-1000           127.600000           52.0               1.40
# mp-10044           10.811000            5.0               0.85
# mp-10086           18.998403            9.0               0.50
# mp-1008858        106.420000           46.0               1.40
# mp-1008867         15.999400            8.0               0.60
# ...                      ...            ...                ...
# mvc-5908           15.999400            8.0               0.60
# mvc-5921           15.999400            8.0               0.60
# mvc-7386           15.999400            8.0               0.60
# mvc-7701           15.999400            8.0               0.60
# mvc-7761           15.999400            8.0               0.60
#
#              min_Atomic radius calculated  min_Boiling point  \
# material_id
# mp-1000                              1.23            1261.00
# mp-10044                             0.87             887.00
# mp-10086                             0.42              85.03
# mp-1008858                           1.43            1837.00
# mp-1008867                           0.48              90.20
# ...                                   ...                ...
# mvc-5908                             0.48              90.20
# mvc-5921                             0.48              90.20
# mvc-7386                             0.48              90.20
# mvc-7701                             0.48              90.20
# mvc-7761                             0.48              90.20
#
#              min_Bulk modulus  min_Critical temperature  min_Density of solid  \
# material_id
# mp-1000                   9.6               1285.517647                3510.0
# mp-10044                 22.0               1285.517647                2460.0
# mp-10086                  7.7                144.000000                1960.0
# mp-1008858               31.0               1285.517647                6800.0
# mp-1008867                6.3                154.600000                 968.0
# ...                       ...                       ...                   ...
# mvc-5908                 17.0                154.600000                1550.0
# mvc-5921                 45.0                154.600000                1738.0
# mvc-7386                 70.0                154.600000                7140.0
# mvc-7701                 58.0                154.600000                7140.0
# mvc-7761                 17.0                154.600000                1550.0
#
#              min_Liquid range  min_Melting point  min_Poissons ratio  \
# material_id
# mp-1000                538.34             722.66            0.294269
# mp-10044               203.00            1090.00            0.294269
# mp-10086                31.50              53.53            0.240000
# mp-1008858            1292.60             544.40            0.280000
# mp-1008867              35.40              54.80            0.294269
# ...                       ...                ...                 ...
# mvc-5908                35.40              54.80            0.210000
# mvc-5921                35.40              54.80            0.280000
# mvc-7386                35.40              54.80            0.250000
# mvc-7701                35.40              54.80            0.250000
# mvc-7761                35.40              54.80            0.294269
#
#              min_Thermal conductivity  min_Van der waals radius  \
# material_id
# mp-1000                       3.00000                      2.06
# mp-10044                     27.00000                      1.85
# mp-10086                      0.02770                      1.47
# mp-1008858                    8.00000                      2.07
# mp-1008867                    0.02658                      1.52
# ...                               ...                       ...
# mvc-5908                      0.02658                      1.52
# mvc-5921                      0.02658                      1.52
# mvc-7386                      0.02658                      1.52
# mvc-7701                      0.02658                      1.52
# mvc-7761                      0.02658                      1.52
#
#              min_Velocity of sound  min_Vickers hardness  min_X  \
# material_id
# mp-1000                1620.000000           2108.307692   0.89
# mp-10044               3723.001515           2108.307692   2.04
# mp-10086               3300.000000           2108.307692   1.22
# mp-1008858             1790.000000            343.000000   1.14
# mp-1008867              317.500000            369.000000   0.93
# ...                            ...                   ...    ...
# mvc-5908                317.500000           1060.000000   1.00
# mvc-5921                317.500000           2108.307692   1.31
# mvc-7386                317.500000           1530.000000   1.65
# mvc-7701                317.500000           2108.307692   1.65
# mvc-7761                317.500000           2108.307692   1.00
#
#              min_Youngs modulus  min_Metallic radius  min_Electron affinity  \
# material_id
# mp-1000                    13.0             1.622591               0.144626
# mp-10044                    8.0             1.622591               0.279723
# mp-10086                   64.0             1.622591               0.307120
# mp-1008858                 32.0             1.376000               0.097493
# mp-1008867                 10.0             1.278000               0.547926
# ...                         ...                  ...                    ...
# mvc-5908                   20.0             1.285000               0.024551
# mvc-5921                   45.0             1.410000              -0.420000
# mvc-7386                  108.0             1.340000              -0.620000
# mvc-7701                   50.0             1.340000              -0.620000
# mvc-7761                   20.0             1.580000               0.024551
#
#              min_First Ionization Energy  max_Atomic mass  max_Atomic no  \
# material_id
# mp-1000                         5.211665        137.32700           56.0
# mp-10044                        8.298019         74.92160           33.0
# mp-10086                        6.217260         88.90585           39.0
# mp-1008858                      5.525000        208.98040           83.0
# mp-1008867                      5.139077         63.54600           29.0
# ...                                  ...              ...            ...
# mvc-5908                        6.113155        183.84000           74.0
# mvc-5921                        7.343918        183.84000           74.0
# mvc-7386                        7.092430         95.94000           42.0
# mvc-7701                        7.343918        118.71000           50.0
# mvc-7761                        6.113155        118.71000           50.0
#
#              max_Atomic radius  max_Atomic radius calculated  \
# material_id
# mp-1000                   2.15                          2.53
# mp-10044                  1.15                          1.14
# mp-10086                  1.80                          2.12
# mp-1008858                1.85                          2.06
# mp-1008867                1.80                          1.90
# ...                        ...                           ...
# mvc-5908                  1.80                          1.94
# mvc-5921                  1.50                          1.93
# mvc-7386                  1.45                          1.90
# mvc-7701                  1.45                          1.45
# mvc-7761                  1.80                          1.94
#
#              max_Boiling point  max_Bulk modulus  max_Critical temperature  \
# material_id
# mp-1000                 2143.0         65.000000               1285.517647
# mp-10044                4200.0        320.000000               1700.000000
# mp-10086                3609.0         91.644118               1314.000000
# mp-1008858              3373.0        180.000000               1285.517647
# mp-1008867              3200.0        140.000000               2573.000000
# ...                        ...               ...                       ...
# mvc-5908                5828.0        310.000000               1285.517647
# mvc-5921                5828.0        310.000000               1285.517647
# mvc-7386                4912.0        230.000000               1285.517647
# mvc-7701                2875.0         91.644118               1285.517647
# mvc-7761                2875.0         91.644118               1285.517647
#
#              max_Density of solid  max_Liquid range  max_Melting point  \
# material_id
# mp-1000               6240.000000           1143.00            1000.00
# mp-10044              5727.000000           1851.00            2349.00
# mp-10086              8067.890411           1810.00            1799.00
# mp-1008858           12023.000000           2076.00            1828.05
# mp-1008867            8920.000000           1842.23            1357.77
# ...                           ...               ...                ...
# mvc-5908             19250.000000           2133.00            3695.00
# mvc-5921             19250.000000           2369.92            3695.00
# mvc-7386             10280.000000           2016.00            2896.00
# mvc-7701              8067.890411           2369.92             692.68
# mvc-7761              8067.890411           2369.92            1115.00
#
#              max_Poissons ratio  max_Thermal conductivity  \
# material_id
# mp-1000                0.294269                      18.0
# mp-10044               0.294269                      50.0
# mp-10086               0.294269                      17.0
# mp-1008858             0.390000                      72.0
# mp-1008867             0.340000                     400.0
# ...                         ...                       ...
# mvc-5908               0.310000                     200.0
# mvc-5921               0.360000                     170.0
# mvc-7386               0.310000                     139.0
# mvc-7701               0.360000                     120.0
# mvc-7761               0.360000                     200.0
#
#              max_Van der waals radius  max_Velocity of sound  \
# material_id
# mp-1000                          2.68            2610.000000
# mp-10044                         1.92           16200.000000
# mp-10086                         2.32            3723.001515
# mp-1008858                       2.39            3070.000000
# mp-1008867                       2.27            3570.000000
# ...                               ...                    ...
# mvc-5908                         2.31            5940.000000
# mvc-5921                         2.18            5174.000000
# mvc-7386                         2.17            6190.000000
# mvc-7701                         2.17            3700.000000
# mvc-7761                         2.31            3810.000000
#
#              max_Vickers hardness  max_X  max_Youngs modulus  \
# material_id
# mp-1000               2108.307692   2.10           43.000000
# mp-10044             49000.000000   2.18          111.786885
# mp-10086              2108.307692   3.98          111.786885
# mp-1008858            2108.307692   2.20          121.000000
# mp-1008867            2108.307692   3.44          130.000000
# ...                           ...    ...                 ...
# mvc-5908              3430.000000   3.44          411.000000
# mvc-5921              3430.000000   3.44          411.000000
# mvc-7386              2108.307692   3.44          329.000000
# mvc-7701              2108.307692   3.44          111.786885
# mvc-7761              2108.307692   3.44          111.786885
#
#              max_Metallic radius  max_Electron affinity  \
# material_id
# mp-1000                 2.236000               1.970876
# mp-10044                1.622591               0.804820
# mp-10086                1.800000               3.401190
# mp-1008858              1.821000               0.942362
# mp-1008867              1.860000               1.461105
# ...                          ...                    ...
# mvc-5908                1.976000               1.461105
# mvc-5921                1.622591               1.461105
# mvc-7386                1.622591               1.461105
# mvc-7701                1.622591               1.461105
# mvc-7761                1.976000               1.461105
#
#              max_First Ionization Energy
# material_id
# mp-1000                         9.009808
# mp-10044                        9.788550
# mp-10086                       17.422820
# mp-1008858                      8.336839
# mp-1008867                     13.618055
# ...                                  ...
# mvc-5908                       13.618055
# mvc-5921                       13.618055
# mvc-7386                       13.618055
# mvc-7701                       13.618055
# mvc-7761                       13.618055
#
# [1399 rows x 68 columns]

# %%
# Computing mean and standard devaitaion for train X and normalizing
mean_train_X = X_train.apply(np.mean, axis=0)
std_train_X = X_train.apply(np.std, axis=0)
norm_train_X = (X_train - mean_train_X) / std_train_X

# Computing mean and standard devaitaion for test X and normalizing 
mean_test_X = X_test.apply(np.mean, axis=0)
std_test_X = X_test.apply(np.std, axis=0)
norm_test_X = (X_test - mean_test_X) / std_test_X

# %%
# from sklearn.linear_model import LinearRegression
# linear_model = LinearRegression()
# linear_model.fit(norm_train_X, y_train['dielectric_poly_total'])
# #linear_predictions = pd.DataFrame(linear_model.predict(norm_test_X),
#                                 #  columns = ['dielectric_poly_total'])
# linear_predictions = linear_model.predict(X_test)

# linear_model.score(design_matrix, train_filt['dielectric_poly_total'])

# #Reallinear_prediction = linear_model.predict(test)

# %%
from sklearn.linear_model import LinearRegression
linear_model = LinearRegression()
linear_model.fit(X_train, y_train['dielectric_poly_total'])
#linear_predictions = pd.DataFrame(linear_model.predict(norm_test_X),
                                #  columns = ['dielectric_poly_total'])
linear_predictions = linear_model.predict(X_test)

linear_model.score(design_matrix, train_filt['dielectric_poly_total'])

#Reallinear_prediction = linear_model.predict(test)

# %%
data2 = mpr.query(criteria={"task_id": {"$in":test["material_id"].to_list()}}, properties=["material_id","energy",
        "energy_per_atom",
        "volume",
        "formation_energy_per_atom",
        "nsites",                                                                                  
        "nelements",
        "density",  "band_gap"])
#df = pd.DataFrame(data)
df2 = pd.DataFrame(data2)
df2

# %%
type(df2)

# %%
df2.set_index('material_id',inplace=True)
df2

# %%
from sklearn.linear_model import LinearRegression
linear_model = LinearRegression()
linear_model.fit(X_train, y_train['dielectric_poly_total'])
#linear_predictions = pd.DataFrame(linear_model.predict(norm_test_X),
                                #  columns = ['dielectric_poly_total'])
linear_predictions = linear_model.predict(X_test)

linear_model.score(design_matrix, train_filt['dielectric_poly_total']) #CLOSE WE GOT TO PREDICTING x TEST....PROBABLY USE SOME FIXING A BETTER WAY TO TELL US HOW CLOSE OUR PREDICTION IS TO ACTUAL X TEST
 

#Y_data_intitial = df2[cols]
X_data_test = design_matrix_X

#F_linear_predictions = linear_model.predict(df2)
Final_linear_predictions = linear_model.predict(X_data_test)
flp_X = pd.DataFrame(Final_linear_predictions)

d_list=[test, flp_X]


newsubs = pd.concat(d_list, axis=1)
newsubs_update = newsubs.rename(columns={0:'dielectric_poly_total'})
newsubs_update.to_csv("submission_test_3.csv", index=False)

# %%
type(linear_predictions)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error


MAE = mean_absolute_error(y_test['dielectric_poly_total'], 
                          linear_predictions)


RMSE = np.sqrt(mean_squared_error(y_test['dielectric_poly_total'], 
                          linear_predictions))


# from sklearn.model_selection import cross_val_predict, KFold
# from sklearn.metrics import r2_score

# # Cross- Validation
# kfold = KFold(n_splits=5, shuffle=True, random_state=42)
# #yhat_mlr = cross_val_predict(linear_model, x_jojo, targets['dielectric_poly_total'], cv=kfold)
# CV_linMAE = mean_absolute_error(targets['dielectric_poly_total'], yhat_mlr)
# CV_linRMSE = np.sqrt(mean_squared_error(targets['dielectric_poly_total'], yhat_mlr))

# print('Cross Val MAE:', CV_linMAE)
# print('Cross Val RMSE:', CV_linRMSE)
print("The MAE is:", MAE)
print("The RMSE is:", RMSE)

# %%
# dielects=(model.predict(test_data))

# df_submit = pd.DataFrame(list(dielects))
# df_submit.to_csv('dielectric_csv.csv')

# %%
# data2 = mpr.query(criteria={"task_id": {"$in":test["material_id"].to_list()}}, properties=["energy",
#         "energy_per_atom",
#         "volume",
#         "formation_energy_per_atom",
#         "nsites",
#         "unit_cell_formula",
#         "pretty_formula",
#         "is_hubbard",
#         "elements",
#         "nelements",
#         "e_above_hull",
#         "hubbards",
#         "is_compatible",
#         "spacegroup",
#         "task_ids",
#         "band_gap",
#         "density",
#         "icsd_id",
#         "icsd_ids",
#         "total_magnetization",
#         "material_id",
#         "oxide_type",
#         "tags",
#         "elasticity"])
# df = pd.DataFrame(data)
# df2 = pd.DataFrame(data2)

# %%
# desired_factors = [ "energy",
#         "energy_per_atom",
#         "volume",
#         "formation_energy_per_atom",
#         "nsites",
#         "nelements",
#         "density",
#         "band_gap"] 

# Y_data = df2[cols]

# #set my model to DecisionTree
# model = DecisionTreeRegressor()

# #set prediction data to factors that will predict, and set target to SalePrice
# train_data = X_data[desired_factors]
# test_data = Y_data[desired_factors]
# target = train.dielectric_poly_total

# # #fitting model with prediction data and telling it my target
# model.fit(train_data, target)

# dielects=(model.predict(test_data))


# dfhi= pd.read_csv("test.csv")

# df_submit = pd.DataFrame(list(dielects))
# df_submit.to_csv('dielectric.csv')

# %%
#dielects

# %%
#len(dielects)

# %%
#test

# %%
 #shit=pd.DataFrame(dielects)

# %%
#d_list=[test, shit]

# %%
#newsubs=pd.concat(d_list, axis=1)

# %%
#newsubs_update=newsubs.rename(columns)

# %%
#newsubs.to_csv("submission_test.csv")

# %%
# from sklearn import metrics
# from sklearn.model_selection import cross_val_predict, KFold
# from sklearn.metrics import r2_score
# # print('Mean absolute error:', metrics.mean_absolute_error(y_test, linear_predictions))
# # print('Mean squared error:', metrics.mean_squared_error(y_test, linear_predictions))
# # print('root mean squared error:', np.sqrt(metrics.mean_squared_error(y_test, linear_predictions)))

# # CV_linMAE = mean_absolute_error(targets['formation_energy_per_atom'], yhat_mlr)
# # CV_linRMSE = np.sqrt(mean_squared_error(targets['formation_energy_per_atom'], yhat_mlr))
# kfold = KFold(n_splits=5, shuffle=True, random_state=42)
# yhat_mlr = cross_val_predict(linear_model, design_matrix, y_jojo['dielectric_poly_total'], cv=kfold)
# metrics.mean_absolute_error(y_test, yhat_mlr)

# %%
# x_train, x_test, y_train, y_test = train_test_split(x_jojo, y_jojo, test_size = 0.2 )

# %%
# x_train.head()

# %%
# # Computing mean and standard devaitaion for train X and normalizing
# mean_train_X = x_train.apply(np.mean, axis=0)
# std_train_X = x_train.apply(np.std, axis=0)
# norm_train_X = (x_train - mean_train_X) / std_train_X

# # Computing mean and standard devaitaion for test X and normalizing 
# mean_test_X = x_test.apply(np.mean, axis=0)
# std_test_X = x_test.apply(np.std, axis=0)
# norm_test_X = (x_test - mean_test_X) / std_test_X

# %%
# # Importing functions for regression 
# from sklearn.model_selection import train_test_split
# from sklearn.linear_model import LinearRegression, Ridge, Lasso, LogisticRegression
# from sklearn.discriminant_analysis import (LinearDiscriminantAnalysis as LDA, 
#                                            QuadraticDiscriminantAnalysis as QDA)




# linear_model = LinearRegression()
# linear_model.fit(norm_train_X, y_train['dielectric_poly_total'])
# #linear_predictions = pd.DataFrame(linear_model.predict(norm_test_X),
#                                   #columns = ['dielectric_poly_total'])
# linear_predictions = linear_model.predict(norm_test_X)


# mae = mean_absolute_error(y_test, linear_predictions)

# mae





# # from sklearn.metrics import mean_squared_error, mean_absolute_error


# MAE = mean_absolute_error(y_test['dielectric_poly_total'],linear_predictions['dielectric_poly_total'])

# # RMSE = np.sqrt(mean_squared_error(y_test['dielectric_poly_total'], 
# #                           linear_predictions['dielectric_poly_total']))

# print("The MAE is:", MAE)
# # print("The RMSE is:", RMSE)

# %%
#mymodel= np.poly1d(np.polyfit(x_train, y_train, 4 ))

# %%
#r2 = r2_score(y_train, linear_predictions)
