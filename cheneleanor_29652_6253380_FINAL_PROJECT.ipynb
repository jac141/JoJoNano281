# %% [markdown]
# Hello! My name is Eleanor Chen and I really like art, animation and game design.
#
# I made a program that can write out short names using the Colab Turtle. The turtle actually already has a function called shelly.write, but it just prints out text instead of drawing it.
#
# My program would take user input and then write it out. I used "if" loops for every letter.
#
# I could have definitely improved this program by making more complex-looking letters. I stuck to mostly 90 degree angles because it would be easier for me to see the movement in my head as I typed it out.
#
# Another way I could have gone about things differently is if I had made the program adaptable to the amount of letters that was in the input. for example, the size of the letters (instead of 50 width-wise) would be determined by the length of the screen divided by the number of characters in the string.
#
# 5 of the lessons I used in this program are functions, for loops, if loops, variables and printing.

# %% [markdown]
# 2 problems I had while coding this:
#
# I didn't want to use if or loops for ever single letter to make sure it accomodated borth uppercase and lowercase inputs, so I solved this problem by remembering that oython has a function that can make a string all uppercase or all lowercase. I used the function lower() to do this.
#
# Another small problem I ran into was that a small dot would shop up in the center of the canvas because I hadn't put the "clear" function in the right place. This just took a bit of rearranging to fix.

# %%
#setting up the turtle
# !pip3 install ColabTurtle
import time
import ColabTurtle.Turtle as shelly
shelly.initializeTurtle(initial_speed=(7))
colors = ['red', 'orange', 'yellow', 'green', 'blue', 'purple']
import sys

def printt(s): #function. I wanted the instructions to come out letter by letter instead of popping up all at once.
  for c in s:
    sys.stdout.write(c)
    sys.stdout.flush()
    time.sleep(0.03)

#getting the input from the user in var "word"

printt("Enter text you want Shelly to write out.") #printing. it makes the instructions show up.
word=input(" ") #variable. it stores information, and in this case it stores the user input as a string.

shelly.home()

#getting the turtle on the side of the screen

shelly.penup()
shelly.left(90)
shelly.forward(400)
shelly.right(90)
shelly.backward(50)

shelly.clear()

#making sure the input is all lowercase for the if statements to work

word=word.lower()
thelist=[char for char in word] # turning the string into a list
print(thelist)

#all of the if statements for the letters

for i in thelist: #for loop. it repeats the if statements for every string in the list, or in this case every letter.
  if i == ("a"): #if loop. it will execute the code within it if the statement applies.
    shelly.penup()
    shelly.right(90)
    shelly.forward(20)
    shelly.left(90)

    shelly.pendown()
    shelly.forward(50)
    shelly.right(90)
    shelly.forward(50)
    shelly.right(90)
    shelly.forward(50)
    shelly.backward(25)
    shelly.right(90)
    shelly.forward(50)
    shelly.backward(50)
    shelly.right(90)
    shelly.backward(25)

  if i == ("b"): #B
    shelly.penup()
    shelly.right(90)
    shelly.forward(20)
    shelly.left(90)

    shelly.pendown()
    shelly.forward(50)
    shelly.right(90)
    shelly.forward(50)
    shelly.right(90)
    shelly.forward(25)
    shelly.right(90)
    shelly.forward(50)
    shelly.backward(50)
    shelly.left(90)
    shelly.forward(25)
    shelly.right(90)
    shelly.forward(50)
    shelly.backward(50)
    shelly.right(90)

  if i == ("c"): #C
    shelly.penup()
    shelly.right(90)
    shelly.forward(20)
    shelly.left(90)

    shelly.pendown()
    shelly.right(90)
    shelly.forward(50)
    shelly.backward(50)
    shelly.left(90)
    shelly.forward(50)
    shelly.right(90)
    shelly.forward(50)
    shelly. backward(50)
    shelly.left(90)
    shelly.backward(50)
    shelly.left(90)
    shelly.backward(50)
    shelly.right(90)

  if i == ("d"): #D
    shelly.penup()
    shelly.right(90)
    shelly.forward(20)
    shelly.left(90)

    shelly.pendown()
    shelly.forward(50)
    shelly.right(90)
    for x in range(30):
      shelly.forward(2.63)
      shelly.right(6)
    shelly.penup()
    shelly.right(180)
    shelly.forward(50)
    shelly.left(90)

  if i == ("e"): #E
    shelly.penup()
    shelly.right(90)
    shelly.forward(20)
    shelly.left(90)

    shelly.pendown()
    shelly.forward(50)
    shelly.right(90)
    shelly.forward(50)
    shelly.backward(50)
    shelly.right(90)
    shelly.forward(20)
    shelly.left(90)
    shelly.forward(50)
    shelly.backward(50)
    shelly.right(90)
    shelly.forward(30)
    shelly.left(90)
    shelly.forward(50)
    shelly.left(90)

  if i == ("f"): #F
    shelly.penup()
    shelly.right(90)
    shelly.forward(20)
    shelly.left(90)

    shelly.pendown()
    shelly.forward(50)
    shelly.right(90)
    shelly.forward(50)
    shelly.backward(50)
    shelly.right(90)
    shelly.forward(20)
    shelly.left(90)
    shelly.forward(50)
    shelly.backward(50)
    shelly.right(90)
    shelly.forward(30)
    shelly.left(90)
    shelly.penup()
    shelly.forward(50)
    shelly.left(90)

  if i == ("g"): #G
    shelly.penup()
    shelly.right(90)
    shelly.forward(20)
    shelly.left(90)

    shelly.pendown()
    shelly.forward(50)
    shelly.right(90)
    shelly.forward(50)
    shelly.backward(50)
    shelly.right(90)
    shelly.forward(50)
    shelly.left(90)
    shelly.forward(50)
    shelly.left(90)
    shelly.forward(20)
    shelly.left(90)
    shelly.forward(20)
    shelly.penup()
    shelly.left(90)
    shelly.forward(20)
    shelly.left(90)
    shelly.forward(20)
    shelly.left(90)
  
  if i == ("h"): #H
    shelly.penup()
    shelly.right(90)
    shelly.forward(20)
    shelly.left(90)

    shelly.pendown()
    shelly.forward(50)
    shelly.backward(20)
    shelly.right(90)
    shelly.forward(50)
    shelly.left(90)
    shelly.forward(20)
    shelly.backward(50)

  if i == ("i"): #I
    shelly.penup()
    shelly.right(90)
    shelly.forward(20)
    shelly.left(90)

    shelly.pendown()
    shelly.right(90)
    shelly.forward(25)
    shelly.left(90)
    shelly.forward(50)
    shelly.left(90)
    shelly.forward(25)
    shelly.backward(50)
    shelly.forward(25)
    shelly.right(90)
    shelly.backward(50)
    shelly.right(90)
    shelly.forward(25)
    shelly.left(90)

  if i == ("j"): #J
    shelly.penup()
    shelly.right(90)
    shelly.forward(20)
    shelly.left(90)

    shelly.pendown()
    shelly.right(90)
    shelly.forward(25)
    shelly.left(90)
    shelly.forward(50)
    shelly.left(90)
    shelly.forward(25)
    shelly.backward(50)
    shelly.forward(25)
    shelly.right(90)
    shelly.backward(50)
    shelly.right(90)
    shelly.penup()
    shelly.forward(25)
    shelly.left(90)

  if i == ("k"): #K
    shelly.penup()
    shelly.right(90)
    shelly.forward(20)
    shelly.left(90)

    shelly.pendown()
    shelly.forward(50)
    shelly.backward(25)
    shelly.right(60)
    shelly.forward(55.9)
    shelly.backward(55.9)
    shelly.right(60)
    shelly.forward(55.9)
    shelly.backward(55.9)
    shelly.right(60)
    shelly.forward(25)
    shelly.left(90)
    shelly.penup()
    shelly.forward(50)
    shelly.left(90)

  if i == ("l"): #L
    shelly.penup()
    shelly.right(90)
    shelly.forward(20)
    shelly.left(90)

    shelly.pendown()
    shelly.forward(50)
    shelly.backward(50)
    shelly.right(90)
    shelly.forward(50)
    shelly.left(90)

  if i == ("m"): #M
    shelly.penup()
    shelly.right(90)
    shelly.forward(20)
    shelly.left(90)

    shelly.pendown()
    shelly.forward(50)
    shelly.right(135)
    shelly.forward(35.36)
    shelly.left(90)
    shelly.forward(35.36)
    shelly.left(45)
    shelly.backward(50)

  if i == ("n"): #N
    shelly.penup()
    shelly.right(90)
    shelly.forward(20)
    shelly.left(90)

    shelly.pendown()
    shelly.forward(50)
    shelly.right(135)
    shelly.forward(70.71)
    shelly.left(135)
    shelly.forward(50)
    shelly.backward(50)

  if i == ("o"): #O
    shelly.penup()
    shelly.right(90)
    shelly.forward(20)
    shelly.left(90)

    shelly.pendown()
    shelly.forward(50)
    shelly.right(90)
    shelly.forward(50)
    shelly.right(90)
    shelly.forward(50)
    shelly.right(90)
    shelly.forward(50)
    shelly.backward(50)
    shelly.right(90)

  if i == ("p"): #P
    shelly.penup()
    shelly.right(90)
    shelly.forward(20)
    shelly.left(90)

    shelly.pendown()
    shelly.forward(50)
    shelly.right(90)
    shelly.forward(50)
    shelly.right(90)
    shelly.forward(25)
    shelly.right(90)
    shelly.forward(50)
    shelly.backward(50)
    shelly.right(90)
    shelly.penup()
    shelly.backward(25)

  if i == ("q"): #Q
    shelly.penup()
    shelly.right(90)
    shelly.forward(20)
    shelly.left(90)

    shelly.pendown()
    shelly.forward(50)
    shelly.right(90)
    shelly.forward(50)
    shelly.right(90)
    shelly.forward(40)
    shelly.right(45)
    shelly.forward(14.14)
    shelly.right(135)
    shelly.penup()
    shelly.forward(10)
    shelly.right(135)
    shelly.pendown()
    shelly.forward(14.14)
    shelly.left(135)
    shelly.left(90)
    shelly.penup()
    shelly.forward(10)
    shelly.pendown()
    shelly.forward(40)
    shelly.penup()
    shelly.backward(50)
    shelly.right(90)

  if i == ("r"): #R
    shelly.penup()
    shelly.right(90)
    shelly.forward(20)
    shelly.left(90)

    shelly.pendown()
    shelly.forward(50)
    shelly.right(90)
    shelly.forward(50)
    shelly.right(90)
    shelly.forward(25)
    shelly.right(90)
    shelly.forward(50)
    shelly.right(180)
    shelly.right(26.56)
    shelly.forward(55.9)
    shelly.left(116.56)

  if i == ("s"): #S
    shelly.penup()
    shelly.right(90)
    shelly.forward(20)
    shelly.left(90)

    shelly.forward(50)
    shelly.right(90)
    shelly.forward(50)
    shelly.pendown()
    shelly.backward(50)
    shelly.left(90)
    shelly.backward(25)
    shelly.right(90)
    shelly.forward(50)
    shelly.right(90)
    shelly.forward(25)
    shelly.right(90)
    shelly.forward(50)
    shelly.backward(50)
    shelly.right(90)

  if i == ("t"): #T
    shelly.penup()
    shelly.right(90)
    shelly.forward(20)
    shelly.left(90)

    shelly.right(90)
    shelly.forward(25)
    shelly.pendown()
    shelly.left(90)
    shelly.forward(50)
    shelly.left(90)
    shelly.forward(25)
    shelly.backward(50)
    shelly.right(90)
    shelly.penup()
    shelly.backward(50)

  if i == ("u"): #U
    shelly.penup()
    shelly.right(90)
    shelly.forward(20)
    shelly.left(90)

    shelly.pendown()
    shelly.forward(50)
    shelly.backward(50)
    shelly.right(90)
    shelly.forward(50)
    shelly.left(90)
    shelly.forward(50)
    shelly.backward(50)

  if i == ("v"): #V
    shelly.penup()
    shelly.right(90)
    shelly.forward(20)
    shelly.left(90)

    shelly.right(90)
    shelly.forward(25)
    shelly.left(90)
    shelly.pendown()
    shelly.left(26.56)
    shelly.forward(55.9)
    shelly.backward(55.9)
    shelly.right(26.56)
    shelly.right(26.56)
    shelly.forward(55.9)
    shelly.backward(55.9)
    shelly.right(64.44)
    shelly.penup()
    shelly.forward(25)
    shelly.left(90)
  
  if i == ("w"): #W
    shelly.penup()
    shelly.right(90)
    shelly.forward(20)
    shelly.left(90)

    shelly.pendown()
    shelly.forward(50)
    shelly.backward(50)
    shelly.right(90)
    shelly.forward(25)
    shelly.left(90)
    shelly.forward(50)
    shelly.backward(50)
    shelly.right(90)
    shelly.forward(25)
    shelly.left(90)
    shelly.forward(50)
    shelly.backward(50)

  if i == ("x"): #X
    shelly.penup()
    shelly.right(90)
    shelly.forward(20)
    shelly.left(90)

    shelly.pendown()
    shelly.right(45)
    shelly.forward(70.71)
    shelly.backward(35.355)
    shelly.left(90)
    shelly.forward(35.355)
    shelly.backward(70.71)
    shelly.right(45)

  if i == ("y"): #Y
    shelly.penup()
    shelly.right(90)
    shelly.forward(20)
    shelly.left(90)

    shelly.right(90)
    shelly.forward(25)
    shelly.left(90)
    shelly.pendown()
    shelly.forward(25)
    shelly.left(45)
    shelly.forward(35.36)
    shelly.backward(35.36)
    shelly.right(90)
    shelly.forward(35.36)
    shelly.backward(35.36)
    shelly.left(45)
    shelly.backward(25)
    shelly.right(90)
    shelly.penup()
    shelly.forward(25)
    shelly.left(90)

  if i == ("z"): #Z
    shelly.penup()
    shelly.right(90)
    shelly.forward(20)
    shelly.left(90)

    shelly.pendown()
    shelly.right(90)
    shelly.forward(50)
    shelly.backward(50)
    shelly.left(45)
    shelly.forward(70.71)
    shelly.left(135)
    shelly.forward(50)
    shelly.backward(50)
    shelly.right(90)
    shelly.penup()
    shelly.backward(50)

  if i == (" "):
    shelly.penup()
    shelly.right(90)
    shelly.forward(40)
    shelly.left(90)
# Out:
# ...
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
# ...
